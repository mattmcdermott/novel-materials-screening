# %% [markdown]
# ## Screening the Materials Project for Previously Unsynthesized Materials
# ## Revision
# #### Date: July 24, 2023
#
# **Authors**: Matthew McDermott and Max Gallant

# %% [markdown]
# From Nathan: "what if you were to allow materials with E_hull < 20 meV/atom? Or < 50 meV/atom? And so on..."

# %% [markdown]
# #### Imports

# %%
from collections import OrderedDict
import re

import emmet
from emmet.core.summary import HasProps
import matplotlib.pyplot as plt
from monty.serialization import dumpfn, loadfn
from mp_api.client import MPRester
import pandas 
from pymatgen.core.composition import Composition, Element
import seaborn as sns

sns.set("talk",style="ticks")

# %load_ext autoreload
# %autoreload 2

# %%
radioactive = ["Ac","Th","Pa","U","Np","Pu","Tc"]  # all other radioactive elements are not on MP
expensive = ["Cs","Rb","Pm","Tm","Sc","Tl","Re","Ir","Os","Pd","Ru","Pt","Rh","Au"]
dangerous = ["Hg","As"]

exclude_elements = radioactive + expensive + dangerous

# %% [markdown]
# #### Get summary documents with MPRester

# %%
new_metastable_cutoff = 0.050  # eV/atom

# %%
with MPRester() as mpr:
    materials = mpr.summary.search(theoretical=True, 
                                   energy_above_hull=(0.000,new_metastable_cutoff), 
                                   exclude_elements=exclude_elements, 
                                   all_fields=False,
                                   deprecated=False,
                                   has_props=[HasProps("oxi_states")],
                                   fields=["material_id","composition","formation_energy_per_atom", 
                                          "energy_above_hull", "equilibrium_reaction_energy_per_atom"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/29605 [00:00<?, ?it/s]

# %% [markdown]
# #### Get oxidation state docs with MPRester

# %%
with MPRester() as mpr:
    oxi_states = mpr.oxidation_states.search([doc.material_id for doc in materials], fields=["material_id","average_oxidation_states", "structure"])
# Out:
# Retrieving OxidationStateDoc documents:   0%|          | 0/29605 [00:00<?, ?it/s]

# %% [markdown]
# #### Join and filter by compounds with pre-computed oxidation states
# **WARNING**: This may take a few mins if there are a lot of materials (i.e., big e_hull cutoff)

# %%
all_data = []
for d1 in materials:
    d2 = list(filter(lambda i: i.material_id == d1.material_id, oxi_states))[0]
    average_oxidation_states = d2.average_oxidation_states
    if average_oxidation_states:
        doc = d1.dict()
        del doc["fields_not_requested"]
        doc["average_oxidation_states"] = average_oxidation_states
        doc["structure"] = d2.structure
        all_data.append(doc)

# %%
len(all_data)  # this number will be lower than the original number
# Out:
# 24278

# %% [markdown]
# #### Removing any duplicate formulas

# %%
seen_formulas = set()
all_data_no_duplicates = []

for d in sorted(all_data, key=lambda i: i["formation_energy_per_atom"]):
    formula = d["composition"].reduced_formula 
    if formula in seen_formulas:
        continue
    else:
        all_data_no_duplicates.append(d)
        seen_formulas.add(formula)

# %%
len(all_data_no_duplicates)
# Out:
# 16406

# %% [markdown]
# #### Filter by unreasonable oxidation states
# If the average oxidation state is outside of the range spanned by the `common_oxidation_states` property (see pymatgen), then we will discard.
#
# For convenience, we will print out all the discard compositions and their avg. oxidation states.

# %%
filtered_data = []
for d in all_data_no_duplicates:
    species = set(d["structure"].species)
    bad = False
    for specie in species:
        common_oxidation_states = specie.element.common_oxidation_states
        if int(specie.oxi_state) not in range(min(common_oxidation_states), max(common_oxidation_states)+1):
            print(specie, d["composition"])
            bad=True
            break
    if not bad:
        filtered_data.append(d)
# Out:
# Yb2+ Yb2 F4
# Pr2+ Ca18 Pr2 F40
# Yb2+ Yb8 Al8 F40
# Yb2+ Yb4 Hf4 O12
# Ti3+ Ba4 Ca4 Ti4 F28
# Ag2+ Ca6 Hf6 Ag2 F40
# Sm2+ Ce4 Sm1 O9
# Ti3+ Ca4 Ti4 F20
# Ti3+ Sr8 Ti8 F40
# La2+ La3 Ce4 O12
# Ti3+ Ba4 Mg4 Ti4 F28
# Ti2+ Na1 Hf2 Ti1 F11
# V3+ Ba4 Ca4 V4 F28
# Ti3+ La10 Ti10 O34
# Ta4+ Y11 Ta5 O28
# La2+ La20 Al3 Si9 O52
# Tb4+ Tb1 Ce3 O8
# Yb2+ Yb4 Ti4 O12
# Ti3+ Sr2 Li2 Ti2 F12
# La2+ Sr2 La18 Al1 Si11 O52
# V4+ Zr15 V1 O32
# Ti3+ Nd20 Ti20 O68
# Ti3+ Na4 Sr4 Ti4 F24
# V3+ Ba4 Mg4 V4 F28
# La2+ La3 Ti4 O12
# Pr4+ Ce3 Pr1 O8
# Ti3+ Ba8 Na8 Ti8 F48
# V4+ Zr11 V1 O24
# Cr2+ Ba4 Cr2 F12
# V3+ Ca2 V2 F10
# Ti3+ Sm12 Ta4 Ti8 O42
# Ti3+ La4 Mg1 Ti3 O12
# Ti3+ Nd20 Ti18 Ga2 O68
# Ti3+ Li1 La4 Ti3 O12
# Ti3+ Pr20 Ti18 Ga2 O68
# V3+ Ba4 Ca2 Mn2 V4 F28
# V2+ Ba6 Al3 V6 F33
# Nd2+ Nd3 Ti4 O12
# Ho2+ Ca2 Ho2 Ti4 O12
# V4+ Zr14 V2 O32
# Pr4+ Ce2 Pr1 O6
# Ti3.25+ Ca1 Y3 Ti4 O12
# Ti3+ Nd18 Ti20 O60
# Ti3+ Sr1 La2 Ti3 O9
# Ti3.5+ Ca2 Y2 Ti4 O12
# Cr2+ Ba6 Al3 Cr6 F33
# Mo3+ Ba4 Ca4 Mo4 F28
# Ti3.75+ Ca3 Y1 Ti4 O12
# Cr2+ Zr1 Cr1 F6
# Ti3+ Sr4 La1 Ti5 O15
# Ti3+ Nd19 Ti20 O60
# Pr2+ Ca2 Pr2 Ti4 O12
# V3+ Ba4 Ca2 V4 Fe2 F28
# Ti3+ Ca18 La2 Ti20 O60
# Ti3+ Sr18 La2 Ti20 O60
# V3+ Sr2 Li2 V2 F12
# V3+ Li2 Ca2 V2 F12
# Ti3+ Li1 La3 Ti4 O12
# Ti3+ Na2 Ti6 F20
# Ta4+ Ca4 Zr3 Ta1 O12
# Tb4+ Tb6 F24
# O- Ca4 Y6 Si6 O26
# V3+ Na4 Sr4 V4 F24
# Cr2+ Ca2 Cr2 F8
# Ti3+ Nd4 Mg1 Ta4 Ti4 O24
# La2+ Ba4 La6 Ti4 Nb4 O30
# V3+ Ba8 Na8 V8 F48
# V4+ Sr8 V8 O4 F40
# Ce2+ Ce22 Mn2 S32
# Mo3+ Ba4 Mg4 Mo4 F28
# O- Ca16 Si8 O30 F6
# Yb2+ Yb2 Al2 O5
# Ti3+ Ba2 Ti16 O32
# Ti3+ Ba6 Ta9 Ti7 O42
# Ti3+ Ba4 Ti28 O56
# Ti3+ K2 Ti2 F8
# Ti3+ Ba3 Ti20 O40
# Ti3+ Ba2 Ti20 O40
# Ag2+ K6 Hf8 Ag4 F46
# V2+ Al1 V1 F5
# Ti3+ Ba2 Ti12 O24
# Cr2+ Zr3 Nb1 Cr4 F24
# Ti3+ Ti1 O1 F1
# V4+ Ca1 V1 F6
# Nb4+ Ti15 Nb1 O32
# Ti3+ Ba2 Ti28 O56
# Tb4+ Ba8 Tb4 Hf4 O24
# Ti3+ Ba2 Li1 Ti11 O24
# La2+ La5 Ta22 O62
# V3+ Mg2 V2 F10
# Ti3+ Ca4 Ta2 Ti2 O12
# V3+ K6 Ca6 V12 F54
# Ta4+ Sr3 Li1 Ta4 O12 F2
# Ti3+ Na4 Ti4 F16
# V4+ Ba4 V4 O4 F16
# O- Ca18 Si8 O34 F2
# Ta4+ Sr6 Ta10 O30
# Ti3+ Mg11 Ti25 O60
# La2+ Li4 La5 Ti6 Nb2 O26
# Ti3.9375+ K1 Ti16 O32
# W3+ Ba4 Mg4 W4 F28
# Ti3+ Mg5 Ti13 O30
# Ti3+ Mg3 Ti9 O20
# Ti3+ Mg4 Ti14 O30
# Ti3+ Ba6 Li2 Ta9 Ti7 O42
# Cr2+ Al1 Cr1 F5
# La2+ La2 Al24 O38
# Ti3+ Mg2 Ti10 O20
# Ti3+ Na5 Ca7 Zr2 Ti2 Si8 O30 F6
# Ti3+ Ba4 Ti24 O44
# V3+ Y12 Al12 V8 O48
# Ti3+ Ba2 Y1 Ti3 O8
# Ta4+ Eu6 Ta10 O30
# Nd2+ Nd4 Eu8 Be4 O20
# Ti3+ Ca2 La8 Ti5 Cr5 O30
# La2+ La2 Al44 O68
# Nb4+ Eu2 Hf1 Nb1 O6
# Ti3+ Li1 Ti8 O16
# Gd2+ Gd1 Al22 O34
# Nb4+ Ca13 Nb3 Si8 O36
# Ti3.83333333+ K2 Ti12 O24
# Pr2+ Pr1 Al22 O34
# V3+ Ba4 Mn4 V4 F28
# Ti3+ Mg1 Ti11 O20
# Nb4+ Ba6 Ta8 Nb2 O30
# Ti3+ Ca12 Ti8 Si12 O48
# Ti3+ Mg2 Ti28 O50
# Mo3+ Ca2 Mo2 F10
# Cr2+ Ca6 La14 Ti10 Cr10 O60
# Ti3+ Ti26 O44
# Ti3+ Mg1 Ti23 O40
# V3+ Ba4 Mg2 V4 Cu2 F28
# Nb4+ Ba1 Sr1 Zr1 Nb1 O6
# V4+ Ca1 La2 V1 O6
# Ti3+ Li2 Ti22 O40
# Nb4+ Ti5 Nb1 O12
# Ti3+ Li2 Ti12 O24
# V4+ La2 Mg1 V1 O6
# Nb4+ Sr1 Eu1 Ti1 Nb1 O6
# Ti3+ Ca4 Ti2 Al2 O10
# Ti3+ Na4 Ti20 O40
# Tb4+ Ba8 Tb4 Ce4 O24
# Ti3+ Ti22 Be2 O40
# Ti3+ Na10 Ti6 F28
# Nb4+ Na4 Ca8 Zr2 Nb2 Si8 O32 F4
# V3+ Ba4 Ca1 V4 Cu2 F28
# Ti3+ Ba4 Li6 Ti19 O44
# Ti3+ Ti8 O13
# Nb4+ Eu2 Ti1 Nb1 O6
# Ti3+ Ti11 O18
# Ta4+ Ba8 Ta7 O24
# Ti3+ K2 Li1 Ti1 F6
# Ti3.2+ Ti15 O24
# Ti3.5+ Mg1 Ti4 O8
# V3+ Ba4 V4 Zn4 F28
# Ti3+ Ca4 Ti8 O16
# V3+ Na4 Mg2 V2 F14
# Nb4+ Sr1 Ca1 Ti1 Nb1 O6
# Ti3+ Li3 Ti12 O24
# Ti3+ Na8 Ti4 F20
# Ta4+ Sr20 Ta8 O39
# Ti3+ Sr5 Ti5 O13
# Ti3.15789474+ Ti19 O30
# Ti3.75+ K1 Ti4 O8
# V3+ Ba2 V2 Cu1 F12
# Ni3+ Ba10 Ti8 Nb1 Ni1 O30
# Nb4+ Ti3 Nb1 O8
# Nb4+ Ba6 Ti7 Nb9 O42
# Nb4+ Yb2 Mg1 Nb2 O8
# Nd2+ La4 Nd4 S4 O7
# Ti3+ Ta2 Ti2 O8
# Ti3+ Ba3 Ti3 O8
# Ti3+ K2 Na1 Ti1 F6
# Ti3+ K6 Ti16 O34
# V3+ Ba4 V4 Cd4 F28
# Nb4+ Ti10 Nb4 O28
# Ta4+ Ba8 Li1 Ta7 O24
# Ti3+ Eu2 Ti2 O5
# Ti3+ Na4 Ti16 O32
# V4+ Mg1 V1 F6
# Yb2+ Yb1 Ta1 O3
# In+ Al22 In2 O34
# Cr2+ Ca4 La4 Ta4 Cr4 O24
# Ti3+ Li1 Ti3 O6
# Mo3+ Tb5 Mg1 Mo2 O12
# Cr2+ Mg2 Cr2 F8
# Co4+ Ba8 Ti3 Co1 Si8 O32
# V4+ Sr8 Zr4 V4 O24
# Ti3.625+ Li6 Ti16 O32
# V3+ Sr8 V4 C4 O12 F20
# Mo3+ Ba4 Ca2 Cu2 Mo4 F28
# La2+ La3 Nb8 O24
# Pr4+ Sr4 Ce1 Pr1 O8
# Fe4+ Sr20 Ti16 Fe4 O60
# Ti3+ K3 Ti1 F6
# V3+ Sr4 Ta2 V2 O12
# Ti3+ Na16 Ti16 F56
# Ta4+ Ba1 Ta1 O3
# Nb2+ Tb16 Nb16 O44
# Ti3+ Li15 Ti36 O72
# Nb4+ Ba6 Li2 Ti7 Nb9 O42
# Ti3+ Li12 Ti28 O56
# Ti3+ Na6 Ti2 F12
# Ti3.06666667+ Ti15 V1 O24
# Ti3+ Li11 Ti24 O48
# Ti3+ Li13 Ti28 O56
# V3+ Ca4 Ta2 V2 O12
# Ta4.5+ Li1 Pr2 Ta2 Cl2 O7
# Ta4+ Ba6 Ta2 Nb8 O30
# La2+ Ba4 La2 Nb10 O30
# Ti3+ Na5 Ti16 O32
# O- Ca8 Be4 Al4 Si18 O56
# Ti3+ Li8 Ti15 O32
# O- Sr10 P6 O26
# Ti3+ Na8 Ti24 O48
# V4+ Ho4 V4 O14
# O- Ca10 P6 O26
# Nb4+ K1 La1 Ti1 Nb1 O6
# Tb4+ Ba16 Tb8 Nb5 Sn3 O48
# Ti3+ Li6 Mg6 Ti12 O32
# Ti3+ Li2 Y14 Ti14 S14 O35
# Cu+ Mg4 Al9 Cu1 Si9 O36
# Nb4+ Li2 Nb1 F6
# Ti3+ Li13 Ti22 O48
# Ti3+ Li7 Ti16 O32
# Ta4+ Na1 Sr2 Ta3 O9
# Ta4+ Ta4 Ti2 O12
# V3+ Sr4 La4 V4 O16
# Ti3+ Li7 Ti11 O24
# Ta4.875+ K6 Ta16 O42
# O- Ca8 Y4 Be4 O20
# Ti3+ Li5 Mg1 Ti12 O24
# Ti3+ Li14 Ti21 O48
# Ti3+ Li4 Ti8 O16
# V3+ Li2 V2 F8
# Ti3+ Li12 Ti18 O40
# V3+ V2 F6
# Nb4+ Sr4 Nb5 O15
# Fe4+ Sr12 Ti6 Fe2 O28
# V4+ La11 V12 O36
# V3+ Na4 Ca34 V4 P28 O112
# Ti3+ Sm4 Ti4 S4 O9
# O- Ca4 Be4 P4 O17 F3
# Ti3+ Li3 Mg1 Ti8 O16
# Ta4+ Ba2 Ta15 O32
# Nb4.28571429+ Sr6 Nb7 O21
# Ti3+ Mg6 Ti12 O24
# V3+ Li4 V2 F10
# Ti3+ Na3 Ti8 O16
# V3+ Ba4 V4 Zn2 Cu2 F28
# Nb4+ Ba8 Nb7 O24
# V3+ Li12 V4 F24
# V3+ Li2 V4 F14
# La2+ La1 O1
# Ta4+ La8 Ta12 Se8 O32
# V3+ Ca6 V4 Si8 O28
# Fe4+ Ca4 Ti3 Fe1 O12
# V3+ Na2 V6 F20
# Cu3+ Ba4 Ca4 Cu4 F28
# Ti3.75+ Li1 Y4 Ti4 S4 O10
# Ta4+ Sm4 Ta6 S4 O16
# Co4+ La4 Co1 O8
# Nb4+ Sr6 Nb10 O30
# Ti3+ Na13 Ti24 O54
# Ta4.91666667+ Li10 Ta24 O64
# O- Ca8 Be5 Al3 Si18 H4 O56
# Nb4+ Ba9 Nb10 O30
# V3+ Li4 V1 F7
# Nb4+ Sr14 Nb19 O57
# Co4+ Sr1 Li4 La15 Co4 O32
# Nb4+ Ba13 Nb14 O42
# Mo3+ Ba4 Mg2 Cu2 Mo4 F28
# Ti3+ Li9 Ti12 Nb1 O30
# Nb4+ Sr4 Nb4 O12
# Nb4+ Ti1 Nb1 O4
# V3+ Ca8 Al4 V4 O20
# Ni3+ Ba4 Mg4 Ni4 F28
# Nb4+ Ba8 Li1 Nb7 O24
# Yb2+ Yb1 Nb1 O3
# V3.25+ Li22 V8 F48
# Ti2+ Ti3 O4
# O- Ca8 Be6 Al2 Si18 H4 O56
# Co4+ Sr2 Li6 La22 Co6 O48
# V3+ Sr1 Nd1 V1 O4
# Ta4+ Nd8 Ta12 Se8 O32
# V3+ Sr1 Pr1 V1 O4
# O- Ca8 Pr4 Be4 O20
# Co4+ Sr1 Li1 La15 Co4 O32
# O- Sr8 La4 Be4 O20
# V3+ Li5 V1 F8
# Ti3+ Li5 Ti8 O16
# Ti3+ Li7 Ti12 O24
# Ta4.75+ Na3 Sr1 Ta4 O12
# V3+ Na8 V4 F20
# V4+ Li6 V3 F18
# O- Sr8 Sm4 Be4 O20
# Mo3+ Ba4 Zn4 Mo4 F28
# La2+ Sr3 Li4 La5 O12
# V2+ Ca2 V2 Si4 O12
# Ti2+ Ti10 O13
# Cu3+ Li6 La28 Cu8 O56
# Cu3+ Li1 La4 Cu1 O8
# Ta4+ K2 Ta15 O32
# Ce2+ Ce1 Pr1 O2
# Tb4+ Ba2 Sr2 Tb2 W2 O12
# V4+ Ba1 Sr7 V8 Si16 O56
# V3+ V8 O2 F22
# Nb4+ Li8 La4 Ti1 Nb7 O28
# Ta4+ Na8 Sr2 Ta10 O30
# Ti3.5+ Na2 Ti4 O8
# O- Sr8 Nd4 Be4 O20
# Ti3+ Li8 Ti8 Si16 O48
# Cu3+ Li4 La28 Cu8 O56
# Ta4+ Ce8 Ta12 Se8 O32
# V2.5+ Li8 V4 F18
# Co4+ Sr1 Li1 La7 Co2 O16
# V3+ Li4 V3 O1 F11
# V3+ Li2 V8 O2 F22
# V3+ K2 Li1 V1 F6
# V3+ Ca2 Ho2 V4 O12
# V3+ Li12 V4 O2 F22
# V3+ Ba8 Nb4 V4 O24
# Ti3+ Ba1 Na4 Ti2 Si12 O30
# La2+ La2 Ti8 Mn6 O24
# Ti3+ Li4 Ti6 O12
# V2+ Mg8 Ta8 V4 O32
# O- K2 Na2 Ca4 Mg15 Si24 O72
# V2+ Li8 V8 F28
# V2+ Li8 Ti12 V4 O32
# V4+ Ca1 Ce3 V4 O16
# O- K8 Nd3 Si12 O33
# V4+ Ca4 V4 Si4 O20
# V4+ Sr1 Ce3 V4 O16
# Nb4+ Ta8 Nb12 O48
# Ti3+ Na7 Ti11 O24
# Nb4+ Sr3 Li2 Nb4 O13
# Ti3.5+ Li1 Y2 Ti2 S2 O5
# Cu3+ Ba4 Mg4 Cu4 F28
# V2+ Na16 V16 F56
# V3+ V4 F14
# Nb4+ K1 Ba2 Nb3 O9
# Ti2+ Ti11 O14
# V3+ Sr1 Eu1 Nb1 V1 O6
# Nb4+ Li7 Ca8 Nb12 O40
# V4+ Li2 V2 F10
# Fe4+ Sr1 Li1 La3 Fe1 O8
# Ti3+ Ti6 Pb10 F38
# Ti3+ Mg8 Ti4 B4 O20
# Ti3+ Na7 Ti13 O26
# V4+ Mg1 V2 O2 F6
# Nb4+ La8 Nb12 S8 O32
# V3+ Na12 Mn6 V6 F42
# Mo3+ Ca4 Ta2 Mo2 O12
# Nb4+ Sr2 Li2 Nb3 O10
# O- K1 Na1 Ca1 Mg5 Si8 O24
# V3+ Tb4 V2 Fe2 O12
# Ti3+ La4 Ti5 Te3 O24
# V2+ Li8 V4 F16
# V4+ La2 V1 Zn1 O6
# V3+ Er4 V2 Fe2 O12
# Fe4+ Eu2 Hf1 Fe1 O6
# Ti3+ Li7 Ti7 O16
# V4+ Sr4 V2 P4 O18
# Cu3+ Li1 La8 Cu3 O16
# V3+ Ho4 V2 Fe2 O12
# Cr2+ Mg4 Ta4 Cr2 O16
# Cr2+ Ca4 Cr4 Si8 O24
# Ti3+ Ti6 N2 O8
# Mo3+ Ca12 Si12 Mo8 O48
# V3+ Li4 Ti8 V4 O24
# Cr2+ Li8 Ti12 Cr4 O32
# Fe4+ Li3 La7 Fe2 O16
# W3+ Ba4 Zn4 W4 F28
# V3+ La4 V2 Fe2 O12
# V3+ Li2 V4 O2 F10
# V4+ Ca2 La2 V2 Cr2 O12
# Ti3+ Li3 Ti4 O8
# V2+ Sr2 Ca2 V2 P4 O16
# Yb2+ Yb2 B8 O14
# Pr2+ Ca2 Pr2 V4 O12
# Ti3+ Ti34 N12 O48
# V4+ Li10 V4 O2 F22
# Cr2+ Mg4 Cr4 Si16 O40
# V3+ Li2 V6 O4 F12
# Nb3+ Ba6 Zr2 Nb10 O24
# V4+ Li8 V4 Si24 O60
# Cu3+ Sr6 La3 Ti3 Cu3 O20
# Cu+ Zr8 Mn1 Cu2 P12 O48
# V2+ Li2 V2 F6
# V3+ V6 O3 F15
# Cr2+ Ta8 Cr4 O24
# V4+ Li12 V8 F48
# V4+ Li12 V4 O4 F20
# V3+ Na1 Mg2 Al6 V1 Si6 B3 H3 O31
# Pr2+ Ba2 Sr2 Pr2 W2 O12
# V3+ Ta2 V2 O8
# Ti3+ Ti6 P6 O26
# Ti3.5+ Mg2 Ti4 P6 O24
# Cu3+ Ba4 Ca1 Fe4 Cu2 F28
# V4+ Ba2 V1 Cu2 F12
# Ti3+ Li1 Mg30 Ti1 O32
# V3+ Gd4 V2 Fe2 O12
# Nb4+ K1 Eu1 Nb2 O6
# Cr2+ Sr2 Ca2 Cr2 P4 O16
# Nb4.5+ Na1 Sr1 Nb2 O6
# V3+ Sm4 V2 Fe2 O12
# V4+ Li4 V2 O2 F8
# V4+ K8 Na4 V4 O4 F20
# Nb4+ Nb4 O6 F4
# Cr2+ Li8 Cr2 F12
# V3+ Li12 V4 Si24 O60
# Ta3+ Na3 Ta12 O24
# V3+ Li8 Y6 V2 O16
# Fe4+ Na8 Ti3 Fe1 Si16 O44
# Ti3+ Sr4 Li4 Ti12 Cr8 O44
# Ti3+ Na1 Mg30 Ti1 O32
# V4+ Li4 V8 F36
# V4+ K8 V4 O4 F16
# Ti3+ Li1 Mg14 Ti1 O16
# V2+ Ca1 Mg30 V1 O32
# V4+ Ca20 V12 O48
# Ag3+ Ba4 Ca4 Ag4 F28
# Ti2+ Ca1 Mg30 Ti1 O32
# V2+ Mg8 V8 Si16 O48
# Nb4+ Na1 Eu1 Nb2 O6
# O- Li1 Nd14 Cu6 O28
# Fe4+ Ca4 La8 Fe4 O24
# V4+ Eu3 V2 O7
# Mo3+ La2 Cr1 Mo1 O6
# Fe4+ La4 Mg2 Fe2 O12
# Ni3+ La12 Ni6 O25
# Cr2+ Ca1 Mg30 Cr1 O32
# V4+ Yb2 Mg1 V2 O8
# O- Ca8 Eu4 Be4 O20
# V3+ Li4 Ti5 V3 O16
# V4+ V2 F8
# Mo3+ K2 Li1 Mo1 F6
# V2+ Ti2 V2 O6
# Ti3+ Li4 Ti8 P8 O36
# V2+ Na4 V4 F12
# V4+ Ca6 V4 O14
# Ti3+ K4 Li5 Ti8 P8 O40
# V3+ Ca2 Ti2 V2 P6 O24
# Ti3+ Li1 Mg6 Ti1 O8
# Co+ Mg30 Al1 Co1 O32
# V3+ Pr4 V2 Fe2 O12
# Cu+ Mg30 Al1 Cu1 O32
# Co+ Y1 Mg30 Co1 O32
# Nb3+ Sr4 Nb8 O16
# V3+ Li8 V4 O4 F12
# Ti2+ Mg30 Ti1 V1 O32
# V4+ Li2 V16 F66
# Cu+ Y1 Mg30 Cu1 O32
# Ni+ Mg30 Al1 Ni1 O32
# V2+ Mg30 Mn1 V1 O32
# V2+ Sr1 Mg30 V1 O32
# Ti3+ K7 Ti8 P12 O48
# Ti2+ Mg30 Ti1 Mn1 O32
# V3+ Li2 V2 Cd2 F12
# Cr2+ Mg8 Cr8 Si16 O48
# V4+ Li2 V6 O2 F22
# Fe+ Mg30 Al1 Fe1 O32
# Ti3+ Na1 Mg14 Ti1 O16
# V2+ Mg30 V1 Zn1 O32
# V4+ Li2 V2 O2 F6
# V3+ V6 O4 F12
# Cr2+ Mg30 V1 Cr1 O32
# V3+ Sr16 V8 O31
# Fe4+ Sr4 Hf2 Fe2 O12
# V3+ Li8 V8 Si16 O48
# V2+ Ca1 Mg14 V1 O16
# Cr2+ Mg30 Mn1 Cr1 O32
# Ti3+ Li1 Ti4 Mn1 P6 O24
# Ti3+ Li4 Ti4 O8
# V2+ Sr2 Mg2 V2 P4 O16
# V2+ Mg30 V1 Fe1 O32
# Ti3+ Li6 Ti12 Zn6 O32
# Nb4+ Na2 Zr2 Nb2 P6 O24
# W3+ Li1 Mg30 W1 O32
# V4+ Ti4 V4 O16
# Nb4+ Ca3 Nb12 O24
# V4+ Eu4 V4 O12
# Cr2+ Mg30 Zn1 Cr1 O32
# Ti3+ Li7 Ti5 O12
# V2+ Mg30 V1 Ni1 O32
# V3+ Li4 V4 O4 F8
# O- Sr10 V6 O26
# V2+ Mg30 V1 Co1 O32
# V4+ Li5 V6 O5 F19
# V3+ Al4 V4 O12
# Ni3+ La15 Ni8 O32
# Pr4+ Pr8 Se6 O20 F12
# Cr2+ Mg30 Cr1 Fe1 O32
# Ti3.66666667+ Li5 Ti3 O8
# V2+ Mg30 V1 Cd1 O32
# V3+ V8 O6 F18
# O- Sr8 Eu4 Be4 O20
# V3+ V8 Pb8 F40
# Cr2+ Mg30 Cr1 Ni1 O32
# Cr2+ Mg30 Cr1 Co1 O32
# V2+ Mg30 V1 Cu1 O32
# Mo3+ Ca4 Al2 Mo2 O10
# W3+ Na1 Mg30 W1 O32
# Cr2+ Li4 Ti5 Cr3 O16
# O- Ca10 V6 O26
# V2+ Mg4 Nb4 V2 O16
# V4+ Li9 V8 F48
# Cr2+ Li6 Ti7 Cr5 O24
# Ti3+ Ti12 Mn5 P18 O72
# V3+ Sr16 V12 O39
# V3+ Sr20 V15 O49
# Mo3+ Sr2 La2 Cr3 Mo1 O12
# Nb3+ Ba4 Zr1 Nb9 O18
# Cr2+ Sr2 Mg2 Cr2 P4 O16
# Nb4+ K4 Ba1 Nb5 O15
# V3+ Li4 Ti4 V4 O16
# V2+ Mg1 Nb4 V1 O12
# Cr2+ Li4 Cr2 Si8 O20
# Bi4+ Ta12 Bi4 O38
# V3+ Ti4 V2 P6 O24
# Co4+ Ca2 La4 Co2 O12
# Cr2+ K2 Cr2 F6
# V4+ Eu2 Mg1 V2 O8
# Ti3+ Li7 Ti12 Fe5 O32
# V3+ Ba6 V8 P12 O48
# V4+ Ca4 V4 O12
# Cu+ Ba2 Ca2 Nd1 Ti2 Cu2 O12
# Nb4+ Ca9 Nb2 Ga10 Si6 O42
# Cu+ Mg30 Fe1 Cu1 O32
# V2+ Li4 V4 Si10 O26
# Ti3+ Ti4 Mn2 P6 O24
# Fe4+ K4 Mg8 Al4 Fe4 Si12 O48
# V4+ Sr1 Ca3 V4 O12
# O- Ba4 La4 Ti4 Cu4 O24
# Nb4+ K14 Nb28 P18 O120
# Bi5+ Sr4 Ce2 Bi2 O12
# V3+ Ba4 Y2 V6 O16
# Ti3+ Ba4 Ti1 Nb9 O18
# Ag3+ Ba4 Mg4 Ag4 F28
# Fe4+ Ca1 Fe1 F6
# Nb4+ K12 Nb22 O60
# V2+ Mg14 Mn1 V1 O16
# V3+ V2 Zn2 F10
# Mo3+ Ca2 Ti2 Mo2 P6 O24
# V2+ Ca4 V4 P8 O28
# Nb3+ Ba8 Zr1 Nb19 O36
# Cr2+ Li4 Cr4 Si10 O26
# Ti3+ Na1 Ti2 P4 O14
# Mo3+ Cr1 Mo1 F6
# V4+ Sr6 Ca2 V8 O24
# Bi5+ Ba2 Sr2 Ce2 Bi2 O12
# Tb4+ Ca1 Tb3 Mn4 O12
# V3+ Sr8 V6 O19
# Nb4+ La3 Nb1 Ga5 O14
# Nb4+ Ti1 Nb3 P6 O24
# La2+ Ca2 La2 Cr4 O12
# Tb4+ Ba2 Tb1 Sn1 O6
# Cr2+ Mg4 Nb4 Cr2 O16
# V4+ Li4 V3 O4 F8
# V3+ Mg2 Ti2 V2 P6 O24
# V2+ Mg14 V1 Zn1 O16
# V3+ V6 Pb10 F38
# Bi5+ Ba4 Ce2 Bi2 O12
# V4+ V6 O2 F22
# Nb4+ Nb8 O16
# Cr2+ Sr4 Cr4 P8 O28
# Tb4+ Ba4 Sr4 Tb4 Sn4 O24
# Mo3+ Y4 Mo4 O12
# Cr2+ Mg14 V1 Cr1 O16
# Ni3+ Ca4 Ni4 F20
# V3+ V2 Si2 O7
# V4+ Ba6 V2 O10
# Cr2+ Mg14 Mn1 Cr1 O16
# V4+ Li2 V6 O6 F14
# Nb4+ K4 Nb12 P12 O60
# Cu3+ Ba4 Ca2 Cu6 F28
# Yb2+ Yb2 Cl4
# V4+ Ca2 La2 V2 Fe2 O12
# Ti3.66666667+ Li4 Ti12 Zn8 O32
# V2+ Mg14 V1 Fe1 O16
# V3+ Mg1 V2 P2 O8 F2
# Bi5+ Ba1 Sr3 Lu2 Bi2 O12
# Yb2+ Yb4 V4 O8
# Fe4+ Sr8 Ti4 Fe4 O24
# Ni3+ Sr1 La3 Ni2 O8
# V3+ Li16 V8 Si16 O52
# V4+ Dy6 V2 H6 O16
# Nb4+ K4 Li3 Nb18 P12 W2 O84
# V2+ Li4 Ti3 Nb2 V3 O16
# Cr2+ Mg14 Zn1 Cr1 O16
# V4+ Mg1 V6 O5 F19
# Bi5+ Sr4 Er2 Bi2 O12
# Ni3+ Sr2 Pr2 Cr1 Ni1 O8
# V2+ Ti3 V3 P6 O24
# W3+ Ca2 Ti2 P6 W2 O24
# Bi5+ Ba2 Sr2 Lu2 Bi2 O12
# Bi5+ Sr4 Ho2 Bi2 O12
# Bi5+ Ba4 Sr2 Lu3 Bi3 O18
# Cu3+ Ba10 Sr4 Nd16 Cu10 O50
# V2+ Mg14 V1 Ni1 O16
# Nb4+ La2 Nb16 O28
# Bi5+ Ba2 Lu1 Bi1 O6
# Ti3+ Li6 Ti12 Co6 O32
# V2+ Mg14 V1 Co1 O16
# Sm2+ Sr1 Sm3 Mn4 O12
# V2+ Ti3 Mn2 V1 P6 O24
# Nb4+ Ba4 Nb32 O56
# Bi5+ Sr4 Dy2 Bi2 O12
# V4+ Ca2 V3 O8
# V2+ Ti3 Mn1 V2 P6 O24
# Ti3+ Ti4 Cr2 P6 O24
# Ti3+ Na11 Ti1 Nb2 Si4 P2 O24 F2
# Cr2+ Mg14 Cr1 Fe1 O16
# Ti3+ Ti3 V2 Cr1 P6 O24
# Ti3+ Ti3 Nb1 V2 P6 O24
# Ti3+ Li4 Ti3 V1 O8
# V4+ Ba10 V10 O28
# V4+ V6 O6 F12
# Nb4.66666667+ K3 Li2 Nb6 P3 O24
# V3+ Li12 Al8 V4 O24
# Cr2+ Li4 Cr4 Si8 O22
# Nb4+ Li13 Nb14 Zn1 O42
# Nd2+ Ca1 Nd3 Mn4 O12
# Pr2+ Ca2 Pr2 Cr4 O12
# Ti3.5+ Ti4 Zn2 P6 O24
# Ti3+ Ti3 Mn2 Cr1 P6 O24
# Ti3+ Ti4 Fe2 P6 O24
# Ti3+ Ti4 Sn2 P6 O24
# Bi5+ Ba3 Sr1 Lu2 Bi2 O12
# Ti3+ Ti3 Mn2 Nb1 P6 O24
# Ta4+ Ta8 Pb6 O25
# V3+ Li6 V2 Fe2 P4 O16 F4
# O- Sr4 Ce1 Sm3 Nb2 Cu4 O20
# V3+ K8 V8 P8 O32 F8
# Bi5+ Sr2 Ca2 Tb2 Bi2 O12
# O- Sr6 Ce2 Y4 Fe3 Cu3 O24
# Nb4+ Nb4 P6 O24
# Bi5+ Sr2 Ca2 Y2 Bi2 O12
# V3+ Nb3 V1 P6 O24
# Bi5+ Sr2 Ca2 La2 Bi2 O12
# V3+ V4 O4 F4
# Ti3+ Na5 Li4 Ti5 O14
# Cu+ Li6 Ta10 Cu4 O30
# V3+ Mg1 V1 Cr1 P2 O8 F2
# Co4+ La4 Mg2 Co2 O12
# Cr2+ Ca4 Cr4 P8 O28
# O- Sr4 Ce1 Nd3 Nb2 Cu4 O20
# V3+ K6 V4 P4 O16 F6
# V3+ Li4 V4 Si4 O16
# Bi5+ Sr1 Ca1 Dy1 Bi1 O6
# V4+ Li8 V4 O8 F8
# V3+ Li18 V6 Si12 O42
# Mo3+ Mg1 Si4 Mo2 O12
# V2+ Ti3 V2 Fe1 P6 O24
# Bi5+ Ba8 Dy4 Bi4 O24
# Ni3+ Ba1 La3 Ni2 O8
# Nb2+ Eu2 Nb5 O9
# Yb2+ Yb10 Er2 Cl26
# Bi5+ Ba4 Sr4 Dy4 Bi4 O24
# Bi5+ Sr4 Gd2 Bi2 O12
# Cu+ Sr4 Ce1 Pr3 Nb2 Cu4 O20
# V3+ Eu4 V4 O10
# Bi5+ Sr2 Ca2 Gd2 Bi2 O12
# V3+ Mg4 V4 P4 O20
# V3+ Mg3 V4 P6 O24
# V3+ Na12 V8 P8 O32 F12
# Mo3+ Li1 Sm4 Mo4 O14
# Bi5+ Ba8 Tb4 Bi4 O24
# Bi5+ Ba4 Sr4 Tb4 Bi4 O24
# V3+ Nb4 V4 O16
# Cu+ Ta8 Cu4 O22
# Bi5+ Sr8 Tb4 Bi4 O24
# Bi5+ Ba8 Y4 Bi4 O24
# V3+ Ca2 V6 P6 O26
# V4+ V1 Zn1 F6
# Bi5+ Ba4 Sr4 Y4 Bi4 O24
# V3+ Li4 Ti4 V6 O20
# Bi5+ Sr8 Y4 Bi4 O24
# Mo3+ Mg2 Ti2 Mo2 P6 O24
# V4+ Sr4 V6 O18
# Bi5+ Sr4 Sm2 Bi2 O12
# Cu+ Ba4 Y1 Cu1 W2 O12
# V2+ Ti3 V2 Ni1 P6 O24
# Cu3+ Sr1 La3 Cu2 O8
# Ni4+ La2 Mg1 Ni1 O6
# Ni3+ Sr1 Nd3 Ni2 O8
# Bi5+ Ba2 Ca2 Dy2 Bi2 O12
# Ga4+ La12 Ga23 W1 O56
# Ti3+ La16 Ti8 Se20 O16
# Nb4.25+ Na1 Nb4 P6 O24
# V2+ Ca4 V2 W2 O12
# V3+ Ca4 V8 P12 O48
# Ni3+ Ba4 Zn4 Ni4 F28
# Bi5+ Sr4 La2 Bi2 O12
# Bi5+ Sr2 Ca2 Sm2 Bi2 O12
# Mo3+ La12 Si4 Mo16 O56
# V2+ Ti3 V1 Sn2 P6 O24
# O- Na8 Pr4 Si4 O20
# Nb4+ Li3 Nb4 V1 O12
# Nd2+ Sr2 Nd1 Mn2 O7
# V4+ Li4 Al4 V4 O16
# V2+ V4 Si4 O12
# Bi5+ Ba2 Sr2 Gd2 Bi2 O12
# Bi5+ Ba4 Ca4 Tb4 Bi4 O24
# V4+ Li8 Ti4 V4 O20
# W2+ Ti3 V2 P6 W1 O24
# Cu+ Ti4 Cu2 P6 O24
# V3+ Li8 V8 P8 O32 F8
# V4+ Li1 V4 O5 F7
# Ga4+ La12 Ga23 Mo1 O56
# Cu+ Mg14 Fe1 Cu1 O16
# Cr2+ Ti3 V1 Cr2 P6 O24
# Pr2+ Pr7 Mn8 O24
# V3+ Li6 Ti4 V6 O20
# Bi5+ Ba8 Gd4 Bi4 O24
# Sm2+ Ba17 Sr1 Sm12 Cl68
# V2+ Ca2 V2 P8 O24
# V4+ Mg1 Mn1 V1 P2 O8 F2
# Ni+ Ti4 Ni2 P6 O24
# W2+ Ti3 Mn2 P6 W1 O24
# Cu3+ Ba4 Mg2 Cu6 F28
# V3+ Li6 V3 Cr3 P6 O24 F6
# Nb4+ Li3 Mn1 Nb4 O12
# V3+ Mg8 V5 O16
# Nb2+ Ba1 Nb5 O8
# V2+ Ti3 V1 Fe2 P6 O24
# V2+ Ti3 V2 Co1 P6 O24
# V2+ Ca4 V8 P8 O32
# Bi5+ Ba2 Sr2 La2 Bi2 O12
# Tb4+ Ba1 Tb1 Mn2 O5
# Ti3+ Ti3 Cr3 P6 O24
# Bi5+ Ca8 Y4 Bi4 O24
# V2+ Mg4 V4 P8 O28
# V2+ Sr2 V1 W1 O6
# V3+ Na8 V8 P8 O32 F8
# Ho2+ Ca2 Ho2 Mn4 O12
# Cr2+ Ca4 Cr2 W2 O12
# V3+ Ca4 V8 O16
# Ta4+ Ta7 P16 O56
# Ti3+ Ti3 Cr1 Sn2 P6 O24
# Bi5+ Ba2 Ca2 Gd2 Bi2 O12
# Ti3+ Ti3 Cr1 Fe2 P6 O24
# V4+ Sr2 V4 P4 O20
# V2+ Mg3 V1 O4
# Bi5+ Ba8 Sm4 Bi4 O24
# V3+ Na1 Mg3 V3 Cr3 Si6 B3 H3 O31
# Bi5+ Ba4 Sr4 Sm4 Bi4 O24
# Bi5+ Ba4 Ca4 La4 Bi4 O24
# Tb4+ Ca2 Tb2 Mn4 O12
# Cr2+ Li8 Cr12 Si16 O48
# W3+ Nb3 P6 W1 O24
# Ag2+ Zr2 Ag3 F14
# Ni3+ Ca12 Si12 Ni8 O48
# Bi5+ Ba8 La4 Bi4 O24
# V3+ Li4 Ti3 V3 Cr2 O16
# Nb4+ Li4 Nb8 P12 O48
# O- Na11 Ti1 Nb2 Si4 P2 O26
# V4+ Ca2 V4 P4 O20
# W3+ Mg2 Ti2 P6 W2 O24
# V4+ Li16 V4 P8 O32 F8
# V4+ Mg2 V2 O6
# Mo3+ Ca2 Ho2 Mo4 O12
# Bi5+ Sr4 Pr2 Bi2 O12
# Nb4.66666667+ Nb3 Pb2 O8 F4
# Cr2+ Ti3 Cr2 Fe1 P6 O24
# Bi5+ Ba2 Ca2 Sm2 Bi2 O12
# V4+ Li8 V8 Si8 O36
# V2+ Mg6 Mn1 V1 O8
# Co4+ Li2 Ti3 Co1 P6 O24
# Bi5+ Ba2 Sr2 Nd2 Bi2 O12
# Cu3+ Ca2 Cu2 F10
# Cu3+ Li5 Cu1 F8
# V3+ Li4 Ti3 V2 Cr3 O16
# V2+ Li4 V8 Si8 O26
# Cr2+ Sr4 Cr2 W2 O12
# O- Sr6 Mg1 Mo3 O14
# Nb3.5+ Li2 Nb20 O36
# Yb2+ Yb1 Ge1 O3
# Ti3+ Ti2 P6 W2 O24
# V3+ Al2 V4 O8
# Cu+ Nb16 Cu4 O42
# Yb2+ Yb2 Mo2 O8
# V4+ V4 O5 F7
# V3+ Li12 Al6 V6 O24
# V2+ Sr1 Eu1 V1 W1 O6
# V3+ V6 O7 F5
# Cr2+ Mg2 Cr2 P4 O14
# V3+ Li4 Mn2 V2 P4 O16 F4
# Cr2+ Ca2 Cr2 P8 O24
# Pr2+ Ca9 Pr11 Mn20 O60
# Nb4+ Li3 Nb4 Zn1 O12
# Ti3+ Ba6 Ti7 Sb9 O42
# Ni3+ La4 Ga2 Ni2 O12
# Cu+ Ho2 Cu2 O4
# V4+ Ca2 V4 O10
# Ti3+ Sr3 Ti3 Ga8 O20
# V3+ Li6 Mn2 V2 P4 O16 F4
# Cu+ Cu17 O96 Ta32
# Bi5+ Ba8 Nd4 Bi4 O24
# Ni3+ Ca2 Ti2 Ni2 P6 O24
# Cu+ Ta24 Cu13 O72
# V3+ Sr4 V2 Mo2 O12
# Ti3+ Li4 Ti4 P16 O48
# Nb4+ Nb8 P15 O56
# Ti3+ Na22 Ti20 O42
# V2+ Ca2 V6 P8 O28
# Ni3+ La10 Fe8 Ni2 O30
# Nb4+ K5 Na3 Nb7 W1 O24
# Ti3+ Na4 Ti4 O8
# Nb4+ Li9 Nb10 Cr6 P24 O96
# Ni3+ Ba1 Pr3 Ni2 O8
# Bi5+ Ba2 Pr1 Bi1 O6
# Ho2+ Sr2 Ho2 Mn4 O12
# V2+ Li6 Ti3 V3 O12
# Ni4+ Li2 Ti3 Ni1 P6 O24
# V2+ Sr2 V2 Zn2 P4 O16
# Bi5+ Sr8 Nd4 Bi4 O24
# V2+ Ti3 V1 Ni2 P6 O24
# Bi5+ Ba2 Ca2 Nd2 Bi2 O12
# Ti3+ Ti3 Cr1 Co2 P6 O24
# V2+ Li16 V8 P8 O32 F8
# Cu3+ Ba4 Zn4 Cu4 F28
# V3+ Li8 V4 B20 O40
# Ni3+ La4 Fe3 Ni1 O12
# Cu+ Ta16 Cu9 O48
# V2+ Li4 V6 Si6 O20
# Fe4+ Mg1 Fe1 F6
# V3+ Li6 V2 Si8 H4 O24
# Pr2+ Ca2 Pr2 Mn4 O12
# V3+ Li4 Ti2 V4 O12
# V4+ V6 O5 F19
# V3+ Li5 V1 Si2 O8
# Bi5+ Ba4 Sr4 Pr4 Bi4 O24
# V2+ Eu2 V1 W1 O6
# V3+ Li3 V1 Cr1 P2 O8 F2
# Co4+ Ca1 Co1 F6
# V3+ Li8 Ti4 V6 O20
# Fe4+ La2 Zn1 Fe1 O6
# V4+ Li4 Ti3 Mn2 V3 O16
# V2+ V4 Zn4 Si8 O24
# V4+ Li8 V4 Si4 O20
# Nb4+ Nb4 P8 O28
# Ti3+ Ti3 Cr1 Ni2 P6 O24
# V3+ Na4 V4 Si4 O16
# V3+ Mg1 V1 Fe1 P2 O8 F2
# Mo3+ Ca2 Pr2 Mo4 O12
# Bi5+ Ba2 Ca2 Pr2 Bi2 O12
# V3+ V12 Si4 P20 O76
# W2+ Ti3 Fe2 P6 W1 O24
# Pr2+ Sr2 Pr2 Mn4 O12
# V4+ Li2 V2 Cr2 P4 O16 F4
# V2+ Mg2 V2 P8 O24
# Cr2+ Li8 Cr4 Si6 O20
# V3+ Li16 V6 P16 O58
# V3+ Li12 V8 P12 O48
# V3+ Li4 Ti2 V6 O16
# Cu+ Li3 Nb4 Cu1 O12
# Ti3.66666667+ Na5 Ti3 O8
# Ni3+ Ca4 Al2 Ni2 O10
# V3+ Ti1 Mn2 V3 P6 O24
# V3+ Ti2 V2 Zn2 P6 O24
# Ta4.9+ Ba10 Ta10 N9 O21
# V2.8+ Ti1 V5 P6 O24
# Nb3.375+ Li2 Nb16 O28
# Ti2+ Ca4 Ti4 Ge8 O24
# V3+ Li4 V4 P8 O28
# Cu+ Ti3 V1 Cu2 P6 O24
# V3+ V6 O8 F4
# Nb3.41666667+ Li7 Nb12 O24
# Dy2+ Dy1 Mn2 O4
# Cr2+ Sr2 Zn2 Cr2 P4 O16
# Cr2+ Li6 Cr4 P4 O16 F4
# Cu3+ Ca2 Ti2 Cu2 P6 O24
# V3+ Li11 V8 P12 O48
# V3+ Li8 V4 O8 F4
# V3+ Li18 V6 P16 O58
# V3+ Na4 V4 P8 O28
# V4+ Ti2 V6 O16
# Yb2+ Yb8 Br12 O2
# V3+ Li6 V6 P8 O32
# V3+ Li10 V8 P12 O48
# V4+ Na3 Ca10 Mn7 V12 O48
# V4+ Li14 V12 O24 F24
# O- Sr1 La7 Cu4 Sn4 O24
# V3+ Li3 V1 P2 O8
# V3+ Ca1 V1 Fe1 P4 O14
# Nb3+ K5 Nb16 O20 F8
# V3+ Li10 V4 P10 O36
# V3+ Mg6 V12 O24
# V4+ Mg1 V2 P2 O10
# V4+ Li4 V4 O8 F4
# V3+ Li12 Mn1 V7 P12 O48
# V3+ Li6 V3 Cr3 P12 O42
# V3+ Li10 Ti4 V6 O20
# Ti3+ Ti10 Bi1 Pb9 O30
# V3+ Li15 V6 P16 O58
# V3+ Li4 Ti3 V3 Sn2 O16
# Fe4+ Ca1 Ti2 Fe2 P6 O24
# Ag3+ Ba4 Ca2 Cu2 Ag4 F28
# V4+ V2 P2 O8 F2
# V3+ Li6 Mn2 V2 P8 O28
# V3+ Li7 V4 P6 O24
# Nb3+ Li4 Nb28 O48
# V3+ Li6 V3 Fe1 P6 O24
# V3+ V4 P4 O16
# V3+ Li8 V8 P12 O48
# Fe4+ Sr3 Sm1 Fe2 O8
# Ni3+ Nb3 Ni1 P6 O24
# O- Sr3 Nd1 Fe2 O8
# V3+ Li14 V6 P16 O58
# V3+ Li4 V4 B8 O20
# Nb3+ K3 Nb8 O10 F4
# V3+ Li4 Mn1 V3 P8 O28
# Cr2+ Mg2 Cr2 P8 O24
# V2+ Ta8 V4 Zn8 O32
# V3+ Ca12 V8 Ge12 O48
# Nb3+ Na4 Nb8 O16
# V4+ Li2 V6 O10 F6
# Cr2+ Li16 Cr8 P8 O32 F8
# V3+ Li14 V8 P18 O64
# W2+ Ti3 Co2 P6 W1 O24
# V3+ Li7 V8 P12 O48
# V3+ Li12 Mn2 V6 P12 O48
# V3+ Sr2 Al1 V11 O22
# V3+ Li2 V4 P10 O32
# Ti3+ La12 Ti6 Se18 O10
# Cr2+ Mg2 Cr5 P6 O24
# V3+ Li8 V4 P6 O24
# Ni3+ Li12 Ni4 F24
# O- Nd4 O10
# Cu+ Ti3 Cu2 Sn1 P6 O24
# Yb2+ Yb2 Be2 N2 F12
# V3+ Na6 V4 P6 O24
# V3+ Li12 V4 Si4 O20
# V3+ Mg2 V2 Cr2 O8
# V4+ Mg4 V6 O16
# V3+ Li8 Mn2 V2 P6 O24
# Cu+ Ho5 Cu1 W8 O32
# V3+ Li2 V8 P14 O48
# V3+ Li2 V4 P6 O22
# V2+ Li14 V14 P12 O48 F6
# V3+ Na2 V6 P6 O26
# V3+ Li6 Ti2 V6 O16
# V3+ Li4 V4 P16 O48
# V2+ Li8 V4 P8 O28
# V4+ Li1 Mn1 V1 P2 O8 F2
# V3+ Li2 V6 P6 O26
# Cr2+ Ca2 Cr6 P8 O28
# V3+ Na4 V8 P8 O36
# V2+ Li4 Nb4 V4 O16
# V3+ Li4 V8 P8 O36
# V3+ V4 O6 F2
# V2+ Li3 V1 Cr1 P4 O14
# V3+ Li4 Ti3 V3 W2 O16
# Ni3+ Sr1 La1 Ni1 O4
# V3+ Li6 V3 Cr1 P6 O24
# Ni3+ Mg2 Ti2 Ni2 P6 O24
# Cr2+ Li4 Cr6 Si6 O20
# Cr2+ Cr6 B14 O26 F2
# Cu+ Ti3 Mn1 Cu2 P6 O24
# V4+ Na12 V8 P8 O40 F4
# V3+ Li12 Mn3 V5 P12 O48
# V3+ Li3 V4 P6 O24
# Ni3+ Mg2 Ni2 F10
# V3+ Li2 Mn1 V1 P4 O14
# Cu3+ Li4 Cu1 F7
# Cr2+ Li4 Ti3 Cr3 Sn2 O16
# Nb4+ K5 Na3 Nb6 W2 O24
# V4+ Li12 V6 P16 O58
# Ni3+ La4 Fe2 Ni2 O12
# V4+ Nb1 V3 P6 O24
# V3+ Mn2 Nb1 V3 P6 O24
# Cu+ Ti3 Fe1 Cu2 P6 O24
# Mo2+ Ca4 Mo2 W2 O12
# Tb4+ K4 Sr4 Tb4 Sb4 O24
# Cr2+ Li4 Cr10 Si8 O28
# Cr2+ Li4 Cr2 P4 O14
# V3+ Li6 Ti2 V4 O12
# V4+ Li8 V4 P8 O32
# V3+ Li4 Ti2 V3 Cr3 O16
# V4+ Ti1 V3 P6 O24
# V3+ Li2 V4 P4 O16
# V3+ V8 P14 O48
# Co4+ La4 Zn2 Co2 O12
# V4+ V6 O9 F9
# V4+ Li4 V8 P12 O48
# V4+ Li6 Mn2 V2 P6 O24
# V3+ K2 V6 P8 O32
# V3+ Li8 Ti6 V6 Sb4 O32
# Nb3.33333333+ Na8 Nb12 O24
# V2+ V10 P12 O44
# Ni4+ Sr5 La5 Cu1 Ni4 O20
# V3+ Li4 Ti3 V3 Fe2 O16
# V2+ Li16 V4 P8 O32
# Bi5+ K1 Sr1 Hf1 Bi1 O6
# Tb4+ Ca3 Tb1 Mn4 O12
# Yb2+ Ca1 Yb3 Mn4 O12
# V3+ Li4 Nb2 V6 O16
# Mo3+ Ca4 Mo8 P8 O36
# Cr2+ Ta8 Zn8 Cr4 O32
# V3+ Li4 V2 P10 O30
# V3+ Li9 V4 P6 O24
# V3+ K6 V4 P6 O24
# Ni3+ K2 Li1 Ni1 F6
# V4+ Li1 V1 Cr1 P4 O14
# Ni3+ La4 Mn1 Ni3 O12
# V3+ Li2 V6 P12 O40
# V2+ Li6 V4 P10 O32
# V3+ Li6 V2 Fe2 P8 O28
# V3+ Na8 V8 P12 O48
# V2+ Li8 V4 P16 O48
# V2+ Li4 V4 P4 O16
# Sm2+ Ca3 Sm1 Mn4 O12
# Mo3+ K2 Al1 Mo3 P8 O28
# V2+ Li4 V4 P12 O36
# V3+ Mg1 V1 Fe1 P4 O14
# Cr2+ Li4 Ti3 Cr3 W2 O16
# V4+ Li4 V4 P4 O20
# Ni3+ Sr1 Sm1 Ni1 O4
# V3+ Li6 V1 Cr3 P6 O24
# V2+ V8 Si4 O16
# V3+ V4 P12 O36
# V3.5+ V4 P10 O32
# V3.5+ V4 P6 O22
# V3+ Li8 Mn3 V1 P6 O24
# Ce2+ Sr3 Ce1 Mn4 O12
# V3+ Nb1 V3 O8
# Mo3+ Ti2 Zn2 Mo2 P6 O24
# V3+ Ti1 V3 Sn2 P6 O24
# V4+ K4 V6 P8 O34
# V3+ Ti1 V3 Fe2 P6 O24
# V4+ Ba2 V12 O22
# V2+ V7 P6 O24
# V2+ Li4 Mn2 V2 P4 O16
# V2+ Li4 Mn1 V3 P4 O16
# Ni3+ Li4 Ti5 Ni3 O16
# V2+ Li4 V6 P8 O28
# Bi5+ Sr4 Eu2 Bi2 O12
# Mo3+ Ho2 Mg2 Mo4 O12
# Cr2+ Li5 Cr3 P4 O16
# Cu3+ Sr1 La1 Cu1 O4
# V3+ Na10 V8 P12 O48
# Fe4+ Li4 Fe2 F12
# V2+ Li4 Mn3 V1 P4 O16
# Nd2+ Ca3 Nd1 Mn4 O12
# V2+ V6 P8 O28
# V3+ V6 P12 O40
# Pr2+ Pr3 Mn4 Pb1 O12
# Bi5+ K4 Ba4 Ce4 Bi4 O24
# V3+ Li4 V2 Fe2 P8 O28
# V3+ Li12 V4 B8 O24
# Ni3+ Sr1 Gd1 Ni1 O4
# Ni3+ Sr1 Nd1 Ni1 O4
# V4+ V2 P4 O14
# O- K8 Sn4 H4 O4 F24
# V4+ Li8 Ti2 V6 O20
# Cu3+ Mg2 Ti2 Cu2 P6 O24
# Cu+ Ti3 Cu2 Sb1 P6 O24
# V2+ Li2 V4 P6 O20
# Ni3+ K1 Na1 Ca1 Si8 Ni5 O24
# Cr2+ K1 Cr12 Si8 Cl1 O28
# Cr2+ Li8 Cr4 P6 O24
# Cr2+ Li16 Cr4 P8 O32
# Fe4+ Ca2 Fe4 F20
# V3+ Li4 V8 B4 O20
# V2.5+ V4 P6 O20
# Cr2+ K1 Cr12 Si8 Br1 O28
# Ag3+ Li5 Ag1 F8
# V3+ V12 B4 O24
# V4+ Li2 V2 Fe2 P4 O16 F4
# V3+ Na2 Nb14 V4 O28
# V4+ Li10 V6 P16 O58
# Cr2+ Na1 Cr12 Si8 Cl1 O28
# Cu3+ Ba4 Zn2 Cu6 F28
# V4+ Li4 V2 P8 O26
# V4+ Li6 V8 P18 O64
# Mo3+ Si6 Mo12 P18 O75
# V3+ Mn2 V4 P6 O24
# V4+ Na12 V4 Si4 B4 O28
# Bi5+ Zr4 Bi4 O16
# V3+ Sr2 V12 O22
# V2+ Mg4 V2 W2 O12
# V3+ Y2 V2 W4 O16
# V2+ Li16 V4 B8 O24
# Cr2+ Li4 Mn3 Cr1 P4 O16
# Cr2+ Li8 Cr4 P16 O48
# Cr2+ Na1 Cr12 Si8 Br1 O28
# Cr2+ Li6 Cr3 Si3 O12
# Ag3+ Ba4 Mg2 Cu2 Ag4 F28
# Cr2+ Mg4 Cr8 P8 O32
# V3+ Mn1 V3 P4 O16
# V3+ Li6 V3 Ni1 P6 O24
# V3+ Mn2 V3 Cr1 P6 O24
# V4+ Na4 V8 P12 O48
# V3+ Li4 Ti1 V3 O8
# Bi5+ K4 Sr4 Ce4 Bi4 O24
# Bi5+ Ba2 Sr2 Eu2 Bi2 O12
# V3+ Li4 V10 B6 O26
# Cu3+ K2 Li1 Cu1 F6
# Cu3+ Li18 Cu6 F36
# Nb4+ Nb8 Pb6 O25
# Nb4+ Nb4 P16 O48
# Bi5+ K4 Ca4 Ce4 Bi4 O24
# V3.75+ V24 P18 O90
# V3+ Li12 Mn6 V2 P12 O48
# Cr2+ Li6 Cr4 P10 O32
# V2+ Li8 V10 P12 O44
# Pr2+ Sr3 Pr1 Mn4 O12
# Bi5+ Ba8 Eu4 Bi4 O24
# V4+ Mg1 V8 P12 O48
# V3+ V6 O10 F2
# V2+ V4 P2 O10
# Bi4+ La4 Bi4 O14
# V3+ Li4 Nb2 V3 Cr3 O16
# Bi5+ K4 Sr4 Zr4 Bi4 O24
# V4+ Na4 V4 P4 O20
# Cu+ Ti3 Cu2 Te1 P6 O24
# Cr2+ Li4 Cr4 P12 O36
# V4+ Li4 V4 B4 O16
# Ni3+ Nd4 Mn1 Ni3 O12
# Cr2+ Li4 Mn2 Cr2 P4 O16
# V2.16666667+ V12 P14 O48
# V4+ Li4 Mn2 V2 P6 O24
# V3+ Li6 V4 P8 H4 O32
# V2+ Li2 V12 P14 O48
# V4+ V6 P8 O32
# Ni3+ Sr2 Ni1 O3 F1
# V4+ Li2 Mn2 V2 P8 O28
# Mo3+ Li6 Mo2 P4 O16
# V4+ Li9 V6 P16 O58
# V4+ Ba2 V20 O34
# Fe4+ Y4 Fe4 O14
# V2+ V4 P4 O14
# Cr2+ Li14 Cr14 P12 O48 F6
# Bi5+ Na4 Sr4 Ce4 Bi4 O24
# Nb4+ K5 Na3 Nb5 W3 O24
# V3+ Na12 V4 B4 P4 O28
# Nb2+ Ba2 Nb8 O11
# V3+ Ba6 V4 P12 H12 O48
# Nb4.66666667+ Li4 Nb3 Te1 O12
# O- Sr4 Ce1 Y3 Fe2 Cu4 O18
# Bi5+ Ba2 Ca2 Eu2 Bi2 O12
# Bi5+ Ba4 Na4 Ce4 Bi4 O24
# V4+ Mg1 V4 P4 O20
# V3+ Li8 V4 P8 H4 O32
# Nb2+ K4 Nb15 O24
# V4+ Mn3 V3 P6 O24
# W3+ Li18 P16 W6 O58
# V4+ Li8 V6 P16 O58
# Cr2+ Li4 Mn1 Cr3 P4 O16
# V3+ Li12 Mn7 V1 P12 O48
# V3+ Mn2 V3 Sn1 P6 O24
# Ni3+ K3 Ni1 F6
# V4+ V3 P6 W1 O24
# Ni4+ Ca1 Ni1 F6
# V4+ K12 V12 P12 O62
# Mo3+ Li4 Mo4 P16 O48
# V3+ Li6 V6 B4 O20
# V4+ Sr1 V4 O10
# V3+ Li5 Ti2 V5 O12
# V3+ V8 P6 O24
# V2.93333333+ Ti1 V15 O24
# Mo3+ Li4 Mo2 P10 O30
# Co4+ La2 Co1 Ni1 O6
# Mo3+ Ca12 Ge12 Mo8 O48
# V3+ Mn2 V3 P6 W1 O24
# Mo3+ Li4 Mo4 P8 O28
# V2+ V10 B4 O20
# V4+ Li8 V4 Si2 Ge2 O20
# Mo3+ K2 Ag1 Mo1 F6
# V4+ Li2 V2 Fe2 P8 O28
# Pr4+ K4 Sr4 Pr4 Sb4 O24
# Co4+ Mg1 Co1 F6
# V4+ Li4 V4 P20 O60
# V2+ Li4 V3 Co1 P4 O16
# V3+ Mn2 V3 Fe1 P6 O24
# Cr2+ Mg4 Cr2 W2 O12
# Mo3+ Pr2 Mg2 Mo4 O12
# Cr2+ Li4 Cr4 P4 O16
# V2+ Li4 V3 Ni1 P4 O16
# V4+ Mg4 V12 O28
# Ni3+ Ca12 V12 Ni8 O48
# Mo3+ Li14 Mo8 P18 O64
# Mo3+ Li6 Mo4 P6 O24
# V4+ Ca1 V4 O10
# Cr2+ Li16 Cr12 P16 O60
# Ni3+ La4 Fe1 Ni3 O12
# Cr2+ Li4 Cr6 P8 O28
# Cr2+ Li2 Cr4 P6 O20
# V4+ V4 Zn4 Si4 O20
# Mo3+ Ca4 Sb2 Mo2 O12
# Ag3+ Ba4 Zn4 Ag4 F28
# V4+ Mg4 V4 Ni4 P8 O36
# V4+ V4 P6 O24
# Co4+ Sr3 La1 Co2 O8
# O- K4 Na4 Ti4 H8 O12 F16
# V4+ V8 P8 O36
# V2+ Li4 V2 Fe2 P4 O16
# Mo3+ K1 Mo2 P4 O14
# V4+ V4 O7 F5
# V4.66666667+ Sr6 V6 Bi4 O28
# Cu+ Mg6 Cu4 P6 O24
# Tb2+ Ba1 Tb1 Fe2 O5
# V2+ V6 P4 O16
# Fe4+ Ba4 V4 Fe2 O18
# Cr2+ Li2 Cr4 P10 O30
# Cr2+ Cr4 P8 O24
# Fe4+ Sr6 Mn3 Fe1 O14
# Cr2+ Na14 Cr8 P12 O48
# Bi5+ Sr4 Yb2 Bi2 O12
# V3+ V4 Fe2 P6 O24
# Co4+ Sr3 Sm1 Co2 O8
# Cr2+ Sr2 Cr2 O4
# Cr2+ Cr6 P8 O28
# V3+ V4 Cd3 P6 O24
# W3+ Li4 P10 W2 O30
# V3+ Li3 Mg1 V8 O16
# Co4+ Sm4 Co2 Ni2 O12
# V4+ V4 P16 O48
# Mo3+ Ca2 Mo6 P6 O26
# Mo2+ K4 Mo4 P12 W4 O48
# V3+ La1 Mn3 V4 O12
# V4+ V4 Zn1 P6 O24
# Ni3+ Li6 Cr3 Ni1 P6 O24
# Cu+ Ti1 V3 Cu2 P6 O24
# Mo3+ Na1 Mo2 P4 O14
# W3+ Li4 P16 W4 O48
# V3+ V3 Cr1 Sn2 P6 O24
# V4+ Mn2 V3 Ni1 P6 O24
# V3+ V3 Co1 P4 O16
# V4+ V4 P2 O13
# Ti3+ Ti2 Te2 P6 O24
# Ni4+ La2 Zn1 Ni1 O6
# V4+ Sr2 V11 Ni1 O22
# V3+ Li2 V10 B4 O20
# Mo3+ Nb1 Mo1 O4
# Ni3+ Cr1 Ni1 F6
# V3+ Li12 V4 Si4 C4 O28
# Gd2+ Ba1 Gd1 Fe2 O5
# V3+ Mn2 V3 Sb1 P6 O24
# Fe4+ Sr1 La1 Fe2 O6
# Bi5+ K2 Bi2 F12
# V4+ V3 Ni1 P4 O16
# Bi5+ Sr6 Li2 Bi2 O12
# V3+ V8 Zn4 P8 O36
# Cr2+ Li2 Cr12 P14 O48
# V4+ Li2 V2 H4 O2 F10
# Ag3+ Ca2 Ag2 F10
# Cr2+ Li6 Cr9 P8 O32
# Cu3+ Mg2 Cu2 F10
# Cu3+ Na6 Cu2 F12
# V3+ Li4 V4 P12 H4 O40
# Cu3+ Sr4 Li1 Cu1 C2 O10
# V2+ Nb4 V2 Zn4 O16
# Cu+ Li5 Cu1 P2 O8
# Cr2.16666667+ Cr12 P14 O48
# V3+ V6 O11 F1
# V2+ Li12 V4 P8 H4 O32
# V3+ Ca2 V8 O12
# V2+ V1 P6 W3 O24
# Mo3.75+ K2 Mo8 P16 O56
# Co4+ Nd4 Co2 Ni2 O12
# V3+ V6 O10
# V4+ Mn2 V3 Co1 P6 O24
# Co4+ Sr3 Nd1 Co2 O8
# V4+ V4 P8 Pb4 O32
# Cr2+ Zn2 Cr5 P6 O24
# Cr2+ Cr4 P16 O44
# Co4+ Sr2 La3 Fe4 Co1 O15
# V4+ V3 Sb1 P6 O24
# Ti3+ Ba6 Nd3 Ti1 Cu6 Mo2 O24
# Cr2+ Cr10 P8 O32
# Nb4+ K2 Na1 Nb2 Fe7 Si8 H4 O31
# Bi5+ Ba2 Yb1 Bi1 O6
# V2+ Li4 V1 Fe3 P4 O16
# W3+ Li2 P4 W2 O14
# V4+ Mg4 V12 O32
# V3+ Mg1 V2 P2 H2 O10
# Cr2+ Li4 Cr3 Co1 P4 O16
# V3+ Li4 Mn3 Nb2 V3 O16
# Cu3+ Ca12 V12 Cu8 O48
# Cr2+ Li4 Cr3 Ni1 P4 O16
# V3+ Mg1 V1 Cr1 P2 H2 O10
# Cu3+ La5 Cu5 O13
# Cr2+ Li4 Cr2 Fe2 P4 O16
# Ni3+ V4 Ni2 P6 O24
# Pr4+ Ca2 Pr2 Fe4 O12
# V4+ Li2 V4 O8
# V4+ Li9 V21 O40
# Mo3+ Li6 Mo6 P8 O32
# O- Sm18 C18 O72
# Ti3+ Sm7 Ti4 Se12 O6
# Cu+ La6 Co4 Cu2 O18
# V2+ V4 Zn4 P8 O28
# In+ Mn1 In1 F3
# Cu+ Ta4 Cu4 O12
# V3+ Nb1 V3 Cu2 P6 O24
# V3+ V16 O24
# V3+ V3 Fe3 P6 O24
# O- Na8 Al6 Ge6 O26
# V4+ V3 Cr1 Ni2 P6 O24
# O- Nd18 C18 O72
# V3+ V4 Ag2 P6 O22
# Ti3+ Ce7 Ti4 Se12 O6
# W3+ Ca12 Ge12 W8 O48
# Cr2+ Li2 Cr5 P4 O16
# V2+ Li4 V2 Ni2 P4 O16
# Cr2+ Li4 Cr16 P12 O48
# W3+ Li6 P6 W4 O24
# Pr4+ Sr2 Pr2 Fe4 O12
# Bi4.33333333+ La12 Bi12 O44
# Fe4+ Sr6 Mn2 Fe2 O14
# Nb4+ K5 Na3 Nb4 W4 O24
# V4+ Mn3 V1 P4 O16
# Ni3+ Tb4 Ni4 O12
# V3+ V3 Cu1 P4 O16
# V4+ Mg1 V4 O10
# V4+ Mn2 V3 Cu1 P6 O24
# Ni3+ Li5 Si2 Ni1 O8
# V3+ Li4 V4 P4 H4 O20
# V4+ Na12 V4 B8 S2 O32
# Fe4+ Sr3 Ca1 Mn2 Fe1 O10
# V3+ V3 Ni2 P6 W1 O24
# Yb2+ La4 Yb2 S8
# Mo3+ Y2 Mo2 W4 O16
# Cu3+ Sr4 La6 Fe8 Cu2 O30
# V3+ V10 O18
# V3+ Li4 V6 Cr2 O16
# Ti3+ Ti1 Sb3 P6 O24
# V4+ Li2 V2 P4 H2 O16
# Cr2+ Li12 Cr4 P8 H4 O32
# V4+ Mn1 V3 P6 O24
# Mo3+ Li2 Mo8 P14 O48
# V3+ Al2 V2 W4 O16
# V4+ Li2 V6 O12
# V3+ Li4 V4 O8
# Mo3+ Mg4 Mo8 P8 O36
# Co4+ Sr1 Eu1 Co1 O4
# V3+ Na12 V4 B8 O24
# V4+ Li8 V4 O12
# V3+ V14 O26
# Co4+ K2 Co1 F6
# V4+ Li7 V5 O12
# Nb4+ Nb3 Sb3 O13
# V3+ Li4 V2 P2 C2 O14
# V3+ V4 Zn4 P4 O20
# Mo3+ Li2 Mo4 P6 O22
# V3+ V4 Cd10 P16 O56
# V2+ Li4 V2 P4 H3 O16
# Mo3+ Mo8 P14 O48
# Cu3+ Sr2 La6 Fe1 Cu7 O20
# Cu+ Ce4 Cu3 S4 O4
# V4+ Li4 V6 O12
# V3.78571429+ K6 V28 O56
# Bi5+ Bi1 Sb3 F20
# V3+ V18 O34
# Cr2+ Cr8 P6 O24
# V4+ V3 Fe2 Ni1 P6 O24
# V2+ V12 B4 O20
# V3+ Li2 V1 Cr1 P2 H2 O10
# V3+ Li8 V6 Cr2 O16
# V4+ Li6 V8 O16
# La2+ La10 Er9 S27
# Yb2+ La5 Yb1 S8
# V3+ Li4 Ti2 V3 Fe3 O16
# V3+ Li6 V4 Cr2 O12
# Cu+ Na4 Li2 Cu2 P8 O24
# Cr2+ Li4 Cr2 Co2 P4 O16
# Cr2+ Zn4 Cr4 P8 O28
# V4+ Mn1 V3 Ni2 P6 O24
# V2+ Li4 V4 P8 H4 O28
# Cr2+ Cr4 P2 O10
# V4+ V8 O16
# V4+ Mg1 V5 O12
# V4+ Li8 V11 O22
# Cr2+ Li4 Cr2 Ni2 P4 O16
# V3+ Ca2 V10 O14
# Cr2+ Ti1 Cr7 O12
# V4+ Li12 V20 O48
# V4+ Li2 V2 Cr2 O8
# O- La6 Cu6 O17
# Fe4+ Ba1 La1 Fe2 O6
# V3+ V3 Fe2 Te1 P6 O24
# V4+ Li6 V5 O12
# Mo3+ Mo4 P6 O22
# V4+ Na8 V4 Si4 C4 O28
# V4+ Mn5 V1 P6 O24
# V4+ Li4 V5 O10
# Fe4+ Li2 Fe2 F10
# V4+ V3 P4 W1 O20
# V4+ Li5 V1 O4 F1
# Co4+ Lu4 Co4 O14
# V3+ Li6 V2 P4 H4 O18
# Cu3+ Li4 Cu2 F10
# V4+ Li4 V8 O20
# V3+ Na12 V4 Si4 C4 O28
# V4+ Na2 V12 O22
# Mo3+ Na4 Mo8 P8 O36
# V3+ V12 O22
# Ni3+ La4 Ni4 O12
# V4+ Mg1 V4 Zn1 O10
# Yb2+ Yb4 Sm1 S5
# V3+ Mg1 Mn1 V1 P2 H2 O10
# Cu+ V4 Cu2 P6 O24
# V3+ Li2 V1 Cr1 O4
# V3+ Li4 V5 Cr3 O16
# V2+ Ca4 V4 Ge8 O24
# V4+ Ca2 Mn6 V8 O24
# V4+ V3 Fe1 Ni2 P6 O24
# Cr2+ Li6 Cr6 B6 O18
# Co4+ Sr6 La14 Ga2 Co18 O60
# V2+ Li17 V16 O32
# Nb3+ Nb1 Sb3 P6 O24
# O- Sr6 Pr3 Cu6 O17
# V3+ V2 Cr2 O6
# V3+ Li6 V6 Cr2 O16
# Mo3+ Li4 Mo8 P8 O36
# V4+ K2 V6 O14
# Co4+ Ba12 Co4 O20
# Pr4+ Ca2 Pr2 Bi4 O12
# Bi5+ Sm2 Bi2 O8
# V2+ Li4 V1 Co3 P4 O16
# V4+ Li4 V4 S4 O16 F12
# Ag3+ Ba4 Zn2 Cu2 Ag4 F28
# V4+ Li8 V20 O48
# Bi4+ Li6 Bi4 P10 O36
# Fe4+ Sr21 Fe14 O47
# Ni3+ Li4 Ni2 P10 O30
# V4+ Li8 Mn4 V12 O32
# V3+ K8 V4 P4 C4 O28
# Ni4+ Sr3 La1 Ni2 O8
# V3+ Li6 V2 Cr4 O12
# V3+ Na8 V4 P4 C4 O28
# V3.375+ Li3 V8 Zn1 O16
# Fe4+ Sr12 Fe8 O27
# V3+ V12 Ga6 O30
# Co4+ Li8 Mn7 Co1 P12 O48
# Ti3+ Li4 Ti3 Ni3 W2 O16
# V4+ Na4 V8 O16
# Bi4+ Ca6 Bi4 O14
# V2+ Li8 V14 O24
# Fe4+ Sr4 Fe3 Mo1 O12
# V2+ Li4 V1 Ni3 P4 O16
# Cr2+ Li4 Cr2 P4 H3 O16
# Ni3+ Ca4 Fe4 Ni4 P8 O36
# V3+ Li4 V6 Sn2 O16
# Fe4+ Sr2 La1 Fe3 O9
# O- Sr12 Ca2 Y4 Ga6 Cu12 O42
# Cu3+ Y6 Cu6 O18
# O- Ba6 Y1 Cu3 O11
# V3+ V11 Ni1 O18
# V3+ Li4 V6 Co2 O16
# V3+ Li4 V1 Cr3 O8
# V4+ Li1 V2 H4 O2 F10
# Bi5+ Ba6 Ca2 Bi4 O18
# Cr2+ Li2 Cr2 P4 H2 O14
# Sm2+ Na3 Sm6 Cl18
# V3+ Li4 V6 W2 O16
# Cu+ Sr16 Cu8 O23
# Nb4+ K4 Na4 Nb3 W5 O24
# V3+ Li10 V6 Cr4 O20
# Mo3+ Mg2 Mo6 P6 O26
# Sm2+ La5 Sm1 S8
# V3+ V3 Cu2 P6 W1 O24
# V2+ Li2 V6 P6 H4 O24
# Cr2+ Li4 Cr1 Co3 P4 O16
# V3+ Li4 Nb2 V3 Fe3 O16
# Mo3+ Na2 Mo6 P6 O26
# V3+ Li4 Mn2 V2 P4 H4 O20
# Fe4+ Sr4 La1 Cr1 Fe4 O15
# Mo2+ Mg2 Mo1 W1 O6
# Co4+ Sr2 La2 Fe2 Co2 O12
# Co4+ Sr3 La2 Fe4 Co1 O15
# Bi5+ Nd2 Bi2 O8
# Cu+ V3 Cu2 Sn1 P6 O24
# V3+ Li6 Mn2 V2 P4 H4 O20
# Bi5+ Pr4 Bi4 O16
# O- Sr1 La3 Cu4 O10
# V3+ Li2 V2 P4 H4 O16
# Fe4+ Li8 Fe7 Te1 P12 O48
# Ni3+ Sr12 In4 Ni4 O24
# Fe4+ Sr24 Fe16 O55
# Cr2+ Li9 Cr4 P4 C4 O28
# Cu3+ Sr16 Cu8 B1 C7 O40
# V2+ Li6 V2 Cr2 P4 H4 O20
# V4+ V2 Co2 P4 O16
# Cu3+ Sm4 Cu4 O12
# V4+ Li9 V19 O48
# Cu3+ Li18 Cu6 P16 O58
# V4+ Na4 V8 O20
# V4+ V3 Co1 Ni2 P6 O24
# Mo3+ Li2 Mo6 P6 O26
# Ni3+ Li12 Ni8 P8 O32 F8
# Fe4+ Sr4 Nd2 Fe6 O18
# Fe4+ Ca6 Fe4 O14
# V3+ Li4 V6 Sb2 O16
# Yb2+ Yb2 Gd4 S8
# Cr2+ Li4 Cr1 Ni3 P4 O16
# Co4+ Ca2 La2 Fe2 Co2 O12
# V4+ Li2 V18 O39
# Ni3+ Cr3 Ni1 P4 O16
# Bi5+ K4 Ba4 Tb4 Bi4 O24
# Fe4+ Sr4 Pr2 Fe6 O18
# V4+ Na2 V6 O13
# V4+ Na2 V12 O26
# Nb7+ Mn3 Nb1 P6 O24
# Fe4+ Sr4 Gd2 Fe6 O18
# V4+ Li2 V2 Cr2 P4 H4 O20
# Cu+ Yb2 Mg1 Cu1 Ge4 O12
# V4+ Na6 V10 O20
# Yb2+ Tb4 Yb2 S8
# Yb2+ Yb2 Sm4 S8
# Co4+ Sr2 La4 Co6 O18
# V4+ Li8 V12 O32
# Tb4+ K8 Tb4 O12
# V2+ Ba1 V13 O18
# V4+ K4 V6 P8 H8 O38
# V3+ V1 Fe3 P4 O16
# V3+ V18 Ni2 O30
# Cu3+ La1 Cu1 O3
# Cu+ Mn1 V3 Cu2 P6 O24
# Yb2+ Yb2 Nd4 S8
# Ce2+ La4 Ce2 S8
# La2+ La1 Eu1 S2
# V4+ Li4 V3 Cr5 O16
# Yb2+ Yb2 Dy4 S8
# Cu+ Li4 Fe3 Cu1 P4 O16
# V4+ Li6 V2 Cr6 O16
# V3+ V1 Sb3 P6 O24
# Sm2+ La4 Sm2 S8
# V4+ V2 Ni2 P4 O16
# Yb2+ Yb2 Y4 S8
# O- Sr4 La4 Fe2 Cu6 O20
# V4+ V12 O26
# V3+ Li12 V6 Ga6 O24
# Yb2+ Yb2 Pr4 S8
# V3+ Li4 Mn1 V3 O8
# Bi5+ Sr2 Eu2 In2 Bi2 O12
# Co4+ Li2 Co1 Sn3 P6 O24
# Co4+ Sr12 Zn4 Co4 O24
# Ag2+ Li4 Ag2 F8
# Ni3+ V3 Ni1 P6 O24
# Co4+ Sr1 Pr1 Fe1 Co1 O6
# Cu+ V3 Fe1 Cu2 P6 O24
# Ni4+ Mg1 Ni1 F6
# Ni3+ Li2 Ni2 P8 O24
# Co4+ Sr2 La3 Fe1 Co4 O15
# Yb2+ Yb2 Ho4 S8
# Fe4+ Sr5 Fe4 Mo1 O15
# V4+ K4 V4 P4 C4 O28
# Ni3+ Ti1 Fe3 Ni2 P6 O24
# Bi5+ Bi2 P8 O24
# V3+ Li4 V3 Cr3 Sn2 O16
# V3+ V12 Pb2 O22
# V3+ Mg1 V3 Zn2 O8
# V2+ K6 V2 P2 C2 O14
# Fe4+ Sr2 Fe1 Sn1 O6
# V3+ Li4 V3 Cr3 W2 O16
# Cu+ Er1 Cu1 W2 O8
# Cu3+ Nd4 Cu4 O12
# V4+ Li4 V4 Ga4 O16
# V3+ V16 Bi3 O32
# Cu+ Dy1 Cu1 W2 O8
# Ni3+ Sr1 Eu1 Ni1 O4
# Co4+ Ba6 Mn4 Co2 Cl1 O16
# V4+ Li6 Mn2 V8 O24
# V4+ V3 Cr1 O8
# Bi4.11111111+ Ba10 Ce1 Bi9 O30
# V4+ Li3 V6 O16
# V4+ Li4 V4 P4 C4 O28
# In2+ Ba8 In8 O19
# Cu3+ Ba4 Pr4 Fe4 Cu4 O21
# Cu+ V3 Cu2 Sb1 P6 O24
# Cu+ Y1 Cu1 W2 O8
# Fe4+ Ba2 La1 Fe3 O9
# Bi+ V20 Bi4 O40
# V4+ Na5 V7 O14
# V4+ Li3 V12 O29
# Bi5+ Ba20 Li4 Bi8 O42
# V2+ Na6 V2 P2 C2 O14
# Nb4.5+ Na2 Nb4 Bi4 O18
# Yb2+ Yb1 Sm1 S2
# V3+ Li4 V2 Fe2 P4 H4 O20
# Cu3+ V3 Cu1 P6 O24
# V3+ Li16 V3 Ga13 O32
# Co4+ Ba1 Nd3 Co4 O12
# Fe4+ Fe6 P12 O40
# V3+ Mn8 V16 O32
# V4+ V1 Fe5 P6 O24
# Tb2+ Tb1 Eu4 S5
# V4+ Li5 V18 O44
# V3+ Li6 Mn2 V4 O12
# V4.33333333+ Na6 V6 O16
# V3+ Li8 V2 Ga6 O16
# V4+ Mg1 V8 O20
# Cu3+ Ca1 Cu2 F8
# V4+ V4 P4 H4 O20
# V4+ Li2 V6 O15
# V2+ Li3 V5 O8
# Fe4+ Fe8 P14 O48
# V4+ Li14 V2 O10 F2
# O- Na12 Fe4 P8 H2 O34
# V4+ Na4 V4 P4 C4 O28
# Cu+ Nd1 Cu1 W2 O8
# V4+ Li5 V12 O32
# Cu+ Sm2 Cu2 W4 O16
# Bi4.5+ Ba8 Bi4 O17
# Yb2+ K4 Yb4 Br12
# V2+ Mg2 V2 Ge4 O12
# Fe4+ Sr6 Ca2 Mn5 Fe3 O24
# V4+ K1 V4 O10
# Cu+ Pr2 Cu2 W4 O16
# V4+ Na5 V12 O32
# V3+ V1 Fe3 Sb2 P6 O24
# Co4+ Ca1 Pr3 Co4 O12
# Fe4+ Na6 Fe2 Si2 B2 O14
# Co4+ Y4 Co4 O14
# Yb2+ Yb2 Ce4 S8
# V3+ Li8 V12 Fe4 O32
# La2+ Ca2 La16 Se24
# V3+ Li4 V3 Cr3 Sb2 O16
# V4+ Li4 Nb2 V3 Ni3 O16
# V4+ Li6 V24 O60
# Ni4+ Ca2 La2 Fe2 Ni2 O12
# Co4+ Sr8 Co4 O16
# Ni+ Li5 Ni6 P8 O28
# Fe4+ Fe2 P8 O24
# Mo3+ Mo6 P6 O26
# Sm2+ La1 Sm1 S2
# Cr2+ K6 Cr2 P2 C2 O14
# Ni+ Na4 Fe4 Ni2 P6 O24
# V3+ Li4 V5 Sn3 O16
# W3+ Sb3 P6 W1 O24
# V3+ Li3 V4 Cr1 O8
# V2+ Li4 V6 P8 H8 O32
# Bi2+ Ca3 Mn4 Bi1 O12
# Cu3+ Li2 Cu2 P8 O24
# W2+ Li4 Cr6 W2 O16
# Tb2+ Tb22 S32
# Ni3+ Li2 Ti2 Ni2 O8
# V4+ Na2 V6 O15
# Cu3+ Sr8 Cu4 O14
# Ni3+ Li4 Ti3 Ni3 Sn2 O16
# V4+ Mn3 V1 Ni2 P6 O24
# Cu+ La4 Cu4 Se1 S3 O4
# V3+ V12 Zn6 O24
# V4+ Li3 V24 O58
# Cr2+ Na12 Cr4 P4 C4 O28
# Ag2+ K4 Ag2 F8
# Fe4+ Sr7 Ca1 Mn4 Fe4 O24
# Co4+ Li4 Co4 P20 O60
# Ni3+ Sr8 Ni4 Cl4 O12
# Cu+ V3 Cu2 Te1 P6 O24
# Sm2+ Sm1 Eu1 S2
# V4+ Na3 V24 O58
# V4+ V4 Zn4 Ni4 P8 O36
# Sm2+ Sm2 Cl4
# V4+ V3 Cu2 Ni1 P6 O24
# Dy2+ Dy22 S32
# Yb2+ Yb1 Sm3 S4
# V4+ Li3 V4 Fe1 O12
# Cu+ La2 Cu2 Se1 S1 O2
# Sm2+ Sm39 S56
# Sm2+ Sm2 Gd4 S8
# Nd2+ Sr1 Nd5 S8
# V4+ Li2 Mn2 V2 P4 H4 O20
# V3+ Li2 V2 Sn2 O8
# V3+ Li4 V3 Fe1 O8
# V4+ Na6 V24 O60
# V4+ Li2 V12 O29
# Gd2+ Ca1 Gd1 S2
# Ce2+ Tb4 Ce1 S7
# Nb2+ K2 Na2 Nb1 W3 O12
# Ce2+ Ce1 Y4 S7
# V2+ V3 Mo1 O6
# Cu3+ Na2 Cu2 P8 O24
# Fe4+ Zn1 Fe1 F6
# V4+ Li4 V24 O60
# V4+ Li8 V12 Cr8 O48
# Ce2+ Ce1 Dy4 S7
# Fe4+ Sr5 Ca3 Mn4 Fe4 O24
# O- Ca4 Eu2 Cu4 O12
# Fe4+ Fe10 P16 O56
# Cr2+ Li2 Cr6 P6 H4 O24
# V3+ Li1 V1 P4 H4 O14
# V2+ Li12 V1 Ni3 P4 C4 O28
# V4.66666667+ V9 O21
# V3+ Li2 V2 W4 O16
# Co4+ Sr12 Zn2 Co6 O25
# Cu+ Li4 Fe2 Cu2 P4 O16
# Cu+ La4 Cu4 Se3 S1 O4
# V4+ Na2 V12 O30
# V4+ V20 O48
# V4+ Na5 V36 O88
# V3+ Li2 V6 Zn4 O16
# Cu3+ Ca2 Cu4 P8 O28
# Bi4+ Ba5 Bi3 O11
# Ni3+ Li5 Ti2 Ni3 O10
# Ce2+ Ce1 Ho4 S7
# Nd2+ Ba3 Nd3 Co6 O16
# Cu3+ Pr1 Cu1 O3
# Yb2+ La24 Se40 Yb4
# V3+ Li6 V4 Fe2 O12
# Ce2+ Ce1 Er4 S7
# Cu+ Li2 Cu2 P4 O12
# Mo3+ Pr2 Zn2 Mo4 O12
# Cu3+ Ca2 La2 Fe2 Cu2 O12
# V4+ Na3 V24 O60
# V3+ Mg1 V2 Ge4 O12
# Sm2+ Ca1 Sm2 S3
# Bi5+ Na12 Bi4 B8 P2 O32
# V4+ Na1 Mn3 V4 O12
# Bi5+ Bi2 P4 O14
# V3+ Li4 V3 Cr2 Sn3 O16
# V4+ Li2 V18 O44
# Bi5+ Sr8 In4 Bi4 O24
# V4+ V2 Cu2 P4 O16
# Sm2+ Ce4 Sm2 S8
# Yb2+ Yb1 Sm4 S5
# V3+ Li4 Mn3 V3 W2 O16
# Fe4+ Sr7 Ca1 Mn3 Fe5 O24
# Cu+ Li8 Cu4 P4 O16
# V4+ V4 Ga8 O20
# Cu+ Ba4 Cu2 I1 Br1 O4
# Ce2+ Ce2 Nd4 S8
# V4+ Li2 V2 Fe2 P4 H4 O20
# V4+ Li1 V24 O58
# Gd2+ Sm1 Gd1 S2
# O- Sr21 Co14 O43
# Ce2+ Ce2 Pr4 S8
# Ce2+ Ce2 Sm4 S8
# Fe4+ Sr6 Ca2 Mn3 Fe5 O24
# Bi5+ Ba4 Sr4 In4 Bi4 O24
# V4+ Na1 V24 O58
# Sm2+ Nd4 Sm2 S8
# V4+ V24 Pb4 O60
# Ni3+ Li2 Ni2 P4 O14
# Cr2+ Li4 Cr1 W3 O12
# Mo3+ Ca2 Mo4 O8
# Sm2+ Pr4 Sm2 S8
# Sm2+ Sm4 Eu1 S5
# V3+ Li4 V2 Cr3 Sn3 O16
# V2+ V4 W4 O16
# V4+ Mg1 V28 O70
# V4+ Li1 V18 O44
# La2+ Sr2 La16 Se24
# V3+ Li4 V4 P8 H12 O34
# Bi5+ Ba2 Ca2 In2 Bi2 O12
# Fe4+ Sr10 Fe10 O27
# Bi5+ Ba8 In4 Bi4 O24
# Cr2+ Li4 Cr6 P8 H8 O32
# Cr2+ Mg2 Cr2 Ge4 O12
# V3+ Li4 V12 P8 H16 O48
# V4+ Li4 V6 Ni2 O16
# Ce2+ Ce1 Nd1 S2
# O- Sr8 Y4 Cu11 C1 O28
# La2+ La39 Se56
# V4+ Li8 V4 C4 O20
# Ni3+ Li8 Ti6 Ni6 Te4 O32
# V2+ Li2 V6 O8
# Ni3+ Li12 Ni4 B8 O24
# V3+ Mn10 V8 O24
# Ni3+ Na6 Ni2 B2 P2 O14
# Ce2+ Ce1 Sm3 S4
# V3+ V10 Fe2 Pb2 O22
# Bi4.33333333+ Ba16 Bi12 O42
# V4+ V12 O29
# Fe4+ Sr8 Fe8 O22
# Bi5+ K2 Ba6 Yb3 Bi5 O24
# V3+ V16 Ni4 O30
# V4+ V12 Pb1 O30
# Ni3+ Li12 Si4 Ni4 O20
# Fe4+ Sr16 Fe16 O43
# La2+ Ba3 La1 Y2 Cu6 O14
# V4+ V4 Sn4 O16
# Fe4+ Sr14 Fe14 O39
# Bi5+ Na6 Ca4 Bi2 O12
# Fe4+ Sr7 Ca1 Mn2 Fe6 O24
# V4+ V4 Zn2 O10
# V3+ Li5 V5 Fe2 O12
# Pr2+ Pr1 Sm3 S4
# V3+ Li32 V4 O20 F4
# V4+ Na2 V16 Mo2 O45
# Fe4+ Sr10 Fe10 O28
# V4+ Na1 V5 Mo1 O15
# V3+ Li4 Mn3 V3 Sn2 O16
# V4+ V4 Zn1 O10
# V4+ V18 O44
# Ni3+ Ni4 P12 O36
# Fe4+ Sr16 Fe16 O45
# Bi4.22222222+ Ba11 Bi9 O30
# Fe4+ Ba1 Sr7 Mn2 Fe6 O24
# Ni3+ Mn4 Ni2 P6 O24
# Bi4+ Na12 Bi4 B8 S2 O32
# La2+ Ba3 La3 Cu6 O14
# Cu3+ Li4 Cu4 F14
# V4+ Li4 V6 Te2 O16
# Mo3+ Zn2 Mo6 P6 O26
# V4+ Na8 V4 O12
# Cu+ Li8 Cu8 F20
# Ta4.8+ Ta5 Pb11 O26
# Ag2+ Ag2 Sb6 I2 F48
# Sm2+ Sm3 Ho1 S4
# V3+ V4 Ge4 O14
# Nb2+ K4 Na4 Nb1 W7 O24
# Fe4+ Fe4 P8 O28
# Fe4+ Na2 Fe6 P6 O26
# O- Ba4 Li1 Y2 Cu5 O14
# Ni3+ Fe3 Ni2 Sn1 P6 O24
# V4+ V10 W6 O40
# V4+ V2 Cr2 Sb2 O12
# Co4+ Sr2 Pr2 Co4 O12
# Sm2+ Sm3 Dy1 S4
# Fe4+ Li2 Fe6 P6 O26
# Fe4+ Sr4 Ca4 Mn2 Fe6 O24
# V4+ Li16 V12 Fe8 O48
# Co4+ Y2 Co6 F30
# V3+ Mn14 V10 O32
# Mo3+ Zn4 Mo8 P8 O36
# Cu+ Li1 Cu1 F2
# Cu+ Ba14 Li1 Y7 Cu20 O42
# Co4+ Sr6 Co4 O13
# V3+ Li4 Mn3 V3 Sb2 O16
# Fe4+ Sr8 Mn1 Fe7 O24
# Ti3+ La8 Ti10 S24 O4
# Ni3+ Ni1 Sb3 P6 O24
# Cu+ Li5 Cu6 P8 O28
# Zr3+ Zr48 N8 Cl120
# Fe4+ Sr10 Fe10 O29
# Co4+ Li8 Mn1 Co7 P12 O48
# Cu+ Li3 V4 Cu1 O12
# Cu+ Li4 Fe1 Cu3 P4 O16
# Cu+ Ba14 Y7 Cu20 O42
# La2.875+ Na2 La16 Se24
# Fe4+ Sr7 Ca1 Mn1 Fe7 O24
# Cr2+ Cr4 W4 O16
# Cu+ Sr4 Ca4 Ga2 Cu6 O18
# V4+ V6 Zn4 O16
# V2+ Mg1 V1 C2 O6
# Gd2+ Sm4 Gd1 S5
# Ag3+ Li4 Ag2 F10
# Fe4+ Ba1 Sr7 Mn1 Fe7 O24
# Fe4+ Sr6 Ca2 Mn1 Fe7 O24
# Fe4+ Sr16 Fe16 O47
# V4+ V3 Fe1 O8
# Co4+ Ca2 Pr2 Co4 O12
# Fe4+ Sr5 Ca3 Mn1 Fe7 O24
# Bi5+ Li1 Bi1 B2 O6
# Cu3+ Cu1 Sb3 P6 O24
# Nb4+ Nb2 Cl4 O2
# O- Sr6 Y3 Fe1 Cu8 O22
# O- Ba3 Nd3 Cu6 O14
# Cu3+ Na2 Cu2 P4 O14
# V4+ Li8 Mn8 V12 O48
# Ni3+ Mn1 Fe3 Ni2 P6 O24
# V3+ V4 H2 O8
# Cu+ Na1 Sr7 Cu8 S8 F8
# Cu3+ Ti1 Cu3 P4 O16
# V3+ V4 Co2 O8
# Fe4+ Ba12 Fe12 O32
# V3+ Li4 V3 Cr3 Te2 O16
# Cu+ Ba2 In1 Cu1 O4
# V3+ Li4 V4 C4 O16
# Cu+ Ba1 Sr1 Sm1 Cu3 O6
# Cu+ V24 Cu4 O58
# V3+ Li4 Mn2 V3 Sb3 O16
# V4+ Mn4 V6 Ni2 O16
# Cu+ Ba2 La1 Cu3 O6
# Cu+ Ba3 Sr1 Sm2 Cu6 O12
# V4+ Mn2 V2 P4 H4 O20
# Zr3+ K4 Zr24 N4 Cl60
# Cu3+ Li2 Cu4 P10 O32
# Bi4.33333333+ Ba4 Li1 Bi3 O11
# Co4+ Ca6 Co4 O14
# Ti3+ Ti8 P12 H28 N4 O52
# Bi5+ Sr2 Fe1 Bi1 O6
# V2+ V4 Fe8 B4 O20
# O- Sr2 Y1 Cu3 O7
# Ni3+ Fe3 Ni1 P4 O16
# Cu+ Ba2 Er1 Cu1 Ni2 O7
# V3+ V4 Sb4 O16
# Bi5+ Ba1 Sr1 Fe1 Bi1 O6
# Cu+ V24 Cu3 O60
# V3+ V3 Ni1 O6
# V4+ V2 Cr4 O12
# V4+ V10 Cu2 O24
# Fe4+ Sr8 Ca2 Fe10 O30
# Cu3+ Ba10 Cu5 O17
# Cu3+ Li2 Cu2 F8
# O- Ba1 Sr1 Er1 Cu3 O7
# Fe4+ Sr3 Ca1 Fe4 O12
# Cu3+ Li4 Cu4 P8 O28
# V4+ V12 Co4 O32
# V4+ Li2 V2 Fe2 O8
# Bi4+ Ba4 Bi3 Pb1 O12
# Fe4+ Ba1 Sr7 Fe8 O24
# Cu+ Ba10 Y5 Cu15 O32
# V4+ Li32 V4 O24
# V2+ V4 Fe2 O8
# O- Ba10 Ho5 Cu15 O33
# Co4+ Sr4 La1 Fe2 Co3 O15
# Yb2+ Yb1 Y2 Se4
# Fe4+ Ba2 Sr8 Fe10 O30
# Ni3+ Fe3 Ni2 Te1 P6 O24
# Cu+ Ba10 Er5 Cu15 O34
# Cr2+ Li8 Cr6 Sn10 O32
# V3+ Li4 V3 Fe3 W2 O16
# Tb+ Tb4 Cl6
# Bi5+ Ba4 Li1 Bi3 O12
# Cu+ Sr6 La2 Cu8 O16
# Bi4+ Ba6 Bi4 Pb2 O18
# V3+ Li6 V3 Fe3 O12
# Co4+ Ba6 Y3 Co3 Cu6 O22
# V4+ V12 Pb8 O36
# Ni3+ Li4 Nb2 Cr3 Ni3 O16
# V3+ Mn16 V8 O32
# Cu+ Ba2 Pr1 Cu3 O6
# Ni3+ Fe4 Ni2 P6 O24
# V4+ V12 Cu2 O30
# V4+ V4 Fe2 O12
# Ga2+ Na4 Ga22 O34
# O- Ba10 Y5 Cu15 O33
# Yb2+ Yb1 Ho2 Se4
# O- Ba8 Y4 Cu12 O27
# Yb2+ Yb1 Er2 Se4
# Cu3+ Cu4 P12 O36
# Ti3+ Gd12 Ti4 S24
# V3+ Na12 V4 P2 C8 O32
# Cu3+ Ba6 Y3 Cu9 O20
# Bi5+ Na4 Si2 Bi2 C2 O14
# V2+ Li16 V8 S16 O64
# Cu+ Ba10 Y5 Cu15 O34
# V4+ Li8 Mn12 V4 O32
# V3+ Li4 V3 Fe3 Sn2 O16
# O- Ba10 Sm5 Cu15 O33
# O- Sr2 Cu1 O4
# Cu3+ Fe3 Cu1 P4 O16
# Ni3+ Li4 Cr3 Ni1 O8
# Ag3+ Ca4 Ag2 Sb2 O12
# Dy2+ Ca8 Dy3 Se12
# Co4+ Sr7 Ca1 Fe7 Co1 O24
# Fe5+ Li2 Fe2 F12
# O- Ba1 Sr1 Sm1 Cu3 O7
# Cu1.75+ Ba8 Ca1 Y3 Cu12 O24
# O- Ba8 Gd4 Cu12 O27
# Fe4+ Sr8 Fe7 Co1 O24
# V3+ V17 Fe7 Pb4 O44
# Yb2+ Yb1 Lu2 Se4
# Fe4+ Li6 Fe4 P4 C4 O28
# Co4+ Sr6 Ca2 Fe7 Co1 O24
# Pr2+ Yb1 Pr1 Se2
# O- Ba10 Gd3 Y2 Cu15 O35
# Zr3+ Zr2 Cl6
# O- Ba10 Pr1 Y4 Cu15 O35
# V4+ Li2 V4 Ni2 O12
# O- Ba3 Ca1 La2 Cu6 O14
# O- Ba10 Gd2 Y3 Cu15 O35
# Ni3+ Ni14 P16 O56
# V4+ V12 Ag2 O30
# O- Ba4 Gd1 Y1 Cu6 O14
# Cu+ Ba10 Gd1 Y4 Cu15 O35
# Cu3+ Ba10 Gd4 Y1 Cu15 O35
# Mo2+ K4 Na4 Mo1 W7 O24
# Cu3+ Ba8 Sr2 Sm5 Cu15 O35
# Co4+ Sr5 Ca3 Fe7 Co1 O24
# Co4+ Co6 P12 O40
# Pr2+ Pr27 Se40
# Ni3+ La1 Eu3 Ni4 O12
# O- Ba8 Pr1 Y3 Cu12 O28
# Ni3+ Li2 Ni4 P4 O16
# O- Ba4 Pr1 Y1 Cu6 O14
# Co4+ Ba1 Sr7 Fe7 Co1 O24
# Ni3+ Li4 Ti2 Ni3 Sn3 O16
# Mo3+ K4 Na4 Mo3 W5 O24
# Sm2+ Sm1 Eu1 Se2
# O- Ba1 Sr1 Nd1 Cu3 O7
# V3+ Li4 V8 P8 H20 O44
# O- Ba4 Pr1 Er1 Cu6 O14
# O- Ba4 Pr1 Ho1 Cu6 O14
# Fe4+ Na4 Fe2 Si2 C2 O14
# O- Ba4 Pr1 Dy1 Cu6 O14
# Cu3+ Li8 Cu10 F34
# Cu3+ Ba10 Pr2 Y3 Cu15 O35
# V4+ V4 Ge8 O24
# O- Ba4 Pr1 Lu1 Cu6 O14
# Ag3+ Y6 Ag6 O18
# Ni3+ Na10 Ni4 P4 C4 O28
# V2+ V4 Ge4 O12
# In+ Sr8 In4 Br20
# O- Ba3 Sr1 Nd2 Cu6 O14
# Ni3+ Ni6 O1 F11
# V3+ Li4 V3 Fe3 Sb2 O16
# V4+ V8 P8 H16 O44
# Co4+ Li6 Cr6 Co2 O16
# O- Ba1 Sr1 Pr1 Cu3 O7
# O- Ba4 La1 Pr1 Cu6 O14
# Mo2+ K2 Na2 Mo1 W3 O12
# O- Ba4 Pr1 Sm1 Cu6 O14
# Mo3+ Mg2 Mo4 O8
# Cu3+ Li2 Cu2 P2 O8 F2
# Ni3+ Li6 Ti2 Ni4 O12
# O- Ba4 Pr1 Gd1 Cu6 O14
# Cu1.75+ Sr8 Ca2 Y2 Cu8 Bi4 Pb4 O32
# Fe4+ Li4 Ti2 Fe6 O16
# Co4+ Sr7 Ca1 Fe6 Co2 O24
# Ce2+ Ce2 Se1 S1
# V2+ Li8 V8 S12 O48
# O- Ba4 Pr1 Nd1 Cu6 O14
# Yb2+ Tb10 Yb1 Se16
# Pr2+ Yb2 Pr22 Se32
# V4.5+ K6 V4 S8 O36
# V3+ Li5 V2 Fe3 O10
# Bi2.5+ La2 Bi2 S4 O1 F1
# Pr2+ Ca2 Pr16 Se24
# Ni3.5+ Ca2 Ho2 Ni4 O12
# V4+ Li4 V2 Ni2 O8
# Cr2+ Li16 Cr8 S16 O64
# Co4+ Ba1 Sr7 Fe6 Co2 O24
# V3+ Li4 V3 Ni3 W2 O16
# Ni3+ Na12 Ni4 B8 O24
# V3+ Li4 V3 Fe2 Sb3 O16
# Cr2+ La4 Cr4 Se8 O4
# V3+ Li1 V1 C2 O6
# Nd2+ Ca2 Nd16 Se24
# Ni3+ Zn4 Ni4 F20
# O- Ba10 Ca1 Y4 Cu15 O35
# Co4+ Ba10 Mn2 Co8 O28
# Bi2.75+ La4 Bi4 S8 O3 F1
# V3+ Li3 V3 S6 O24
# V3+ V8 Ni4 O18
# Cu+ Ba2 Y1 Cu3 Pb1 O7
# Co4+ Sr4 Ca4 Fe6 Co2 O24
# Cu+ Sr2 Cu1 Se1 O2
# V3+ Li6 V2 C6 O18
# Bi5+ Bi4 F20
# V2+ Li4 V2 C4 O12
# Yb2+ Sr4 Yb2 Cu4 Bi4 O16
# Pr2+ Pr1 Sm1 Se1 S1
# O- Ba8 O16
# Cu+ Ba1 Sr1 Y1 Cu3 Pb1 O7
# Nb3+ Lu4 Nb24 Cl52 O12
# O- Ba4 Dy2 Cu6 Ni1 O15
# Ni3+ Li7 V6 Ni5 O24
# Mo3+ Mg1 Ge4 Mo2 O12
# Ni3+ Li4 Ti2 Mn3 Ni3 O16
# V4+ V6 Cu2 O15
# Co4+ Ba10 Co10 O26 F2
# Sm2+ Ca2 Sm16 Se24
# V4+ V4 Ag1 O10
# Co4+ Sr7 Ca1 Fe5 Co3 O24
# Ni3+ Ba8 Y4 Cu12 Ni2 O30
# V3+ Li4 V8 S12 O48
# Ni3+ Na6 Si2 Ni2 C2 O14
# Cr2+ Li2 Mg1 Cr3 S6 O24
# Ag2+ K1 Ag1 F3
# V3+ Mg1 V2 C4 O12
# Fe4+ Li20 Fe4 O16 F4
# V2+ Na12 V4 C8 S2 O32
# Ni3+ Li5 Ti2 Ni5 O12
# O- Ba4 Y2 Cu7 O15
# Co4+ Sr6 Ca2 Fe5 Co3 O24
# Nb3+ Sm4 Nb24 Cl52 O12
# V4+ V8 Fe4 H2 O24
# Ni3+ Ni12 P12 O44
# V4+ V5 Mo5 O25
# Cu+ K2 Lu1 Cu1 Cl6
# Mo3+ Li21 Mo11 O32
# Ni3+ Li3 Cr2 Ni1 O6
# Co4+ Zn1 Co1 F6
# Co4+ Co3 P6 W1 O24
# Nd2.875+ Na2 Nd16 Se24
# O- Ba4 Pr1 Eu1 Cu6 O14
# Cr2+ La12 Cr4 S24
# V3+ Na8 V4 C8 S2 O32
# V4+ V6 Zn2 Fe4 O22
# V4+ Ca1 V2 P2 H8 O14
# Fe4+ K2 Fe2 P2 C2 O14
# V3+ K4 V4 Fe4 P8 H20 O44
# Pr2+ Ca2 Pr2 Ni4 O12
# Co4+ Sr4 La1 Co5 O15
# Nb2+ Nb12 Br17 F13
# Fe4+ Sr2 Fe1 Co1 O6
# Ag3+ La2 Ag2 O6
# Ni3+ K4 Ni2 P2 C2 O14
# Sm2.875+ Na2 Sm16 Se24
# Cu+ V8 Fe2 Cu2 O24
# V2+ V2 O2
# Cr2+ Li8 Cr4 O8
# Nd2+ Nd4 Br8
# V3+ V8 S12 O48
# Ni3+ Na4 Ni2 P2 C2 O14
# V3+ V4 Bi4 O12
# O- Ba4 Yb1 Pr1 Cu6 O14
# Ti3+ Nd12 Ti2 In2 S24
# Cr2+ Li8 Cr8 S12 O48
# Cu3+ Fe2 Cu2 P4 O16
# Ti3+ Li4 Ti1 Te3 O12
# Co4+ Sr7 Ca1 Fe4 Co4 O24
# Cu3+ Li1 V4 Cu1 O12
# Bi4.25+ K1 Ba3 Bi4 O12
# V3+ Li4 V1 Fe3 O8
# Cu3+ Ca2 Pr2 Cu4 O12
# Ni3.33333333+ Sr12 Ni9 O27
# V4+ Li4 V3 Ni3 Sb2 O16
# Ag2+ Li2 Ag2 F6
# V3+ V4 H4 O8
# V4+ Mg1 V2 P2 H8 O14
# Zr+ K6 Zr12 Be2 Cl30
# Ti3+ La4 Ti4 S12
# Cu+ Sr4 Ho2 Cu6 Pb4 O16
# Cu3+ Li4 Cu2 P2 C2 O14
# Gd2+ Sm1 Gd1 Se2
# Ni4+ Na6 Ni4 P4 C4 O28
# Cu3+ Ca8 Cu8 O20
# Fe4+ Na2 Fe2 P2 C2 O14
# V4+ V4 Zn8 O16
# Cu+ Sr4 Y2 Cu6 Pb4 O16
# Cu3+ Y6 Cu11 O24
# O- Ba1 Sr1 Y1 Cu4 O8
# V2+ V4 Zn4 Ge8 O24
# O- Ba4 Nd2 Cu6 Ni1 O15
# Cr2+ Li4 Cr3 C6 O18
# Cr2+ Na12 Cr4 C8 S2 O32
# V4+ Na8 V2 O8
# V4+ V2 Fe2 Sb2 O12
# Nd2.5+ Nd2 Bi7 O14
# Cu+ La10 Cu12 S14 O8
# Co4+ Li4 Cr4 Co2 O12
# O- Ba1 Sr1 Eu1 Cu3 O7
# Co4+ Sr6 Ca2 Fe3 Co5 O24
# V4+ Mg1 V6 H6 O18
# La2.5+ Na1 La2 Se3
# Ni3+ Li8 Ni4 O8 F4
# Ni3+ Li4 Cr3 Ni3 W2 O16
# Co4+ Ba4 Co4 O12
# V2+ Li4 V4 P8 H20 O36
# Cu3+ K4 Cu2 P2 C2 O14
# Co4+ Li2 Co6 P6 O26
# V4+ V18 Ag7 O48
# Ti3+ Ti2 Cl6
# Cu1.5+ Li3 V6 Fe4 Cu2 O24
# Zr3+ Sr2 Zr24 B4 I10 Cl46
# Cu3+ Sm2 Cu4 O8
# Cu3+ Li12 Cu16 F60
# Cu3+ Y8 Cu14 O32
# V4.66666667+ V6 Pb8 O24
# Cu3+ Cu3 Sn1 P4 O16
# Mn+ K2 Zr12 Mn2 Cl28
# Gd2+ Ba2 Gd1 Cu4 O8
# Cu3+ La2 Cu4 O8
# Sm2+ Ba2 Sm1 Cu4 O8
# Ni3+ Sr18 Ni14 O42
# Cr2+ Li4 Cr8 S12 O48
# Cu+ Sr2 Nd1 Cu3 Pb2 O8
# Co4+ Ba3 Sr1 Co4 O12
# Cu+ Ba2 Y1 Cu3 Pb2 O8
# Cu3+ Na4 Cu2 P2 C2 O14
# Cu3+ Ba10 Pr1 Y4 Cu20 O40
# Ni4+ Sr4 Fe2 Co1 Ni1 O12
# Cu3+ Ba8 Sr2 Yb5 Cu15 O35
# Ni4+ Ca6 Ni4 O14
# O- Ba8 Y3 Lu1 Cu16 O32
# Cu+ Sr2 Pr1 Cu3 Pb2 O8
# V4+ V12 Ag5 O32
# Co4+ Ba1 Sr3 Co4 O12
# Cr2+ Li4 Cr4 P8 H20 O36
# Zr2+ Zr12 Mn2 Cl28
# Ni3+ Ni10 P8 O32
# V3+ Li5 V2 Fe5 O12
# V4+ V16 Ag7 O40
# V3+ Li2 V4 C8 O24
# Bi4.33333333+ K1 Ba2 Bi3 O9
# Cr2+ Li2 Zn1 Cr3 S6 O24
# Ni3+ Li16 Ni2 O10 F2
# O- Ba2 Yb1 Cu3 O7
# O- Ba4 Nd1 Y1 Cu8 O16
# Cu3+ Sr19 Cu19 O41
# Pr4+ Ba6 Pr2 Y1 Cu12 O24
# Cu3+ Nd2 Cu4 O8
# Cu3+ Cu6 P8 O28
# Cu+ Sm31 Cu3 Se48
# Fe4+ Ca4 Fe6 O16
# Ni3+ Sr18 Ni13 O42
# O- Ba4 Pr1 Y1 Cu8 O16
# La2+ La12 P4 Br12
# Cu+ K2 Ca2 Er4 Cu2 S10
# Ti3+ Lu3 Mg2 Ti1 S8
# Cu+ Sr8 Cu8 O17
# Cu3+ Zn4 Cu4 F20
# Co4+ Ba1 Sr1 Co2 O6
# Cu+ K2 Eu1 Cu1 Cl6
# Mn+ Li2 Zr6 Mn1 Cl15
# Pr2+ Pr2 Cu4 O8
# Cu3+ Li8 Cu12 F44
# V3+ V8 Cd12 Ge12 O48
# Zr3+ Na4 Zr24 B4 I10 Cl46
# Ni3+ Na12 Ni4 P2 C8 O32
# V4+ V2 Co2 O6
# In+ La4 In8 Cl20
# Cr2+ La6 Cr1 Si2 S14
# Cr2+ Li2 Cr3 Ni1 S6 O24
# Cu+ Sr4 Ca1 Ho1 Cu6 Pb4 O16
# Ni3+ Li8 Ti2 Ni6 O16
# V4.66666667+ V6 Pb10 O24
# Cu+ Sr9 Nd3 Cu12 Pb8 O32
# Cu+ Sr4 Ca1 Y1 Cu6 Pb4 O16
# Mo3+ K4 Mo16 O32
# Ni3+ Li4 Nb1 Ni3 O8
# Zr+ Zr12 O6
# Cu+ Sr4 Fe2 Cu2 Pb4 O12
# Mo3+ Li2 Mo4 O8
# In2+ Mn11 In25 O48
# V4+ Mn1 V2 P2 H8 O14
# Bi4+ Ca8 Bi16 O40
# Fe4+ Mn1 V4 Fe1 Pb4 O18
# Co4+ Sr2 Co2 O6
# Ag3+ Li2 Ag2 F8
# Cu3+ Mn1 Cu3 P4 O16
# Nb2+ Nd12 Nb10 S32
# Bi5+ Li7 Bi1 O6
# Cr2+ Cr4 S4 O16
# Cu+ Cu6 P6 O18
# Ni3+ Li4 Nb2 Fe3 Ni3 O16
# Co4+ Li8 Ti4 Co12 O32
# Ni3+ Li10 Mn4 Ni2 O16
# V2+ Li4 V2 P8 H24 O36
# Ti3+ Sr24 Ti21 S63
# Cr2+ Li5 Cr2 Fe5 O12
# O- Nd1 Mn5 Cu2 O12
# Ni3+ Li9 Si2 Ni5 O16
# Cu3+ Fe1 Cu3 P4 O16
# Cu3+ Ca8 Cu10 O20
# Co4+ Li4 Cr3 Co3 Sn2 O16
# Ni3+ Li3 Mn2 Ni1 O6
# Co4+ K2 Co2 P2 C2 O14
# Fe4+ Li16 Fe2 O12
# Cu+ Sr4 La4 Cu4 S12
# Cr2+ Cr4 O4
# Tb4+ Tb24 Se45
# V4+ V4 N2 O10
# Ni3+ Li9 Mn12 Ni3 O32
# Nd2+ Na1 Nd2 Se3
# V3+ V2 H3 O5
# Sm2+ Na1 Sm2 Se3
# Pr2+ Na1 Pr2 Se3
# Ni3+ Li2 Cr1 Ni1 O4
# Cu3+ Li1 Cu5 F12
# Cr2+ Li2 Cr2 P6 H16 O26
# V4+ V2 C4 O12
# Cr2+ Li4 Cr2 P8 H24 O36
# In+ Nd4 In8 Cl20
# Yb2+ Yb4 Te10 O26
# V3+ Na2 V6 H12 S4 O28
# In+ Sm4 In8 Cl20
# La2.33333333+ La12 Si4 Cl12
# Bi5+ Ca4 Fe4 Bi4 O20
# In+ Gd4 In8 Cl20
# Mo3.08333333+ Li11 Mo12 O24
# Zr3+ Ba30 Zr28 Se84
# Cu3+ Li8 Cu2 Sb2 O12
# O- Ba2 Eu1 Cu4 O8
# Ni4+ Zn1 Ni1 F6
# Ga2+ Ga8 P8 H16 N4 O32
# V3+ Li16 V4 Te12 O48
# Co4+ Li4 Cr3 Co3 O12
# Fe4+ Li35 Fe8 O32
# Cu3+ Li4 Nb2 Fe3 Cu3 O16
# Pr2+ Pr12 P4 Br12
# Ag2+ Ag1 Pb1 F6
# V4+ K2 V1 Cl6
# Cu3+ Li2 Cu4 F14
# Ag3+ Ca2 Ag6 P6 O26
# Ni3+ Li3 Ti1 Ni4 O8
# Cu3+ Ba8 Cu8 O20
# Ni3+ Na10 Ni4 P2 C8 O32
# V3+ V3 H5 O8
# Nb2.33333333+ K2 Sr1 Nb6 Cl18
# Cu+ Eu2 Lu2 Cu2 S6
# V4+ V8 S16 O64
# Ni3+ Li4 Al2 Ni6 O12
# Cu3+ V6 Fe4 Cu2 O24
# Bi4+ Li12 Bi4 O14
# Ce2+ Ce4 Ge1 S3
# Ce2+ Na1 Ce2 Se3
# O- Sr4 Cu4 O10
# Fe+ Li4 Fe3 Sb5 O16
# Nb3+ K1 Gd1 Nb6 Cl18
# Cu3+ Ba8 Cu8 O19
# Yb2+ Yb2 In2 Br6
# Nb2.33333333+ K1 Y1 Nb6 Cl18
# Zr2+ Hf1 Zr1 N2
# Ag2+ Ca2 Ag2 O4
# V3+ Li4 V4 P4 H24 O30
# Cr2+ La6 Cr1 Ge2 S14
# Nb2.33333333+ K1 Lu1 Nb6 Cl18
# Ni3+ Cr3 Ni1 S6 O24
# La+ K4 La2 Ta12 Br30 O6
# Cu3+ Co1 Cu3 P4 O16
# Cu+ Sr8 Mn4 Cu6 S8 O8
# Cr2+ Li3 Cr1 Fe4 O8
# Hf2+ Hf2 N2
# Ti2+ Hf1 Ti1 N2
# Ni3+ Ta2 Ni22 B8 O40
# O- K10 H6 S8 O36
# Cu+ Li12 Cu8 S12 O48
# Ni3+ Li4 Cr3 Ni3 Te2 O16
# V2+ Li4 V2 P8 H32 O40
# Bi5+ Li6 Bi2 O8
# Cu+ Pr4 Eu4 Cu4 S12
# Ni3+ Li6 Ti2 Ni6 O16
# Cr2+ Cr2 Si2 H24 O12 F12
# Mo2+ Zn2 Mo1 W1 O6
# Co4+ Li5 Mn1 Co2 O8
# Co4+ Li2 Cr2 Co2 O8
# Yb2+ Yb6 Ge2 O2
# Co4+ Li4 Nb2 Co3 Ni3 O16
# Co4+ Li8 Ti2 Co10 O24
# Cu3+ Cu4 P4 O16
# V2+ Li4 V2 Cl8
# Fe4+ Li8 Fe4 O12
# Ni3+ Li4 Al1 Ni3 O8
# Cr2+ Li4 Cr2 P8 H32 O40
# Cr2+ Y6 Cr1 Si2 S14
# V4+ V2 Ni10 B4 O20
# Co4+ Li4 Ti2 Co3 Ni3 O16
# Ti3+ Na2 Ti10 N10 Cl10
# Ni3+ Li5 Cr2 Ni3 O10
# Cu3+ Cu9 P8 O32
# Yb2+ Yb4 Sb2 O1
# Ni3+ Li10 Ni6 Sn4 O20
# Ti3+ Ti2 S2 Cl2
# Ta2+ Sm4 Ta24 Br52 O12
# Cu+ Sr3 Cu3 Pb3 Cl1 O8
# Co+ La6 Co2 Si2 S14
# Ni3+ Li4 Ni3 Sn5 O16
# Zr2+ K4 Zr6 Fe1 Br18
# Ni3+ Li47 Ni8 O32
# Fe+ La6 Fe2 Si2 S14
# Ni3+ Nb2 Ni22 B8 O40
# Ni3+ Li4 Fe3 Ni3 W2 O16
# Zr2.66666667+ Zr24 S32
# Cu+ Sr4 Mn2 Cu3 Se4 O4
# Ti3+ Ca1 Ti2 S4
# Cu3+ Cu8 P6 O24
# Cu+ Na4 Cu8 P4 Cl2 O18
# V3+ La4 V4 S12
# Co4+ Ca2 Co3 O8
# Ni3+ Ti4 Ni15 O24
# Bi4+ Mg8 Bi16 O40
# Cr2+ Dy4 Cr1 Se7
# Cr2+ Li2 Mg1 Cr3 Se3 S3 O24
# Mo3+ K2 Li1 Mo1 Cl6
# Fe4+ Li4 Mn3 Fe5 O16
# Cu3+ Tb1 Mn4 Cu3 O12
# Mo3+ K2 Na1 Mo1 Cl6
# V3+ V2 Cu2 O4
# Fe4+ Li4 Fe6 Sn2 O16
# Co4+ Li4 Mn5 Co3 O16
# V3+ V1 Ag1 S2 O8
# V4+ V4 Sb16 O48
# Cu3+ Er1 Mn4 Cu3 O12
# V2+ K2 V2 Cl6
# Cu3+ Nd1 Mn4 Cu3 O12
# O- Ni4 P2 O10
# Ni3+ Li4 Mn3 Ni3 Sn2 O16
# Yb2+ K2 Yb2 I6
# Ce2+ Ce12 P4 Br12
# Ni3+ Li5 Mn2 Ni3 O10
# Ni3+ Li6 Fe5 Ni1 O12
# Ni3+ Ni2 F6
# O- Sr2 Ag2 O4
# Zr3+ Li1 Zr2 S4
# Cu+ Gd1 Mn4 Cu3 O12
# Ni3+ Li40 Ni8 O32
# Ni3+ Li4 Fe3 Ni1 O8
# Zr3+ Zr64 S127
# Bi5+ Ca4 Co4 Bi4 O20
# Co4+ Li8 Fe9 Co1 O20
# Ti3+ Ca3 Ti8 S16
# Zr3+ Zr2 N2
# Cu+ Sr4 La4 Cu4 Se12
# Sm2+ Sm10 Sb3 Se7
# Cu3+ Eu2 Cu4 O8
# Cu+ Li7 Mn12 Cu5 O32
# Mo3+ Zn3 Mo3 O8
# Cu3+ Li2 Cu6 F20
# Zr3+ Zr63 S128
# Fe4+ Li3 Fe4 O8
# Ni3+ Na8 Ni4 C8 S2 O32
# Fe5+ Li12 Fe4 O16
# V2+ Li10 V10 Cl32
# V2+ Li2 V2 P6 H28 O32
# V4+ Ba2 Ti1 V1 S6
# Ni3+ Li4 Fe2 Ni3 Sb3 O16
# V4+ V6 H12 O20
# Zr+ Zr4 Br4 O1
# Ag2+ V8 Ag6 O24
# Co4+ Li14 Mg1 Co13 O28
# Ni3+ Mn2 Ni10 B4 O20
# Ti3+ Ca1 Ti4 S8
# B3- Na8 Zr6 B1 Br20
# Tb4+ Tb12 Ge5 S28
# Ni3+ Li8 Ni6 Sb2 O16
# Ni3+ Li3 Fe2 Ni1 O6
# Ni3+ Li6 Ni4 Sn2 O12
# Cu3+ Li4 Fe3 Cu1 O8
# Cr2+ Y6 Cr1 Ge2 S14
# Cu+ Li5 Cu3 Sb2 O10
# Co4+ Li3 Fe3 Co1 O8
# Cu+ V18 Cu20 O57
# Co4+ Li8 Co4 O12
# Ag3+ Li3 Ag6 F18
# Mo3+ Zn2 Mo4 O8
# Ce2+ Ce3 Ge1 S2
# Fe4+ K2 Li8 Fe2 O10
# Ce2+ La4 Ce2 Te8
# Fe4+ Na8 Li9 Fe4 O16
# Ni3+ Li4 Nb2 Ni6 O16
# O- Cu10 P6 O26
# Co4+ Be4 Co2 N4 F28
# Ni3+ Mn4 Ni2 O8
# Zr3+ Eu2 Zr5 Se10
# Cu+ V30 Cu34 O95
# Ni3+ Li3 Ni3 S6 O24
# O- Sr6 Ca4 Cu17 O29
# Cu+ Yb2 Eu2 Cu2 S6
# O- K8 P4 H16 O28
# B3- Tb12 B4 Cl12
# Bi4+ Ca2 Bi8 O18
# ...
# Cu+ Nb1 Cu3 Se2 S2
# Cu+ Cr4 Ga1 Cu1 Se8
# Zr3+ Zr20 C18
# Ho2+ Ho4 Si3 Ge1
# B2- Ti1 Nb8 B12
# Ga2+ Ga12 Te12 Cl4
# Tb2+ Tb8 Hf12 Si16
# Ho2+ Ho4 Si4 Ni4
# Co+ Tb2 Co12 P7
# Ti3+ Ti10 Si6 C2
# Nb4+ Nb4 P8 S32
# Ga2+ Cr8 Ga3 Cu1 Se16
# B2- Hf1 Nb8 B12
# Cu+ In5 Cu1 S8
# Cu+ Ca20 Cu8 N16
# Cu+ Sm4 Cu5 P7
# Ti3+ Ti24 Al2 Si6 C16
# Ni3+ Ni4 Ag4 O8
# Ta3+ Ta4 Nb2 Te2 I14
# Ni+ Li2 Ca4 Ni2 N4
# Co+ Er2 Fe6 Co6 P7
# Cu+ V1 Cu3 Se2 S2
# Ta4+ Ta1 Ti1 Te4
# Ni+ Fe1 Ni35 S32
# Dy2+ Dy12 Ni4 Ge8
# Cu+ Eu4 Zn4 Cu2 P6
# Cr2+ Ti2 Cr1 Te4
# Yb2+ Yb1 Mg2 Sb2
# Dy2+ Dy4 Si4 Ni4
# Cu+ Al1 Ga1 Cu2 Se4
# La+ La30 Ge18 P2
# Cu+ La1 Zn1 Cu1 P2
# B3- Ti1 B2 W1
# Cu+ Ta1 Cu3 Se3 S1
# Co+ La2 Co2 N6
# Cu+ Ga2 Cu1 Ag1 S4
# Ti2+ Ti6 Sn2 C4
# Nb3+ Nb10 Si6 N2
# Ni+ Eu6 Ni20 P13
# Cu+ Zn1 Ga1 Cu1 Se3
# In2+ In10 Sn1 S14
# In+ Cr5 In1 Se8
# Ta2+ Hf1 Ta1 B2
# Cu+ Y1 Zn1 Cu1 P2
# Cu+ Al1 Cu1 Sn1 Se4
# Co+ Sm2 Co12 P7
# Cu+ In2 Cu1 Se3 Br1
# W3+ Ca6 W6 N10
# Ni3+ Y3 Si3 Ni1
# Cu+ Zn1 In2 Cu2 S5
# La2+ La20 Mn8 Te7 C12
# Ag2+ Cr4 Cd1 Ag1 Se8
# Tb2+ Tb4 Si4 Ni4
# Cu+ Er1 Zn1 Cu1 P2
# Cu+ Cd2 Ga1 Cu1 Se4
# Cu+ Sm1 Zn1 Cu1 P2
# Cu+ In5 Cu1 Se8
# Ni+ Eu4 Ni14 P8
# Co4+ Co4 N16 O48
# Cu1.5+ K1 Cu2 S2
# In2+ In18 Sn8 S34
# Co1.5+ Lu6 Co4 Si6
# B0.33333333- K24 B54 Se54
# Yb2+ Yb2 Ni10 P6
# Nb2+ Hf1 Nb1 B2
# Cu+ Al1 In1 Cu2 Se4
# Cu+ Li2 Ca4 Cu2 N4
# Cu+ Ga2 Cu2 Se2 S2
# Cu+ Na1 Mn1 Cu1 Se2
# Ce2+ Ce3 Si4 Ni4
# Fe5+ Fe2 Co2 S8
# In2+ In16 Bi8 Pb3 S38
# Ni1.22222222+ Ca5 Ni9 P7
# Dy2+ Dy3 Si3 Ni1
# Tb4+ Tb3 Si3 Ni1
# Cu+ Ta1 Nb1 Cu6 Se8
# Ti3+ Ta1 Ti1 C2
# Ga2+ Ga12 Te12 Br4
# Cu+ Ga7 Cu3 Se12
# Mo3+ K6 Mo6 C5 Se8 N5
# Nb+ Nb24 I42 Br2
# In2+ In16 Bi12 S40
# In+ In2 Ga2 Se4
# Cu+ In3 Cu1 Se5
# V3+ V10 Si6 N2
# Ni+ La3 Si7 Ni3
# Zr+ Zr28 Sb16
# La2.25+ La4 H9
# Co1.5+ Er6 Co4 Si6
# B1.25- Er4 Ta1 V7 B24
# Ta4+ Zr1 Ta1 C2
# Mo3+ In6 Mo30 Se38
# Bi+ Bi8 I2 Br6
# V3+ Ta1 V1 Cu6 Se8
# Cu+ Ce1 Zn1 Cu1 P2
# V3+ Nb1 V1 Cu6 Se8
# Ta3.25+ Ta4 Ga1 Te6 Se2
# Cu+ Li14 Cu24 S20
# Ce2+ Ce4 Ni4 Bi3 Sb5
# Ag2+ Cu2 Ag1 O4
# Zr3+ Zr3 H1 C2
# Zr2+ Zr2 H1 C1
# La2.5+ La4 H10
# Cu+ Cd2 In1 Cu1 Se4
# Yb2+ Yb2 Ga12 Te20
# Mo2+ Mo30 Pb6 Se38
# Nd2+ Tb1 Nd1 Ni2 Ge4
# Ho2+ Ho6 Co4 Si6
# O- Cu1 Ag1 O2
# Nb4+ Zr3 Nb1 C4
# Nb4+ Hf1 Nb1 C2
# B1.33333333- Lu16 V20 B72
# Fe+ Li2 Ca4 Fe2 N4
# V3+ Ti6 V4 Si6
# Fe4+ Fe1 Co3 S8
# Co1.5+ Y6 Co4 Si6
# La+ La5 Er5 Ge6
# Ti2+ Ti2 H1 C1
# Nd2+ Nd12 Ni4 Ge8
# Cu+ In2 Cu2 Sn2 S8
# Cu+ Ba6 Cu34 S27
# Fe+ Ho2 Fe12 P7
# Ce2+ Ce4 Ni2 Ge6
# Dy2+ Dy6 Co4 Si6
# Co4+ Co2 Ni4 S8
# Cu+ Er4 Cu12 Te12
# Cu+ Ga3 Cu3 Si1 Se8
# B2- Zr1 Nb1 B2
# Cu+ Ta1 Cu3 Te1 Se2 S1
# Cu+ In2 Cu1 Se3 I1
# Mo2+ Sn6 Mo30 Se38
# Cu+ Co5 Cu1 S8
# Cu+ Al1 In3 Cu4 Se8
# In2+ In12 Te12 Br4
# Ce2+ Ce1 Si1 Ni1
# Cu+ Cr4 Fe1 Cu1 Se8
# Ni4+ Fe1 Co16 Ni1 S16
# Nd2+ Nd2 Si2 Ni2
# Bi3- K2 Ca2 Bi2
# O- Cu4 N2 O12
# B2- Nb1 V1 B4
# Nb2.5+ K1 Nb6 Te8
# Ta3+ Ta10 Si6 N2
# Nd2.5+ Nd4 H10
# Cu+ In1 Cu1 Ge1 S4
# V2+ V11 Fe1 B8
# Cr2+ V9 Cr3 B8
# Ni4+ Ce2 Si3 Ni1
# Tb2+ Tb6 Co4 Si6
# V3+ V2 I6
# Cu+ In2 Cu1 Ag1 Sn2 S8
# Ce2+ Ce3 Ni4 Ge4
# Ni4+ La3 Si3 Ni1
# Cu+ In2 Cu1 Ag1 S4
# Ni4+ Nd3 Si3 Ni1
# Nb2.5+ Na1 Nb6 Te8
# Hf2+ Hf2 H1 C1
# Cu+ Sm2 Cu6 Te6
# Nd2+ Nd4 Ni4 Ge4
# Co+ Y4 Co4 Si4
# La+ La2 Ga2 Si2
# Ni1.8+ Lu4 Si12 Ni20
# B2- Ta1 V1 B4
# Sm2+ Sm4 Zn4 Ge4
# Cu+ In2 Cu2 Se2 S2
# Nd2+ Nd4 Zn4 Ge4
# Ni1.8+ Dy4 Si12 Ni20
# Tb+ Tb1 Ni1 Bi1
# Cu+ Ga2 Cu1 Ag1 Se4
# Ni4+ Y1 Cu1 Si2 Ni1
# Co4+ Co4 S8
# Ti2+ Ti8 C5
# Ta+ Ta12 Nb6 Te4 S6
# Ni3+ Li1 Ni1 P2 S6
# Co4+ Co4 P2 S6
# Cu+ Y2 Cu6 Te6
# V2+ V1 Co2 Se4
# Cu+ In1 Ga1 Cu2 Se4
# Co4+ Co3 Ni3 S8
# B3- V1 Cr1 B2
# Nb4+ Ta3 Nb3 Te12
# Yb2+ Yb4 H8
# Cu+ Tb2 Cu6 Te6
# Cu+ Cu8 Si4 S12
# V4+ La4 V4 Sb12
# Ni3+ Fe2 Ni2 S8
# Pr2+ Pr2 Si2 Ni2
# Al2+ Sr1 Li1 Al1 Sb2
# Cu+ Ga1 Cu1 Sn1 Se4
# B2- Ti1 Cr1 B4
# Cu+ Cu2 Cl2
# Cu+ Ce4 Cu5 Sb8
# Cu+ K1 Zn1 Cu1 Te2
# La+ La2 Al1 Ge3
# Cu+ Mn1 Cu2 Sn3 S8
# Cr2+ Mn2 Cr1 I6
# V3+ Mn2 V2 P4
# Pr2+ Pr3 Si3 Ni1
# Cu+ Dy2 Cu6 Te6
# Ti2+ Ti6 C4
# Tb2+ Tb4 Zn4 Ge4
# Ni3+ Cr3 Cu2 Ni1 Se8
# La2+ La4 Ga1 Si3
# Cu+ In1 Ga1 Cu1 Ag1 Se4
# Cu+ In4 Ga2 Cu6 Se12
# Ga2+ Eu4 Ga8 P8
# Ti2+ Ti10 Si2 Sb4
# Ta+ Ta1 Be1 B1
# Cu+ Cr2 Cu2 Sn2 Se8
# Cu+ Cu2 Bi8 Pb6 S19
# Yb2+ Yb18 Zn8 Bi18
# Fe+ Ti1 Fe2 Si1
# Cu+ In3 Cu3 Si1 Se8
# La+ La11 Ni4 Ge6
# Pr2+ Pr2 Ga2 Si2
# Ga2+ Nd2 Ga2 Si2
# V3+ V2 Cr2 P4
# Nb4+ Nb24 Te96
# Ni+ Nd1 Ni1 Bi1
# Cu+ Li4 Cu8 S6
# Cu+ K1 Fe1 Cu1 Se2
# Ag2+ Ag13 Bi14 I56
# Cr2+ Cr4 Cu3 Se8
# Ti2+ Ce2 Ti2 Ge6
# Bi+ Bi12 I6 Br6
# Ag2+ Ag15 Bi16 I64
# Fe5+ Sm2 Fe2 Si4
# Mo2+ Ti3 B4 Mo3
# Cu+ Ho2 Cu6 Te6
# Ta+ Ta4 Se1 S1
# Cu+ In1 Cu1 Se2
# Nb4+ Ti1 Nb1 C2
# B2- V3 Cr3 B8
# Ni4+ Ce1 Cu1 Si2 Ni1
# Co+ Ce1 Co1 Si3
# Cu+ Cd1 Cu2 Sn3 S8
# Ta2+ Ta1 B2 Mo1
# Bi3- La6 Ni6 Bi8
# Ta2+ Ta4 Si4 Ni4
# Ti3+ Ta2 Ti2 Nb1 C5
# Cu+ Mn2 Ga4 Cu6 Se12
# Sm2+ Sm2 Ga2 Si2
# Co4+ Co2 Cu2 Ni2 S8
# Ni3+ Co1 Ni5 S8
# Tb+ Tb2 Al2 Ge2
# Nb4+ Zr1 Nb1 C2
# Yb2+ Yb1 Mn1 Cu1 P2
# Ho2+ Ho4 Zn4 Ge4
# Cu+ In2 Cu1 Ag1 Se4
# Cu+ In1 Cu1 Sn1 Se4
# Ga+ Ba4 Ga2 Ge2 N2
# Cr2+ Cr4 Cu4 P8 S24
# Nd2+ Nd12 Co4 Ge8
# Nb2+ Nb4 Ni4 Te8
# Cu+ Li1 In2 Cu1 Te4
# Tb4+ Tb10 Si4 B16
# Nd2+ Nd4 Co3 Ge8
# La+ La2 Al2 Si2
# Fe4+ Ce2 Fe2 Si4
# Ti3+ Ti4 W1 C5
# Nb2+ Hf12 Nb8 Ge16
# Cu+ Y1 Cu1 Ge1
# B+ B18 Br18
# Cu+ Yb2 Cu6 Te6
# Cu+ Cu3 Bi4 I16
# V4+ Pr4 V4 Sb12
# Cu+ Cu2 Bi8 Pb3 Se3 S13
# Ce2+ Ce4 Ni6 Ge10
# Cu+ La1 Cu1 Si2 Ni1
# Zr2.75+ Zr4 Si3 Sb5
# Cu+ Cr2 Cu2 S8
# Cu+ Co1 Cu2 Sn3 S8
# Cu+ Zn2 Cu4 Ge2 Se4 S4
# Nb+ Nb3 Ni9 P6
# Zr+ Zr10 Cr1 Sb5
# Co+ Co3 Ni6 S8
# Ho2+ Ho6 Fe4 Si6
# Ni+ Ti2 Fe1 Ni1 Sb2
# In2+ In11 Cu9 Se20
# Fe5+ Tb2 Fe2 Si4
# Hf2+ Hf6 Ni6 Sb8
# Ho2+ Ho30 Si18 C2
# Cu+ La1 Cu1 Ge1
# Nb2+ Nb10 Si2 B4
# Tb+ Tb1 Cu1 Ge1
# Nb+ Nb4 B4 Mo2
# Y+ Y2 Sn2 Ge2
# Cu+ Zn1 Fe1 Cu4 Ge2 S8
# V4+ Sm4 V4 Sb12
# B0.66666667+ Na12 B36 Se34
# Mo2.66666667+ Hf8 Si16 Mo12
# Co+ Ti1 Fe1 Co1 Si1
# Cu3+ Fe12 Cu8 S40
# Cu+ Zn1 Cu2 Si1 Se4
# Cu+ Cu4 Sn7 S16
# Ni+ Li5 Ni9 P7
# Fe4+ Fe8 Ni2 Se20
# O- Cd2 Ag4 O8
# Cu+ Mn1 Ga1 Cu2 Se4
# Cu+ Cu4 Bi10 Pb10 S28
# B- Lu4 Co4 B16
# Nb2+ Nb10 Si3 B3
# Ti2+ Ti2 C1
# Co1.5+ Ho3 Co2 Si7
# B3- Ho2 B6 Mo2
# B- Ho4 Fe4 B16
# Cu+ Y1 Cu1 Si1
# V3+ Mn3 V1 P4
# V4+ Dy4 V4 Sb12
# Ce2+ Ce12 Co4 Ge8
# Cu+ Nb1 Cu3 Te2 Se2
# Ga+ Ce2 Ga2 Si2
# Co4+ Co2 Ni2 S8
# Cu+ Yb1 Zn1 Cu1 P2
# Sm2+ Sm1 Zn1 Si1
# V4+ Ti1 V1 C2
# Cu+ Cu1 Bi5 S8
# Cu+ Zn1 Fe2 Cu6 Sn3 S12
# Cu+ Cu2 Ni1 Sn3 S8
# Cu+ Cu2 Bi6 Pb2 S12
# Cu+ Tb2 Zn1 Cu1 Si2
# Ga+ Ce2 Ga2 Ge2
# B3- V10 Si6 B2
# Tb2+ Tb6 Fe4 Si6
# Ni+ Er12 Ni36 Ge24
# B3- Dy2 B6 Mo2
# B2- Er4 Co4 B16
# Cu+ Dy2 Zn1 Cu1 Si2
# Tb2+ Tb1 Zn1 Si1
# Nb2+ Nb6 Te8 Pb1
# Cu+ Er1 Cu1 Si1
# W2+ Te6 Mo3 W1 Se2
# Cu+ Dy1 Cu1 Si1
# Ti3+ Ti3 W1 C4
# Co+ Mn12 Fe4 Co8 P12
# Cu+ Cu12 Bi8 S16 Cl4
# Cu+ Pr1 Cu1 Ge1
# Cu+ Ta1 Cu3 Te2 Se2
# Ni+ Ni18 S16
# Cu+ Tb1 Cu1 Si1
# Cu+ Lu1 Cu1 Ge1
# Cu+ Ho1 Cu1 Si1
# Nb3+ Nb2 Cu1 Te4
# Cu+ Mn2 Fe3 Cu10 Sn5 S20
# Cu+ Ho2 Zn1 Cu1 Si2
# Ni+ Li14 Ni42 P28
# B- Ho6 B14 Mo2
# Co+ Mn3 Co1 P4
# Nb2+ Nb6 In1 Te8
# Cu+ Zn1 Fe4 Cu10 Sn5 S20
# Cu+ Gd1 Cu1 Si1
# Dy2+ Dy1 Zn1 Si1
# Gd2+ Gd1 Zn1 Si1
# B- Ho4 Co4 B16
# Fe4+ Y4 Fe4 B16
# Co+ Lu6 Co30 Si18
# V2.1+ V10 Si6 B1
# Cu+ Cu2 W1 Se4
# La+ La24 In8 Ge8
# V3+ V5 Te8
# Bi3- Nd6 Ni6 Bi8
# Ni+ Pr6 Ni6 Bi8
# Co+ Er2 Co2 Si6
# La+ La10 Cu2 Ge6
# Fe4+ Tb4 Fe4 B16
# Bi+ Bi8 I6 Br2
# Cr2+ Cr3 Te2 Se2
# Co4+ Co8 Cu6 Ni4 Se24
# Co+ Mn4 Fe2 Co2 P4
# Ta2+ Ta8 Ni12 Te20
# Sm2.8+ Sm10 Si4 B16
# Co+ Ho6 Co30 Si18
# Ho2+ Ho1 Zn1 Si1
# Cu+ Na1 Mn1 Cu3 Se4
# B- Dy4 Co4 B16
# Co+ Dy6 Co30 Si18
# Co+ Y6 Co30 Si18
# Ni1.22222222+ Mg5 Ni9 P7
# B- Er2 B4 C1
# Cu+ Sm1 Cu1 Si1
# Co+ Eu2 Co4 Si3 Ge1
# B2- Ce4 Mn4 B16
# B- Dy6 B14 Mo2
# Ta2+ Ta12 C8
# V3+ V1 Cu3 Te2 Se2
# Cu+ Zn2 Ga1 Cu1 Te4
# W3+ Nb1 B2 W1
# Cu+ Ga2 Cu2 Te2 Se2
# Zr+ Zr1 Be1 B1
# Mo2+ Ti6 Si6 Mo4
# Cu+ Cu6 Sn1 W1 S8
# La2+ La10 Co2 Ge6
# Ce2+ Ce2 Si2 Ge2
# B2- Y4 Co4 B16
# Cu+ Fe2 Cu3 Sn6 Se16
# Nb2+ Nb4 Fe4 Si4
# Nd2+ Nd4 Co6 Ge10
# Co+ Be1 Co2 Si1
# Cu+ Fe1 Cu2 Ge1 S4
# Cu+ Zn2 In1 Cu1 Te4
# Cu+ Cu12 Bi8 S16 Br4
# Pr2+ Li4 Pr4 Si6
# Ni3+ Fe2 Ni2 Se8
# Co4+ Co4 Se8
# B2- Tb4 Co4 B16
# Cu+ La1 Cu1 Si1
# Sm2+ Sm1 Mg5 Sb4
# B- Ho2 B4 C1
# Cu+ Cu2 Sn1 S3
# Ni3+ Ni6 Se8
# Ta+ Ta5 Nb5 Si6
# O- Cu1 Br1 O2
# W2.66666667+ Ti1 P4 W3
# Ta2+ Ta8 Al2 C6
# Ni1.76470588+ Ce2 Si9 Ni17
# Cu+ Ga2 Cu1 Ag1 Te2 Se2
# Ti3+ Ti6 Cr6 Si10
# In+ In1 Te5 Pb4
# Co4+ Co2 Ni2 Se8
# Co+ Co3 Ni3 P3
# Cu+ Ce1 Cu1 Ge1
# Zr3+ Zr8 Al6 C12
# Cu+ Zn3 Fe2 Cu10 Sn5 Se20
# Ta+ Ta36 Te18 S6
# Co+ Zr3 Co9 B6
# Cu+ Nd1 Cu1 Si1
# Cu+ Cu8 Ge4 S12
# Tb+ Tb20 Co4 Bi8
# Ni4+ Fe3 Ni1 P4
# Cu+ In1 Ga1 Cu2 Te2 Se2
# B- Tb6 B14 Mo2
# Mo2+ Er4 B28 Mo12
# Ni+ Sr10 Li24 Ni1 N15
# Cu+ Cd2 In1 Cu1 Te4
# Zr+ Zr12 Fe8 Sb12
# Co4+ Co2 Cu2 S8
# B3- Nb1 B4 Mo3
# Cu+ Cd2 Cu4 Ge2 Se8
# B1.28571429- Dy4 B28 Mo12
# Nb4+ Zr1 Nb3 C4
# Nb3+ Nb24 Fe18 Si30
# Cu+ Cd2 Ga1 Cu1 Te4
# Cu+ Al1 Cu1 P2 Se6
# Tb4+ Tb8 Si14
# Cu+ Cu1 Br1
# Cu+ In2 Cu1 Ag1 Te2 Se2
# Cu+ In2 Cu2 Te2 Se2
# B1.28571429- Tb4 B28 Mo12
# Bi2+ Ag3 Bi8 S13
# Fe4+ Ce4 Fe4 B16
# Cu+ Fe1 Cu6 Ge1 S8
# Cu+ Pr1 Cu1 Si1
# Zr+ Zr8 Ni4 H18
# Cu+ Ga6 Cu6 Te8 Se4
# Yb2+ Yb2 Zn2 Ge2
# Ta2+ Ta4 C3
# Co4+ Co1 Ni2 Se4
# Ti2+ Mg1 Ti7 H16
# B- Tb2 B4 C1
# Ni3+ Co2 Ni2 Sb4 S4
# Cu+ Zn1 Cu4 Sn2 Se8
# Y+ Gd1 Y1 Co4 B4
# Ta2+ Ta3 V7 Si6
# Bi5+ Bi4 I20
# Cr2+ Cr6 N4
# Cu+ Ga5 Cu1 Te8
# Nb2+ Ti5 Nb5 Ge6
# Cu+ Mn1 Cd1 Cu4 Ge2 Se8
# Ni4+ Ni1 Te1 Se1
# Cu+ Li4 Cu2 P2
# B0.5- Ce1 Eu1 B12
# Cu+ In5 Cu1 Te8
# Sm2+ Sm3 Mg21 Sb16
# Ni3+ Ni4 Se4 S4
# La2+ La6 Cu24 P12
# Ti2+ Ti6 Fe6 Ge6
# Cu+ Zn2 Fe3 Cu10 Sn5 Se20
# Mo3+ Mo30 N32
# V2+ Mn3 V17 Si12
# La2+ Ca1 La3 Si8
# Ce2+ La1 Ce1 Mn4 Si4
# B0.5- La1 Ce1 B12
# B2- V1 Cr1 B4
# Co+ Co7 Ni1 P4
# Nb+ Nb4 Ni10 Te12
# Cu+ Ce1 Cu1 Si1
# Nb+ Nb10 Ge6 C1
# Co4+ Co1 Te1 Se1
# Y+ La1 Y3 Mn4 Si4
# Bi3- Li6 Bi2
# Ce2+ Ce5 Nd5 Si6
# Ga2+ Eu1 Ga1 Si1
# Cu+ Cd2 Fe3 Cu10 Sn5 Se20
# B- Gd4 Ni2 B20
# B0.5- La1 Ce3 B24
# Fe+ Zr6 Fe16 Si7
# B0.5- La1 Eu1 B12
# B1.5- Nb4 B20 Mo11
# Ag2+ Ag1 Sn1 Se2
# Cu+ Ce5 Cu19 P12
# Ta+ Ta12 Te2 Se4
# Nd2+ La2 Nd1 Mn6 Si6
# Pr2+ Pr6 Cu24 P12
# In+ Sr4 Li3 In1 Ge6
# Cu+ Sr2 Li7 Cu1 N4
# Pr2+ La1 Pr1 Mn4 Si4
# V2.4+ V10 Si6
# Ni4+ Pr4 Ni2 B20
# Cu+ Cu16 Bi16 S36
# B2- Tb1 Er4 Ni10 B10 C5
# Nb+ Nb6 Al2 C4
# Al2+ Al2 Si2 Te6
# Cu+ Fe4 Cu26 Ge4 S32
# Nb3+ Ta1 Nb1 C2
# Ce2+ Ce6 Cu24 P12
# Ce2+ Ce1 Zn1 Si1
# Yb2+ Yb4 Co4 Ge4
# B- Tb4 Ni2 B20
# V2+ V1 Cu3 Te3 Se1
# Ag2+ Ag7 N1 O11
# Cr2+ V2 Cr1 Te4
# B1.2- Er4 Lu1 Ni10 B10 C5
# Cu+ Cd1 Cu2 Se2
# B- Dy4 Ni2 B20
# Ag2+ Ag10 Sn12 S32
# B2- Ta1 Cr1 B4
# Nb+ Nb4 Ge2 C2
# Cu+ Cd1 Fe4 Cu10 Sn5 Se20
# Ni+ Be1 Si1 Ni2
# W2+ Te8 Mo3 W1
# In2+ In1 Sn1 Te2
# B0.5- La1 Gd1 B12
# B2- Tb1 Y1 Ni4 B4 C2
# B0.5- La1 Sm1 B12
# B2- Tb1 Y2 Ni6 B6 C3
# Ni4+ Co1 Ni1 Te4
# B2- Tb1 Y3 Ni8 B8 C4
# V2+ Al2 V8 C6
# Ho2+ Ho2 Mn4 Si2 C2
# Ni4+ Y4 Ni2 B20
# Zr+ Zr1 Fe1 Sb1
# B1.2- Tb4 Y1 Ni10 B10 C5
# Ti2+ Mg1 Ti3 H8
# Fe4+ Li36 Fe10 N24
# B2- Er4 Al4 B16
# Bi3- Mg6 Bi2 P1 N1
# B- Ho4 Ni2 B20
# Cu+ Cr1 Cu1 P2 Se6
# Dy2+ Dy2 Mn4 Si2 C2
# B- Ho4 Al4 B16
# Fe+ Mn3 Fe9 P6
# Bi3- Na1 Li2 Bi1
# W2+ W12 I24
# Cu+ Cu8 Ag4 Bi4 Pb4 S16
# La+ La1 Mn1 Cu1 Ge2
# B2- Ta3 Al1 B8
# La2+ La3 Y1 Mn4 Si4
# Mo2+ Ti2 Si6 Mo1
# V3+ V4 H1 C3
# In2+ In1 Sn2 Te3
# In1.66666667+ In3 Ga1 Te4
# Ni3+ Ni19 Se20
# Hf2+ Hf4 Al6 C8
# Cu+ Ga2 Cu1 Ag1 Te4
# Tb2+ Tb2 Mn4 Si2 C2
# W3+ Te6 Mo2 W1
# Cu+ In1 Ga1 Cu1 Ag1 Te4
# Sm2+ Sm2 Fe2 Ge4
# Cu+ Ta1 Nb1 Cu6 Te8
# Ni3+ Ni23 Te42
# Cu+ In4 Cu1 Ag3 Te8
# Co1.125+ La2 Co16 Si10
# Nb4+ Nb8 Si2 C6
# B0.5- Nd1 Eu1 B12
# B2- Yb4 Mn4 B16
# B0.5- Ce1 Sm1 B12
# Cu+ Eu12 Cu12 Ge12
# In+ Eu4 In4 Ge4
# B3- Mn1 Cr1 B2
# Cu+ In2 Cu1 Ag1 Te4
# Cu+ Zn2 Cu10 Sb4 S13
# Cu+ In1 Ga1 Cu2 Te4
# B0.5- La1 Sm3 B24
# Cu+ In1 Cu1 Te2
# Fe+ Ti1 Fe2 Ge1
# Y+ Y4 Ga6 Fe1 Ge6
# Cu+ In4 Cu3 Ag1 Te8
# Zr2+ Zr4 Cu2 H10
# Nb2+ Nb10 C7
# W2.33333333+ Ta1 B4 W3
# B0.5- Sm1 Eu1 B12
# Cr2+ Cr1 B2 Mo1
# Cr2+ Cr5 Te8
# Ni+ Ga4 Si8 Ni24
# Cu+ Cu8 Ge4 Se12
# Sm2+ Nd1 Sm1 Mn4 Ge4
# La2+ La1 Ag2 Ge2
# Ta2+ Ta4 Fe5 Te12
# Zr+ Zr1 Ti1 Ni2 H6
# Co4+ Mn2 Co2 Si4
# Mn+ La2 Mn3 Cu1 Ge4
# Fe+ Fe6 Ni2 P4
# Nb4.5+ Nb2 Al1 B6
# B0.5- Pr1 Sm1 B12
# Mo2.2+ Nb5 Si6 Mo5
# Cu+ Cu12 H24 C12 N24 Cl12
# Cu+ Cd2 Cu10 Sb4 S13
# La2+ Ca1 La1 Si4
# Cu+ Mn2 Cu10 Sb4 S13
# Cu+ Cu3 Ag3 P2 S8
# B0.5- Yb1 Sm1 B12
# B2- Ce1 Co2 B2 C1
# Co+ Ti1 Fe1 Co1 Ge1
# Mn+ Nd1 Mn1 Fe1 Ge2
# Mn+ Nd2 Mn3 Fe1 Ge4
# Co+ Er2 Co18 Si8
# Mo2.33333333+ Ni1 Te8 Mo6
# Co4+ Co19 Te34
# W2+ Te8 Mo2 W2
# Mo2+ Ta4 Si6 Mo6
# Fe+ Fe12 P6
# Cr2+ V1 Cr2 Te4
# B0.5- Sm1 Gd1 B12
# Mo2+ Ti1 Si6 Mo2
# Ni+ Ni32 P12
# Mn+ Nd2 Mn1 Fe3 Ge4
# Cu+ K1 Cu7 S4
# B2- Yb4 Cr4 B16
# Nb2+ Nb10 Ge7
# Co+ V1 Fe1 Co1 Si1
# Co+ Nd2 Fe1 Co17 Si8
# Zr3+ Zr4 Al6 C8
# B3- Mn1 B4 Mo3
# V2+ Ti1 V1 H4
# Mo3+ Nb3 Si12 Mo3
# W2+ Ti2 Si6 W1
# Cu+ Cu4 Bi4 P8 Se24
# Sm2+ Sm2 Fe4 Si2 C2
# Cu+ Co1 Cu2 Ge1 Se4
# Mo2+ V2 Si6 Mo8
# Cu+ Li8 Cu1 N3
# Cu1.25+ Li5 Cu4 P6
# Ni1.44+ Si9 Ni25
# Ni3+ Ni3 Te4
# B0+ Si4 Ni9 B2
# Ag2+ Ag2 O2
# Cu+ Ga1 Cu1 Te2
# B1.5- Mn3 B8 Mo3
# V3+ Nb3 V3 Si12
# Sm2+ Sm2 Mn4 Si2 C2
# Mo2+ Cr2 B4 Mo4
# W3+ Cr2 P4 W2
# Ni4+ Mn2 Si4 Ni2
# B2- Y1 Co2 B2 C1
# B2- Tb1 Co2 B2 C1
# Ni+ Li2 Ni1 N1
# Ga2+ Sr1 Ga1 Si1
# B3- Mn3 B4 W1
# Sm2+ Sm1 Al2 Ge2
# Ni+ Li6 Ni2 N3
# Yb2+ Li2 Yb1 Ge1
# Cu+ Cu69 Sb24 S78
# Nb4+ Nb16 Cr28 Si32
# Cu+ Eu2 Cu4 Si3 Ge1
# In2+ Ca1 In2 N2
# W3+ Cr1 B2 W1
# Co+ Mn1 V1 Co4 Si2
# V2+ V3 Si12 Mo3
# Yb2+ Yb8 Si4
# Cu+ Cu6 P2 Se4 S4
# Ga2+ Ba1 Ga1 Si1
# Cu+ Cu15 Bi4 Se16 I4
# Mo2+ Zr1 B2 Mo3 C2
# Cu+ Li47 Cu7 N18
# W3+ Te6 Mo1 W2
# B0.5- Sm1 Y1 B12
# B3- Mn3 B4 Mo3
# Yb2+ Yb3 Ni19 B10
# Mo3.33333333+ Al2 Si4 Mo3
# Ni+ Ni30 Sb3 P9
# Fe+ Tb2 Fe8 Si4
# Cu+ Li49 Cu8 N19
# B0.33333333- Ba2 Sr1 B18
# B1.28571429+ Y40 B28 C40
# Ga2+ Ca1 Ga1 Si1
# Ni1.33333333+ Si1 Ni6 Se2
# Mo3+ Fe3 Mo5 N8
# Bi+ In3 Bi9 Te12
# Cu+ Li7 Cu2 N3
# Fe+ Mn1 V1 Fe4 Si2
# Ni+ La2 Ni18 Ge8
# Tb+ Tb3 Ga1 C1
# Co1.27586207+ Dy6 Co58 Si8 B20
# Nd2+ Nd8 Si16 P48
# Nb+ Nb5 Si6 W5
# B3- Cr2 Fe2 B4
# Mo2.4+ Mn24 Si32 Mo20
# Co+ Mn4 Cr1 Co10 Si5
# Cr2+ Ti2 Cr1 Si6
# Cu+ Mn1 In1 Cu1 Te3
# V3+ Ta3 V3 Si12
# Dy2+ Dy1 Al2 Ge2
# W3.33333333+ Te8 Mo1 W3
# B3- Co19 Si8 B4
# B3- Ta1 B2 Mo3 C2
# In2+ In4 Sb1 Te3
# Ni+ Al1 Ni1 Ge1
# Ni4+ Fe2 Ni2 P12
# Cu+ Cr4 Cu3 Te8
# Bi2+ Bi24 Te21
# Ni+ Pr2 Ni18 Ge8
# In2+ In1 Ge1 Te2
# B+ Sm20 B20 C20
# La2+ Ca3 La1 Si8
# Co1.5+ Li1 Co2 Si1
# Ho2+ Ho1 Al2 Ge2
# Cr2+ V4 Cr6 Si6
# Cr2+ Ta16 Cr28 Si32
# Cu3+ Yb1 Zn1 Cu1 Si2
# Cu+ Cu6 Bi1 S6
# Nb+ Nb20 Ge16
# Nb2+ Nb3 Si3 Ge3
# Ni4+ Co1 Si4 Ni1
# Nb+ Nb2 Ge2 Sb2
# Ni+ Ni11 Ge2 Se4
# Ni+ Fe16 Ni20 P12
# Co+ Co3 Ni9 P4
# La+ La2 Fe2 Ni16 Ge8
# W3.33333333+ Mn1 B4 W3
# La2+ La1 Al2 Si2
# Cu+ Cu4 H12 C6 Br4 N12
# Bi3- K1 Na2 Bi1
# Ni+ Fe6 Ni6 P4
# Ce2+ Ce2 Cu4 Si2
# Ni+ Fe7 Ni5 P4
# Ni+ Fe20 Ni16 P12
# V3+ Mn1 V2 Si6
# Ni+ Zn1 Si1 Ni2
# Bi2+ Bi4 Te3
# Bi3- Na3 Bi1
# B3- Fe4 B4
# Fe+ Be1 Fe2 Si1
# W2+ Si4 Mo1 W1
# Cr2+ Cr20 Si4 B8
# B3- Fe2 Co2 B4
# Co+ Co4 Si2 Ge2
# V2.8+ V5 Si6 W5
# Cr2+ Cr1 P8 W3
# In2+ In3 Sb1 Te2
# In+ Li2 In1 Bi1
# Cu+ Cu2 I2
# Ni+ Mn3 Cr3 Si7 Ni16
# Cu+ Cu13 I15
# Nd2+ Nd1 Al2 Si2
# Bi3- Li2 Ag1 Bi1
# Ni+ Ni17 Ge4 Se4
# B2- Eu1 Ni2 B2 C1
# Mo2.44444444+ Si6 Ni1 Mo9
# Cu+ Na1 Cu3 Te2
# B2- Cr3 Ni1 B6
# Mo2.3+ Si5 Mo10 P1
# Fe+ Fe3 Co3 Si2
# Ce2+ Ce2 Fe2 Ni16 Ge8
# Cu+ Cu75 Se78
# Cu+ Mn4 Cu8 Se8
# Cu+ Cu16 I19
# Ag2.5+ Dy1 Si2 Ag2
# Cu+ Li8 Cu4 N4
# Ni+ Li1 Ni2 Sb1
# Co+ Fe2 Co1 Si1
# Mo3+ Mo2 C1 N1
# Co+ Mn2 Co1 Si1
# Mo3+ Dy2 Mo2 C3
# Bi3- K4 Ag2 Bi2
# Co+ Co12 P4
# V2+ V1 Cr2 Si6
# Mn+ Ca1 Mn1 Fe1 Ge2
# Bi+ Bi8 Se4
# Mn+ Ti1 Mn2 Ge1
# Ni+ Fe8 Ni4 P4
# B3- Mg2 B6 H40 N6
# Ho2+ Ho1 Al2 Si2
# Cu+ Cu9 Se8
# Ag2+ Ag1 I2
# Ce2+ Ce1 Al2 Si2
# Mo3+ Tb2 Mo2 C3
# Ni+ Ni11 Ge2 Te4
# B2+ Mg4 B8 H30
# B3- B2 H12 N2
# B2- Cr2 Ni3 B6
# Bi3- Mg3 Bi1 Sb1
# Nb+ Nb1 V1 H4
# Fe6+ Ca1 Ce1 Fe8 Sb24
# In2+ In1 Co16 Sb48
# Cu+ Cu14 I19
# Dy2+ Dy30 C40
# B- B6 Mo2
# Ni3+ Co3 Ni1 Sb12
# Cu3+ Cu3 I4 N4
# Ni+ Ni10 Ge6
# La+ La1 Ni5 H6
# Ni+ Ga2 Ni8 Ge6
# B2+ Mg4 B8 H31
# Co+ Be1 Co2 Ge1
# Bi3- K2 Bi2 Pb2
# Co+ Cr1 Co2 Si1
# Co+ Mn2 Co2 B2
# Ni+ Li1 Ni1 H2
# Cr2+ V4 Cr4 C4
# B3- Mn2 Fe2 B2
# Cu+ Cu4 Ge2 Te6
# Cu+ Mn1 Cu2 Si1 Te4
# Yb2+ Li2 Yb1 Si1
# Ni4+ Co2 Ni2 Sb12
# B2+ Mg4 B8 H24
# Co+ Mg1 Co2 Si1
# Ta2+ Ta3 Si3 Ge3
# Ga+ Lu1 Mn6 Ga1 Ge5
# In2+ Mg1 In2 N2
# Fe+ Er15 Fe8 C25
# B2+ Li2 B6 H16
# Fe+ Fe36 B4 P8
# B3- Fe4 B8
# Cr2+ Mn3 Cr1 Te4
# Ni1.75+ Ga6 Ni72 B48
# B2+ Na4 B36 H40 C4
# Mo2.66666667+ Si6 Mo6 W4
# Cu+ Cu4 Si2 Te6
# Ni+ Ni7 Ge4
# Fe+ Cr1 Fe3 B2
# Fe+ Cr1 Fe11 Si4
# W3+ Fe1 Si1 W1
# Cu+ Li2 Cu4 P2
# Co+ Fe2 Co2 B2
# Mn+ Dy2 Mn9 Cr3 Ge12
# Ni+ Ni6 Sb1 Te2
# Mn+ Mn2 V1 Ge1
# Cu+ Cu18 S10
# Ni4+ Fe2 Ni2 Sb12
# B0.5+ Li2 B24 P2 C2
# Sm2+ Sm12 Mn5 C15
# Sm2+ Sm2 Co18 Si4 C3
# Mn+ Dy1 Mn4 Cr2 Ge6
# Ta+ Ta1 V1 H4
# Fe+ Fe12 B2 P2
# Ni3+ Cr1 Ni3 Sb4
# Cu+ Cu4 S2
# Ni+ Mg1 Ni1 H3
# Co+ V1 Fe1 Co1 Ge1
# Bi3- Zr12 Bi4
# Gd2+ Gd2 C1
# Nb+ Nb2 Sn2 Sb2
# Ni4+ Fe1 Ni1 Sb4
# Bi3- Na4 Cd4 Bi4
# Co+ V1 Co2 Ge1
# Mn+ Mn4 Co1 Ni3 Ge4
# Cu+ Tb6 Cu40 Sb22
# Co+ Mn4 Cr1 Co10 Ge5
# Nb+ Nb2 H2
# Ni4+ Ni2 P16 W2
# Cu+ Dy6 Cu40 Sb22
# Ga+ Ga1 Co4 Ge3
# Fe6+ Fe1 Co1 Sb4
# Cu+ Mn4 Cu8 Te8
# Ni+ Ni10 Sb4
# Co+ Mn4 Co11 Ge5
# Mn+ Dy1 Mn2 Cr4 Ge6
# Co+ Fe6 Co6 B4
# Fe+ Ta1 Fe2 Ge1
# Cu+ Ba2 Cu20 P8
# In2+ In5 Sn1 Sb3 Te1
# Ag3+ Ag4 Br4 O16
# Ni+ Fe6 Ni6 B4
# Tb4+ Tb2 Si8 B36 C2
# B0.25- Yb1 Lu1 B24
# Ni4+ Fe3 Ni1 Sb8
# B0.83333333- Dy2 Si9 B36 C1
# Bi3- Na2 Zn2 Bi2
# Mn+ Ta1 Mn2 Ge1
# Bi3- Mg24 Bi16
# B2+ B40 H44 C8
# Cu+ Cu3 Te2
# Cr2+ Cr6 C3 N1
# B0.83333333- Lu2 Si9 B36 C1
# Ni+ Ni3 Sb1
# Mn+ Mn1 Fe1 Co1 Ge1
# La2+ La1 Fe5 H12
# Fe6+ Fe4 Sb12
# B2+ B40 H72
# B0.23076923+ Li2 B26 C4
# Sm2+ Sm2 C1
# Co+ Mn8 Co8 Sb8
# Mn+ Mn4 Fe8 Si1 Ge3
# Fe+ Fe24 N8
# Fe+ Fe24 N9
# Cr2+ Cr6 B1 C3
# Fe+ Fe48 N22
# Co+ Mn3 Co4 Ge6
# Fe+ Fe20 Si4 C4
# Dy2+ La4 Dy1 C10
# B3- Li1 Si1 B1
# Ho2+ La4 Ho1 C10
# Ga2.66666667+ Ba8 Ga6 Si40
# Co+ Cr1 Co2 Ge1
# B3- Li2 Be2 B2
# Mn+ Mn3 Ge1
# B0.83333333- Mg3 Si9 B36 C1
# Ga+ Ga4 Fe4 Ge4
# Mn+ Mn8 Fe2 Ge6
# Fe+ Mn1 Fe2 Ge1
# Bi+ Bi3 Sb1
# Fe6+ Cr1 Fe1 Sb4
# Fe+ Fe14 Ge8
# Yb2.90909091+ Yb11 Mn12 C18
# Fe+ Fe12 B2 C2
# Fe+ Fe1 H1
# Co+ Co1 H1
# Cu1.33333333+ Cu6 Si2
# Sm2+ Sm1 C6
# Co+ Co6 N2
# B+ Na2 B2 C2
# Bi3- In3 Bi1
# Bi3- Sn1 Bi1

# %%
filtered_data_df = []
for d in filtered_data:
    clean_d = {"formula":d["composition"].reduced_formula}
    clean_d["mpid"] = str(d["material_id"])
    clean_d["e_hull"] = d["energy_above_hull"]
    clean_d["e_f"] = round(d["formation_energy_per_atom"],4)
    clean_d["e_d"] = round(d["equilibrium_reaction_energy_per_atom"],4) if d["equilibrium_reaction_energy_per_atom"] else None
    clean_d["avg_oxi"] = d["average_oxidation_states"]
    clean_d["num_elems"] = len(d["composition"].elements)
    filtered_data_df.append(clean_d)
    
df = pandas.DataFrame(filtered_data_df)

# %%
len(filtered_data_df)
# Out:
# 11948

# %% [markdown]
# #### Removing compounds which have other synthesized polymorphs

# %%
with MPRester() as mpr:
    previously_synthesized = mpr.summary.search(theoretical=False, 
                                   exclude_elements=exclude_elements, 
                                   all_fields=False,
                                   deprecated=False,
                                   has_props=[emmet.core.summary.HasProps("oxi_states")],
                                  fields=["composition"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/32545 [00:00<?, ?it/s]

# %%
known_formulas = {d.composition.reduced_formula for d in previously_synthesized}
# Out:
# No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
# No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
# No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.

# %%
filtered_data_df_2 = [d for d in filtered_data_df if d['formula'] not in known_formulas]

# %%
df = pandas.DataFrame(filtered_data_df_2)

# %%
len(df)
# Out:
# 10635

# %% [markdown]
# #### Removing binary compounds

# %%
df_2 = df[df["num_elems"]>2]
df_2
# Out:
#           formula        mpid    e_hull     e_f     e_d  \
# 0      BaGdCrFeO6  mp-1518724  0.000000 -5.1543 -2.4397
# 3        SrLa5F17   mp-675492  0.022906 -4.4354     NaN
# 4         BaLu2F8  mp-1214962  0.000000 -4.4284 -0.0539
# 5          BaY2F8   mp-768240  0.000000 -4.3848 -0.0106
# 6      BaCaLu2F10  mp-1228137  0.008439 -4.3762     NaN
# ...           ...         ...       ...     ...     ...
# 10624     Zn3SbN3  mp-1271278  0.000000 -0.0506 -0.0000
# 10625     Zn4SnN4  mp-1247422  0.035929 -0.0441     NaN
# 10627     Zn2SbN3  mp-1029334  0.020381 -0.0298     NaN
# 10630   Bi2(CN2)3  mp-1246532  0.023457  0.0235     NaN
# 10631       SnCN2  mp-1245869  0.028682  0.0287     NaN
#
#                                                  avg_oxi  num_elems
# 0      {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5
# 3                      {'Sr': 2.0, 'La': 3.0, 'F': -1.0}          3
# 4                      {'Ba': 2.0, 'Lu': 3.0, 'F': -1.0}          3
# 5                       {'Ba': 2.0, 'Y': 3.0, 'F': -1.0}          3
# 6           {'Ba': 2.0, 'Ca': 2.0, 'Lu': 3.0, 'F': -1.0}          4
# ...                                                  ...        ...
# 10624                  {'Zn': 2.0, 'Sb': 3.0, 'N': -3.0}          3
# 10625                  {'Zn': 2.0, 'Sn': 4.0, 'N': -3.0}          3
# 10627                  {'Zn': 2.0, 'Sb': 5.0, 'N': -3.0}          3
# 10630                   {'Bi': 3.0, 'C': 4.0, 'N': -3.0}          3
# 10631                   {'Sn': 2.0, 'C': 4.0, 'N': -3.0}          3
#
# [10490 rows x 7 columns]

# %% [markdown]
# #### Filter by literature data

# %%
f1 = loadfn("solid-state_dataset_20200713.json.xz")
f2 = loadfn("sol-gel_dataset_20200713.json.xz")

# %%
def get_formulas_from_lit(f):
    all_formulas = set()
    for r in f["reactions"]:
        for precursor in r["precursors"]:
            try:
                all_formulas.add(Composition(precursor["material_formula"]).reduced_formula)
            except Exception as e:
                pass
        try:
            all_formulas.add(Composition(r["target"]["material_formula"]).reduced_formula)
        except Exception as e:
            pass
                
    return all_formulas

# %%
all_lit_formulas = get_formulas_from_lit(f1) | get_formulas_from_lit(f2)

# %%
df_3 = df_2[[f not in all_lit_formulas for f in df_2["formula"]]]

# %%
len(df_3)
# Out:
# 10059

# %% [markdown]
# #### Label common composition types

# %%
def get_formula_type_by_anion(formula):
    polyatomics={
        'PO3': 'phosphite',
        'PO4': 'phosphate',
        'HPO4': 'hydrogen phosphate',
        'H2PO4': 'dihydrogen phosphate',
        'BO3': 'orthoborate',
        'BO2': 'metaborate',
        'B2O5': 'diborate',
        'B3O7': 'triborate',
        'B4O7': 'tetraborate',
        'ClO4': 'perchlorate',
        'ClO3': 'chlorate',
        'ClO2': 'chlorite',
        'ClO': 'hypochlorite',
        'OCl': 'oxychloride',
        'BrO4': 'perbromate',
        'BrO3': 'bromate',
        'BrO2': 'bromite',
        'BrO': 'hypobromite',
        'IO4': 'periodate',
        'IO3': 'iodate',
        'IO2': 'iodite',
        'IO': 'hypoiodite',
        'NH4': 'ammonium',
        'NO2': 'nitrite',
        'NO3': 'nitrate',
        'SO3': 'sulfite',
        'SO4': 'sulfate',
        'HSO3': 'bisulfite',
        'HSO4': 'bisulfate',
        'S2O3': 'thiosulfate',
        'HS2O3': 'hydrogen thiosulfate',
        'C2O4': 'oxalate',
        'HC2O4': 'hydrogen oxalate',
        'OH': 'hydroxide',
        'CH3COO': 'acetate',
        'CO3': 'carbonate',
        'HCO3': 'bicarbonate',
        'CrO4': 'chromate',
        'Cr2O7': 'dichromate',
        'MnO4': 'permanganate',
        'CN': 'cyanide',
        'OCN': 'cyanate',
        'SCN': 'thiocyanate',
        'C8H4O4': 'phthalate',
        'C2H3O2': 'acetate',
        'HCO2': 'fomate',
        'SiO4': 'silicate'
    }
    polyatomics = OrderedDict({k: polyatomics[k] for k in sorted(polyatomics, key=len, reverse=True)})
    anions = {"H":'hydride',
            "F":"fluoride",
              "Cl":"chloride",
              "Br":"bromide",
              "I":"iodide",
              "O":"oxide",
              "S":"sulfide",
              "Se":"selenide",
              "Te":"telluride",
              "N":"nitride", 
              "P":"phosphide",
              "As":"arsenide",
              "Sb":"antimonide",
              "Bi":"bismide",
              "C":"carbide",
              "Si":"silicide",
              "Ge":"germanide",
             "Sn":"stannide",
             "Pb":"plumbide",
             "B":"boride",
             "Al":"aluminide",
             "Ga":"gallide",
             "In":"indide",
             "Tl":"thallide",
             "Ni":"nickelide",
             "Mo":"molybdenide"}
    
    for p, name in polyatomics.items():
        if p in formula:
            return name

    output = None
    try:
        output = anions[re.findall(r"([A-Z][a-z]?)(\d*\)?\d*$)", formula)[0][0]]
    except:
        print(formula)
        
    return output

# %%
df_3["type"] = [get_formula_type_by_anion(f) for f in df_3["formula"]]  # some compounds do not quite work
# Out:
# NdSiAg
# LaSiAg
# PrSiAg
# CeSiAg
# AlSi3W2
# LiSiAg2
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Desired composition types:

# %%
desired = ["oxide","sulfite","sulfate","bisulfate","silicate",
           "fluoride","chloride","bromide","orthoborate", "metaborate",
           "hydroxide","carbonate","tetraborate","phosphate","phosphite",
           "chlorate","chlorite","hypochlorite","oxychloride","bicarbonate",
          ]

# %%
df_4 = df_3[[r["type"] in desired for _, r in df_3.iterrows()]]

# %%
df_4.sort_values("e_d").head(10)
# Out:
#          formula        mpid  e_hull     e_f     e_d  \
# 0     BaGdCrFeO6  mp-1518724     0.0 -5.1543 -2.4397
# 7490    Na3ErBr6  mp-1210529     0.0 -2.0638 -0.9318
# 7532    Li3ErBr6  mp-1222492     0.0 -2.0536 -0.9269
# 4216   Tb2(SO4)3  mp-1208801     0.0 -2.6597 -0.3736
# 4434   Sm2(SO4)3  mp-1208980     0.0 -2.6233 -0.3730
# 4195   Dy2(SO4)3  mp-1213482     0.0 -2.6635 -0.3698
# 4156   Ho2(SO4)3   mp-768978     0.0 -2.6695 -0.3688
# 4080   Lu2(SO4)3   mp-768453     0.0 -2.6833 -0.3559
# 1423   La5Mn5O16   mp-531717     0.0 -3.1633 -0.3022
# 3356       YbCO3   mp-755213     0.0 -2.8150 -0.3007
#
#                                                 avg_oxi  num_elems       type
# 0     {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5      oxide
# 7490                 {'Na': 1.0, 'Er': 3.0, 'Br': -1.0}          3    bromide
# 7532                 {'Li': 1.0, 'Er': 3.0, 'Br': -1.0}          3    bromide
# 4216                   {'Tb': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 4434                   {'Sm': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 4195                   {'Dy': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 4156                   {'Ho': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 4080                   {'Lu': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 1423                  {'La': 3.0, 'Mn': 3.4, 'O': -2.0}          3      oxide
# 3356                   {'Yb': 3.0, 'C': 3.0, 'O': -2.0}          3  carbonate

# %%
df_4.value_counts("type")  # most are oxides!
# Out:
# type
# oxide           5732
# phosphate        743
# fluoride         737
# sulfate          237
# chloride         196
# silicate         116
# orthoborate       98
# bromide           85
# phosphite         76
# hypochlorite      55
# carbonate         41
# metaborate        26
# chlorite          22
# chlorate          16
# sulfite            5
# Name: count, dtype: int64

# %%
len(df_4)
# Out:
# 8185

# %% [markdown]
# #### Removing any missed ICSD compounds
# Citrine ICSD dataset

# %%
citrine = loadfn("icsd_compounds.json.gz")
df_5 = df_4[[f not in citrine for f in df_4["formula"]]]

# %%
len(df_5)
# Out:
# 5850

# %% [markdown]
# #### Removing compounds that appear in De Gruyter's Handbook of Inorganic Substances (2017)

# %%
de_gruyter = loadfn("de_gruyter_formulas.json.gz")
de_gruyter = set(de_gruyter)

# %%
df_6 = df_5[[f not in de_gruyter for f in df_5["formula"]]]

# %%
len(df_6)
# Out:
# 4354

# %%
df_6.sort_values(["e_d", "e_hull"]).head(10)
# Out:
#           formula        mpid  e_hull     e_f     e_d  \
# 0      BaGdCrFeO6  mp-1518724     0.0 -5.1543 -2.4397
# 1423    La5Mn5O16   mp-531717     0.0 -3.1633 -0.3022
# 988      Eu5P3O13  mp-1212818     0.0 -3.3259 -0.2512
# 8408       Eu2PCl  mp-1225319     0.0 -1.7790 -0.2175
# 57       YbGd3F12  mp-1215594     0.0 -4.1427 -0.2041
# 191    BaCeEuHfO6  mp-1516655     0.0 -3.8470 -0.1453
# 895         CaWF6  mp-1395540     0.0 -3.3691 -0.1426
# 6709   HfZn(SO4)3  mp-2713876     0.0 -2.2481 -0.1379
# 1294        MgWF6  mp-1407403     0.0 -3.2070 -0.1286
# 3049  Hf2Si(SO6)2  mp-2713341     0.0 -2.8616 -0.1188
#
#                                                 avg_oxi  num_elems      type
# 0     {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5     oxide
# 1423                  {'La': 3.0, 'Mn': 3.4, 'O': -2.0}          3     oxide
# 988                    {'Eu': 2.2, 'P': 5.0, 'O': -2.0}          3     oxide
# 8408                 {'Eu': 2.0, 'P': -3.0, 'Cl': -1.0}          3  chloride
# 57                    {'Yb': 3.0, 'Gd': 3.0, 'F': -1.0}          3  fluoride
# 191   {'Ba': 2.0, 'Ce': 4.0, 'Eu': 2.0, 'Hf': 4.0, '...          5     oxide
# 895                    {'Ca': 2.0, 'W': 4.0, 'F': -1.0}          3  fluoride
# 6709        {'Hf': 4.0, 'Zn': 2.0, 'S': 6.0, 'O': -2.0}          4   sulfate
# 1294                   {'Mg': 2.0, 'W': 4.0, 'F': -1.0}          3  fluoride
# 3049        {'Hf': 4.0, 'Si': 4.0, 'S': 6.0, 'O': -2.0}          4     oxide

# %% [markdown]
# #### Saving as Excel file
# **Note: this is not manually curated**! i.e., some of these may be removed from further searches of recent literature.

# %%
df_6.sort_values(["e_d", "e_hull"]).to_excel("screened_targets_50meV.xlsx")
