# %% [markdown]
# ## Screening the Materials Project for Previously Unsynthesized Materials
# ## For trial synthesis in the A-Lab
#
# **Authors**: Matthew McDermott and Max Gallant
#
# **Date**: Last updated July 24, 2023

# %% [markdown]
# #### Suggested filters
# Some of these were suggested by Nathan.
#
# - Not previously known to be synthesized (i.e., not in ICSD experimental DB or experimental literature)
# - Thermodynamically stable (i.e. <0.001 eV/atom $E_{hull}$)
# - Reasonable oxidation states (e.g., Mn3+, not Mn7+)
# - Must be of a common (and easy-to-handle) composition type, including but not limited to: oxides, sulfates, phosphates, silicates, fluorides, chlorides, bromides, borates
# - Exclude all expensive elements (Rh, Ir, etc.)
# - Exclude all dangerous elements (radioactive elements like Pu or toxic elements like As)

# %% [markdown]
# #### Imports

# %%
from collections import OrderedDict
import re

import emmet
from emmet.core.summary import HasProps
import matplotlib.pyplot as plt
from monty.serialization import dumpfn, loadfn
from mp_api.client import MPRester
import pandas 
from pymatgen.core.composition import Composition, Element
import seaborn as sns

sns.set("talk",style="ticks")

# %load_ext autoreload
# %autoreload 2

# %%
radioactive = ["Ac","Th","Pa","U","Np","Pu","Tc"]  # all other radioactive elements are not on MP
expensive = ["Cs","Rb","Pm","Tm","Sc","Tl","Re","Ir","Os","Pd","Ru","Pt","Rh","Au"]
dangerous = ["Hg","As"]

exclude_elements = radioactive + expensive + dangerous

# %% [markdown]
# #### Get summary documents with MPRester

# %%
with MPRester() as mpr:
    materials = mpr.summary.search(theoretical=True, 
                                   energy_above_hull=(0.000,0.001), 
                                   exclude_elements=exclude_elements, 
                                   all_fields=False,
                                   deprecated=False,
                                   has_props=[HasProps("oxi_states")],
                                   fields=["material_id","composition","formation_energy_per_atom", 
                                          "energy_above_hull", "equilibrium_reaction_energy_per_atom"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/6522 [00:00<?, ?it/s]

# %% [markdown]
# #### Get oxidation state docs with MPRester

# %%
with MPRester() as mpr:
    oxi_states = mpr.oxidation_states.search([doc.material_id for doc in materials], fields=["material_id","average_oxidation_states", "structure"])
# Out:
# Retrieving OxidationStateDoc documents:   0%|          | 0/6522 [00:00<?, ?it/s]

# %% [markdown]
# #### Join and filter by compounds with pre-computed oxidation states
# Note: we will lose some compounds that don't have oxidation states calculated (this is okay).

# %%
all_data = []
for d1 in materials:
    d2 = list(filter(lambda i: i.material_id == d1.material_id, oxi_states))[0]
    average_oxidation_states = d2.average_oxidation_states
    if average_oxidation_states:
        doc = d1.dict()
        del doc["fields_not_requested"]
        doc["average_oxidation_states"] = average_oxidation_states
        doc["structure"] = d2.structure
        all_data.append(doc)

# %%
len(all_data)  # this number will be lower than the original number
# Out:
# 4723

# %% [markdown]
# #### Removing any duplicate formulas
# There seem to be a few compounds with multiple stable (or close-to-stable entries).

# %%
seen_formulas = set()
all_data_no_duplicates = []

for d in sorted(all_data, key=lambda i: i["formation_energy_per_atom"]):
    formula = d["composition"].reduced_formula 
    if formula in seen_formulas:
        continue
    else:
        all_data_no_duplicates.append(d)
        seen_formulas.add(formula)

# %%
len(all_data_no_duplicates)
# Out:
# 4548

# %% [markdown]
# #### Filter by unreasonable oxidation states
# If the average oxidation state is outside of the range spanned by the `common_oxidation_states` property (see pymatgen), then we will discard.
#
# For convenience, we will print out all the discard compositions and their avg. oxidation states.

# %%
filtered_data = []
for d in all_data_no_duplicates:
    species = set(d["structure"].species)
    bad = False
    for specie in species:
        common_oxidation_states = specie.element.common_oxidation_states
        if int(specie.oxi_state) not in range(min(common_oxidation_states), max(common_oxidation_states)+1):
            print(specie, d["composition"])
            bad=True
            break
    if not bad:
        filtered_data.append(d)
# Out:
# Yb2+ Yb2 F4
# Yb2+ Yb8 Al8 F40
# Yb2+ Yb4 Hf4 O12
# Ag2+ Ca6 Hf6 Ag2 F40
# Yb2+ Yb4 Ti4 O12
# V3+ Ba4 Mg4 V4 F28
# V3+ Ca2 V2 F10
# V3+ Ba4 Ca2 Mn2 V4 F28
# Ti3.75+ Ca3 Y1 Ti4 O12
# Cr2+ Zr1 Cr1 F6
# Ti3+ Sr4 La1 Ti5 O15
# Pr2+ Ca2 Pr2 Ti4 O12
# V3+ Ba4 Ca2 V4 Fe2 F28
# Ti3+ Ca18 La2 Ti20 O60
# Ti3+ Sr18 La2 Ti20 O60
# V3+ Sr2 Li2 V2 F12
# V3+ Li2 Ca2 V2 F12
# V3+ Na4 Sr4 V4 F24
# Cr2+ Ca2 Cr2 F8
# V3+ Ba8 Na8 V8 F48
# V4+ Sr8 V8 O4 F40
# Ce2+ Ce22 Mn2 S32
# Mo3+ Ba4 Mg4 Mo4 F28
# Ti3+ Ba2 Ti16 O32
# Ti3+ Ba6 Ta9 Ti7 O42
# Ti3+ Ba3 Ti20 O40
# Ag2+ K6 Hf8 Ag4 F46
# V4+ Ca1 V1 F6
# Ti3+ Mg11 Ti25 O60
# Ti3+ Mg5 Ti13 O30
# Ti3+ Mg3 Ti9 O20
# Ti3+ Mg4 Ti14 O30
# Ti3+ Mg2 Ti10 O20
# Nd2+ Nd4 Eu8 Be4 O20
# Ti3.83333333+ K2 Ti12 O24
# Nb4+ Ba6 Ta8 Nb2 O30
# V4+ La2 Mg1 V1 O6
# Ti3+ Na4 Ti20 O40
# V4+ Ba4 Ca1 V4 Cu2 F28
# V3+ Ba4 V4 Zn4 F28
# V3+ Na4 Mg2 V2 F14
# V3+ Ba2 V2 Cu1 F12
# Nb4+ Ba6 Ti7 Nb9 O42
# Yb2+ Yb2 Mg1 Nb2 O8
# Ti3+ K2 Na1 Ti1 F6
# Ti3+ K6 Ti16 O34
# V3+ Ba4 V4 Cd4 F28
# V3+ Sr8 V4 C4 O12 F20
# Mo3+ Ba4 Ca2 Cu2 Mo4 F28
# V3+ Sr4 Ta2 V2 O12
# Ti3+ Na6 Ti2 F12
# V3+ Ca4 Ta2 V2 O12
# Ta4+ Ba6 Ta2 Nb8 O30
# O- Sr10 P6 O26
# V3+ Sr4 La4 V4 O16
# Ti3+ Li7 Ti11 O24
# Ta4.875+ K6 Ta16 O42
# V3+ Li2 V2 F8
# V3+ Na4 Ca34 V4 P28 O112
# Ta4+ Ba2 Ta15 O32
# Ta4+ La8 Ta12 Se8 O32
# Cu3+ Ba4 Ca4 Cu4 F28
# Nb4+ Ba9 Nb10 O30
# Nb4+ Ba13 Nb14 O42
# V3+ Ca8 Al4 V4 O20
# Ta4.75+ Na3 Sr1 Ta4 O12
# V3+ Na8 V4 F20
# Mo3+ Ba4 Zn4 Mo4 F28
# Ta4+ K2 Ta15 O32
# Ta4+ Na8 Sr2 Ta10 O30
# V4+ Ca2 Ho2 V4 O12
# V3+ Ba8 Nb4 V4 O24
# V2+ Li8 Ti12 V4 O32
# V4+ Ca4 V4 Si4 O20
# V4+ Sr1 Ce3 V4 O16
# Cu3+ Ba4 Mg4 Cu4 F28
# V4+ V4 F14
# Nb4+ K1 Ba2 Nb3 O9
# V4+ Li2 V2 F10
# Mo3+ Ca4 Ta2 Mo2 O12
# V3+ Tb4 V2 Fe2 O12
# Mo3+ Ca12 Si12 Mo8 O48
# Yb2+ Yb2 B8 O14
# V3+ Li2 V6 O4 F12
# V3+ V6 O3 F15
# V3+ Ta2 V2 O8
# V4+ Ba2 V1 Cu2 F12
# Nb4+ K1 Eu1 Nb2 O6
# Nb4.5+ Na1 Sr1 Nb2 O6
# V3+ Sm4 V2 Fe2 O12
# V4+ Li4 V2 O2 F8
# V4+ K8 Na4 V4 O4 F20
# Ta3+ Na3 Ta12 O24
# V4+ K8 V4 O4 F16
# Nb4+ Na1 Eu1 Nb2 O6
# V4+ Yb2 Mg1 V2 O8
# V4+ V2 F8
# Mo3+ K2 Li1 Mo1 F6
# V2+ Ti2 V2 O6
# V2+ Na4 V4 F12
# V3+ Pr4 V2 Fe2 O12
# Nb3+ Sr4 Nb8 O16
# V3+ Li2 V2 Cd2 F12
# V3+ Sr16 V8 O31
# V3+ Li8 V8 Si16 O48
# Nb4+ Ca3 Nb12 O24
# V4+ Eu4 V4 O12
# O- Sr10 V6 O26
# V4+ V8 O6 F18
# Cr2+ Li6 Ti7 Cr5 O24
# V3+ Sr16 V12 O39
# Mo3+ Sr2 La2 Cr3 Mo1 O12
# Nb4+ K4 Ba1 Nb5 O15
# V3+ Li4 Ti4 V4 O16
# V3+ Ti4 V2 P6 O24
# V4+ Eu2 Mg1 V2 O8
# V3+ Ba6 V8 P12 O48
# Nb4+ K14 Nb28 P18 O120
# Mo3+ Ca2 Ti2 Mo2 P6 O24
# Nb2+ Ba8 Zr1 Nb19 O36
# Mo3+ Cr1 Mo1 F6
# Nb4+ Ti1 Nb3 P6 O24
# Nb4+ Nb8 O16
# Cr2+ Sr4 Cr4 P8 O28
# Ni3+ Ca4 Ni4 F20
# Nb4+ K4 Nb12 P12 O60
# Cu3+ Ba4 Ca2 Cu6 F28
# Yb2+ Yb2 Cl4
# Yb2+ Yb4 V4 O8
# Bi5+ Sr4 Er2 Bi2 O12
# V2+ Ti3 V3 P6 O24
# Bi5+ Sr4 Ho2 Bi2 O12
# Nb4+ Ba4 Nb32 O56
# Bi5+ Sr4 Dy2 Bi2 O12
# V4+ Ca2 V3 O8
# V2+ Ti3 V2 Cr1 P6 O24
# V3+ Ba10 V10 O28
# V4+ V6 O6 F12
# Ta4+ Ta8 Pb6 O25
# V3+ Li6 V2 Fe2 P4 O16 F4
# V3+ K8 V8 P8 O32 F8
# Bi5+ Sr2 Ca2 Tb2 Bi2 O12
# Nb4+ Nb4 P6 O24
# Bi5+ Sr2 Ca2 Y2 Bi2 O12
# V3+ Nb3 V1 P6 O24
# Bi5+ Sr2 Ca2 La2 Bi2 O12
# V3+ V4 O4 F4
# Bi5+ Sr1 Ca1 Dy1 Bi1 O6
# Bi5+ Ba8 Dy4 Bi4 O24
# Nb2+ Eu2 Nb5 O9
# Bi5+ Sr4 Gd2 Bi2 O12
# Bi5+ Sr2 Ca2 Gd2 Bi2 O12
# V3+ Na12 V8 P8 O32 F12
# Bi5+ Sr8 Tb4 Bi4 O24
# Bi5+ Ba8 Y4 Bi4 O24
# Bi5+ Ba4 Sr4 Y4 Bi4 O24
# Bi5+ Sr8 Y4 Bi4 O24
# Bi5+ Sr4 Sm2 Bi2 O12
# Ni4+ La2 Mg1 Ni1 O6
# Bi5+ Sr4 La2 Bi2 O12
# Bi5+ Sr2 Ca2 Sm2 Bi2 O12
# V2+ Ti3 V1 Sn2 P6 O24
# Bi5+ Ba8 Gd4 Bi4 O24
# Sm2+ Ba17 Sr1 Sm12 Cl68
# V2+ Ca2 V2 P8 O24
# Cu3+ Ba4 Mg2 Cu6 F28
# V3+ Li6 V3 Cr3 P6 O24 F6
# Nb2+ Ba1 Nb5 O8
# Bi5+ Ba2 Ca2 Gd2 Bi2 O12
# Bi5+ Ba8 Sm4 Bi4 O24
# V4+ Na1 Mg3 V3 Cr3 Si6 B3 H3 O31
# Bi5+ Ba4 Ca4 La4 Bi4 O24
# W3+ Nb3 P6 W1 O24
# V4+ Mg2 V2 O6
# Mo3+ Ca2 Ho2 Mo4 O12
# Bi5+ Sr4 Pr2 Bi2 O12
# Cu3+ Ca2 Cu2 F10
# Cu3+ Li5 Cu1 F8
# Cr2+ Sr4 Cr2 W2 O12
# Yb2+ Yb1 Ge1 O3
# Ti3+ Ti2 P6 W2 O24
# V2+ Al2 V4 O8
# Yb2+ Yb2 Mo2 O8
# V4+ V4 O5 F7
# Cr2+ Mg2 Cr2 P4 O14
# V3+ Li4 Mn2 V2 P4 O16 F4
# Bi5+ Ba2 Pr1 Bi1 O6
# Cu3+ Ba4 Zn4 Cu4 F28
# Pr2+ Ca2 Pr2 Mn4 O12
# Co4+ Ca1 Co1 F6
# Mo3+ Ca2 Pr2 Mo4 O12
# Pr2+ Sr2 Pr2 Mn4 O12
# V4+ Li16 V6 P16 O58
# V4+ Ti1 Mn2 V3 P6 O24
# V3+ Li4 V4 P8 O28
# V3+ Na4 V4 P8 O28
# V4+ Na3 Ca10 Mn7 V12 O48
# V3+ Mg6 V12 O24
# V3+ Li6 V3 Cr3 P12 O42
# V3+ Li6 Mn2 V2 P8 O28
# V3+ Li6 V3 Fe1 P6 O24
# V3+ Li4 Mn1 V3 P8 O28
# V4+ Li7 V8 P12 O48
# V3+ Li2 V4 P10 O32
# Ni3+ Li12 Ni4 F24
# V3+ Na6 V4 P6 O24
# V3+ Mg2 V2 Cr2 O8
# V3+ Li4 V4 P16 O48
# V4+ Li1 Mn1 V1 P2 O8 F2
# V4+ Na4 V8 P8 O36
# V4+ V4 O6 F2
# Ni3+ Sr1 La1 Ni1 O4
# Cr2+ Cr6 B14 O26 F2
# V4+ Na12 V8 P8 O40 F4
# V3+ Li2 Mn1 V1 P4 O14
# Ni3+ La4 Fe2 Ni2 O12
# Mo2+ Ca4 Mo2 W2 O12
# Cr2+ Li4 Cr10 Si8 O28
# Cr2+ Li4 Cr2 P4 O14
# Co4+ La4 Zn2 Co2 O12
# V4+ Li4 V8 P12 O48
# Nb3.33333333+ Na8 Nb12 O24
# Mo3+ Ca4 Mo8 P8 O36
# V3+ Li6 V2 Fe2 P8 O28
# V2+ Li4 V4 P4 O16
# V2+ V8 Si4 O16
# Bi5+ Sr4 Eu2 Bi2 O12
# Fe4+ Li4 Fe2 F12
# Bi5+ K4 Ba4 Ce4 Bi4 O24
# V3+ Li4 V2 Fe2 P8 O28
# Ni3+ Sr1 Nd1 Ni1 O4
# V4+ V2 P4 O14
# Ni3+ K1 Na1 Ca1 Si8 Ni5 O24
# Cr2+ K1 Cr12 Si8 Cl1 O28
# V3+ Li4 V8 B4 O20
# Cr2+ K1 Cr12 Si8 Br1 O28
# V3+ Na2 Nb14 V4 O28
# Cr2+ Na1 Cr12 Si8 Cl1 O28
# Cu3+ Ba4 Zn2 Cu6 F28
# Mo3+ Si6 Mo12 P18 O75
# V2+ Li16 V4 B8 O24
# Cr2+ Na1 Cr12 Si8 Br1 O28
# V4+ Mn2 V3 Cr1 P6 O24
# Cu3+ K2 Li1 Cu1 F6
# Cu3+ Li18 Cu6 F36
# V3.75+ V24 P18 O90
# Bi5+ Ba8 Eu4 Bi4 O24
# V2+ V4 P2 O10
# Bi4+ La4 Bi4 O14
# Ni3+ Nd4 Mn1 Ni3 O12
# V4+ Li6 V4 P8 H4 O32
# V4+ Li2 Mn2 V2 P8 O28
# Fe4+ Y4 Fe4 O14
# V3+ Li8 V4 P8 H4 O32
# V4+ V3 P6 W1 O24
# Ni4+ Ca1 Ni1 F6
# Co4+ La2 Co1 Ni1 O6
# Mo3+ Ca12 Ge12 Mo8 O48
# Co4+ Mg1 Co1 F6
# V4+ Mn2 V3 Fe1 P6 O24
# Mo3+ Li6 Mo4 P6 O24
# Ag3+ Ba4 Zn4 Ag4 F28
# Mo3+ K1 Mo2 P4 O14
# Bi5+ Sr4 Yb2 Bi2 O12
# V3+ V4 Cd3 P6 O24
# Co4+ Sm4 Co2 Ni2 O12
# Mo3+ Na1 Mo2 P4 O14
# W3+ Li4 P16 W4 O48
# Mo3+ Nb1 Mo1 O4
# Ni3+ Cr1 Ni1 F6
# Bi5+ K2 Bi2 F12
# Bi5+ Sr6 Li2 Bi2 O12
# Cu3+ Mg2 Cu2 F10
# Cu3+ Na6 Cu2 F12
# Cu3+ Sr4 Li1 Cu1 C2 O10
# Co4+ Nd4 Co2 Ni2 O12
# V3+ V6 O10
# V4+ V4 P8 Pb4 O32
# V4+ Mg4 V12 O32
# V3+ Mg1 V1 Cr1 P2 H2 O10
# Pr4+ Ca2 Pr2 Fe4 O12
# Ti3+ Ce7 Ti4 Se12 O6
# Cr2+ Li4 Cr16 P12 O48
# Pr4+ Sr2 Pr2 Fe4 O12
# Ni3+ Tb4 Ni4 O12
# V3+ Li4 V4 P4 H4 O20
# Co4+ K2 Co1 F6
# V3+ V4 Cd10 P16 O56
# Mo3+ Mo8 P14 O48
# Cu+ Ce4 Cu3 S4 O4
# Bi5+ Bi1 Sb3 F20
# V3+ Li2 V1 Cr1 P2 H2 O10
# V4+ Li2 V2 Cr2 O8
# Mo3+ Mo4 P6 O22
# V4+ Li4 V8 O20
# V3+ Na12 V4 Si4 C4 O28
# Mo3+ Na4 Mo8 P8 O36
# Co4+ Ba12 Co4 O20
# Bi5+ Sm2 Bi2 O8
# O- Sr21 Fe14 O47
# V3+ K8 V4 P4 C4 O28
# Ni4+ Sr3 La1 Ni2 O8
# V3+ Na8 V4 P4 C4 O28
# Fe4+ Sr12 Fe8 O27
# V4+ Li4 V6 Sn2 O16
# V4+ Li4 V6 Co2 O16
# Bi5+ Ba6 Ca2 Bi4 O18
# V2+ Li4 V6 W2 O16
# Bi5+ Nd2 Bi2 O8
# Bi5+ Pr4 Bi4 O16
# Ni3+ Sr12 In4 Ni4 O24
# Fe4+ Sr24 Fe16 O55
# Cu3+ Sm4 Cu4 O12
# Fe4+ Sr4 Nd2 Fe6 O18
# Fe4+ Ca6 Fe4 O14
# V3+ Li4 V6 Sb2 O16
# Fe4+ Sr4 Pr2 Fe6 O18
# V4+ K4 V6 P8 H8 O38
# Co4+ Sr12 Zn4 Co4 O24
# Co4+ Sr1 Pr1 Fe1 Co1 O6
# Ni4+ Mg1 Ni1 F6
# V4+ Li4 V3 Cr3 Sn2 O16
# Cu3+ Nd4 Cu4 O12
# Bi4.11111111+ Ba10 Ce1 Bi9 O30
# Bi5+ Ba20 Li4 Bi8 O42
# Cu3+ Ca1 Cu2 F8
# V4+ V4 P4 H4 O20
# Yb2+ K4 Yb4 Br12
# La2+ Ca2 La16 Se24
# Ni4+ Ca2 La2 Fe2 Ni2 O12
# Co4+ Sr8 Co4 O16
# La2+ La1 Sm1 S2
# Cu3+ Sr8 Cu4 O14
# V3+ V12 Zn6 O24
# Yb2+ Yb1 Sm3 S4
# V3+ Li2 V2 Sn2 O8
# Fe4+ Zn1 Fe1 F6
# V4+ Li2 V6 Zn4 O16
# Yb2+ La24 Se40 Yb4
# Gd2+ Sm1 Gd1 S2
# Bi5+ Ba4 Sr4 In4 Bi4 O24
# Bi5+ Ba8 In4 Bi4 O24
# Ce2+ Ce1 Nd1 S2
# V4+ Mn10 V8 O24
# Ce2+ Ce1 Sm3 S4
# Bi4.33333333+ Ba16 Bi12 O42
# Pr2+ Pr1 Sm3 S4
# Bi4.22222222+ Ba11 Bi9 O30
# Ag2+ Ag2 Sb6 I2 F48
# Ho2+ Sm3 Ho1 S4
# V4+ V2 Cr2 Sb2 O12
# Zr3+ Zr48 N8 Cl120
# La2.875+ Na2 La16 Se24
# Nb4+ Nb2 Cl4 O2
# Cu3+ Na2 Cu2 P4 O14
# V3+ V4 Co2 O8
# Cu+ Ba2 In1 Cu1 O4
# V4+ Mn4 V6 Ni2 O16
# Cu+ Ba2 La1 Cu3 O6
# Zr3+ K4 Zr24 N4 Cl60
# V2+ V4 Fe8 B4 O20
# Cu3+ Li2 Cu2 F8
# Tb2+ Tb4 Cl6
# Bi5+ Ba4 Li1 Bi3 O12
# Cu+ Ba2 Pr1 Cu3 O6
# O- Sr2 Cu1 O4
# Fe5+ Li2 Fe2 F12
# Pr2+ Pr27 Se40
# Sm2+ Sm1 Eu1 Se2
# V3+ Li1 V1 C2 O6
# Cu+ Ba2 Y1 Cu3 Pb1 O7
# Nb2+ Lu4 Nb24 Cl52 O12
# V2+ Na12 V4 C8 S2 O32
# Nb2+ Sm4 Nb24 Cl52 O12
# Co4+ Zn1 Co1 F6
# V3+ Na8 V4 C8 S2 O32
# Nb2+ Nb12 Br17 F13
# V3+ V8 S12 O48
# Bi4.25+ K1 Ba3 Bi4 O12
# Ni3.33333333+ Sr12 Ni9 O27
# V3+ V4 H4 O8
# Zr+ K6 Zr12 Be2 Cl30
# Gd2+ Sm1 Gd1 Se2
# Ni4+ Na6 Ni4 P4 C4 O28
# Cu3+ Ca8 Cu8 O20
# O- Y6 Cu11 O24
# V4+ Na8 V2 O8
# V4+ V2 Fe2 Sb2 O12
# Ni3+ Li8 Ni4 O8 F4
# V4+ V18 Ag7 O48
# B3- Sr2 Zr24 B4 I10 Cl46
# Cu3+ Sm2 Cu4 O8
# Mn+ K2 Zr12 Mn2 Cl28
# Gd2+ Ba2 Gd1 Cu4 O8
# La2+ La2 Cu4 O8
# Sm2+ Ba2 Sm1 Cu4 O8
# Ni3+ Sr18 Ni14 O42
# Cu3+ Na4 Cu2 P2 C2 O14
# Co4+ Ba1 Sr3 Co4 O12
# Zr2+ Zr12 Mn2 Cl28
# Nd2+ Nd2 Cu4 O8
# La2+ La12 P4 Br12
# Cu+ K2 Ca2 Er4 Cu2 S10
# Cu3+ Zn4 Cu4 F20
# Pr2+ Pr2 Cu4 O8
# B3- Na4 Zr24 B4 I10 Cl46
# In+ La4 In8 Cl20
# Cr2+ La6 Cr1 Si2 S14
# In2+ Mn11 In25 O48
# Bi4+ Ca8 Bi16 O40
# Ag3+ Li2 Ag2 F8
# Nb2+ Nd12 Nb10 S32
# Bi5+ Li7 Bi1 O6
# Ti3+ Sr24 Ti21 S63
# Cu+ Sr4 La4 Cu4 S12
# Tb4+ Tb24 Se45
# Ni3+ Li9 Mn12 Ni3 O32
# Nd2+ Na1 Nd2 Se3
# V4+ V2 H3 O5
# Pr2+ Na1 Pr2 Se3
# Cu3+ Li1 Cu5 F12
# In+ Nd4 In8 Cl20
# Yb2+ Yb4 Te10 O26
# V3+ Na2 V6 H12 S4 O28
# In+ Sm4 In8 Cl20
# La2.33333333+ La12 Si4 Cl12
# In+ Gd4 In8 Cl20
# Zr3+ Ba30 Zr28 Se84
# O- Ba2 Eu1 Cu4 O8
# Ni4+ Zn1 Ni1 F6
# Pr2+ Pr12 P4 Br12
# Ag2+ Ag1 Pb1 F6
# V4+ K2 V1 Cl6
# Cu3+ Li2 Cu4 F14
# Cu3+ Ba8 Cu8 O20
# Nb2.33333333+ K2 Sr1 Nb6 Cl18
# Cu+ Eu2 Lu2 Cu2 S6
# V4+ V8 S16 O64
# Ce2+ Ce4 Ge1 S3
# Gd2+ K1 Gd1 Nb6 Cl18
# In+ Yb2 In2 Br6
# Nb2.33333333+ K1 Y1 Nb6 Cl18
# Zr2+ Hf1 Zr1 N2
# Ag2+ Ca2 Ag2 O4
# Nb2.33333333+ K1 Lu1 Nb6 Cl18
# Ni3+ Ta2 Ni22 B8 O40
# Bi5+ Li6 Bi2 O8
# Yb2+ Yb6 Ge2 O2
# Cu3+ Cu4 P4 O16
# Fe4+ Li8 Fe4 O12
# Yb2+ Yb4 Sb2 O1
# Ta3+ Sm4 Ta24 Br52 O12
# Zr2+ K4 Zr6 Fe1 Br18
# Ni3+ Nb2 Ni22 B8 O40
# Zr2.66666667+ Zr24 S32
# Co4+ Ca2 Co3 O8
# Ni3+ Ti4 Ni15 O24
# V2+ K2 V2 Cl6
# Ce2+ Ce12 P4 Br12
# Ni3+ Ni2 F6
# O- Sr2 Ag2 O4
# Zr3+ Li1 Zr2 S4
# Sm2+ Sm10 Sb3 Se7
# Cu3+ Eu2 Cu4 O8
# Cu3+ Li2 Cu6 F20
# V2+ Li10 V10 Cl32
# Zr2+ Zr4 Br4 O1
# Ti3+ Ca1 Ti4 S8
# B3- Na8 Zr6 B1 Br20
# Co4+ Li8 Co4 O12
# Ce2+ Ce3 Ge1 S2
# Ce2+ La4 Ce2 Te8
# Co4+ Be4 Co2 N4 F28
# B3- Tb12 B4 Cl12
# Sm2.66666667+ Sm6 Ge3 S14
# Hf2+ Hf1 S1
# Yb2+ Yb6 Si2 O2
# Ag2+ Ba1 Ag1 O2
# Zr3+ Li1 Zr1 S2
# Ti3+ Ti20 H2 N17
# Nb2+ K3 Nb24 Cl60
# Nb4+ Ba16 Nb14 S48
# Co4+ Li4 Mn1 Co5 O12
# Hf2+ Hf4 C1 N3
# Hf3+ Li1 Hf1 S2
# Zr3.75+ Zr4 Cu1 S8
# Ti3+ Ca1 Ti8 S16
# Cu+ La8 In4 Cu4 S20
# Cu3+ Ca2 Cu4 O8
# Ni3+ Li2 Mn2 Ni2 O8
# Ti3+ Ti4 S6
# Ti3+ Ti5 S8
# Zr3+ Na19 Zr11 S30
# Co4+ Li8 Mn4 Co12 O32
# Bi5+ Na5 Bi1 O5
# Ti3.5+ Li1 Ti2 S4
# Cu+ Ga2 Cu2 O4
# Ti3+ Ti14 S24
# Ni3+ K8 Li12 Ni4 O16
# Ni3+ Ca4 Ni8 O16
# Cu+ K2 Dy4 Cu4 S9
# Ni3+ Ni12 B4 O20
# Ti3+ Ti4 C1 N3
# La2+ La2 Sb1 I2
# W3+ K2 H16 W2 N4 F12
# Zr3+ Zr4 Se6
# Ti3+ Na3 Ti10 S20
# Fe4+ Na8 Fe4 O12
# Zr3+ Zr2 Ni1 S4
# Zr3+ Zr4 C1 N3
# Bi2+ Bi4 Te4 O16
# Cu+ V4 Cu6 Ni2 O12
# Hf2+ Hf3 N2
# Ti3+ Ti2 C1 Cl2
# Cu+ K2 Cu1 Bi1 Cl6
# V3+ Ti3 V1 S6
# Ag2+ Ag3 P2 O8
# In+ Ti5 In1 S8
# Cu+ Zr3 Cu6 Cl18
# Zr2+ Zr1 Se1
# Bi3- Sr4 Bi2 O1
# V2+ Ti2 V1 S4
# La+ La7 Co1 I12
# Ce2+ Ce3 Ta2 N6
# Co4+ Li8 Fe4 Co12 O32
# Hf3+ Hf8 Se12
# Yb2+ Yb8 Sn4 S20
# Ni3+ Li4 Ni6 Sb2 O16
# B3- Tb12 B4 Br12
# B3- Gd12 B4 Br12
# Pr2+ Pr12 C4 Br12
# V3+ V2 Sb2 Se8 O24
# La2.25+ La4 Si1 I5
# Nb4+ Li10 Nb14 S28
# Ni3+ Ba1 Ni1 I1 O6
# Bi3- Ba4 Bi2 O1
# Hf3+ Li1 Hf1 Se2
# Ni3+ Li4 Ni6 Te2 O16
# Ag2+ Ti6 Ag1 S12
# O- K2 V2 H8 O14
# Ce2+ Ce3 Cu4 P4 O2
# Pr2+ Pr3 Ta2 N6
# Ta3+ Li4 Ta6 S12
# Co4+ Na8 Co4 O12
# Ta3+ Li2 Ta2 S4
# B3- Pr12 B4 Br12
# Tb2+ Tb1 Te1
# Co4+ Na32 Co8 O32
# Co4+ Li8 Co16 O32
# V2+ V4 H48 S4 O40
# Co4+ Na16 Co2 O12
# La2.25+ La4 B2 N5
# Nb4+ K4 Nb6 S12
# Hf3+ Hf2 C1 N1
# Cu3+ Mg4 Cu8 O16
# Ni3+ Li3 Ni3 O6
# Ta3+ K4 Ta6 S12
# Ti3+ Ti3 Co1 S6
# Ti2.58333333+ K1 Ti12 Se16
# Nb4+ Na4 Nb6 S12
# Ta3+ Na4 Ta6 S12
# Ti2.5+ K1 Ti6 Se8
# Hf2+ Hf4 C2 S2
# Nd2+ Nd3 Cu4 P4 O2
# Cu3+ Cu4 S6 O24
# Co4+ K4 Co8 O16
# Ti3+ Li1 Ti1 Se2
# Cu+ Ba2 Nd2 Cu2 Te6
# Cu+ Ba2 Pr2 Cu2 Te6
# V3+ Na1 Ti1 V1 S4
# Ce2+ Ce12 P4 I12
# Cu+ Dy1 Cu1 Se2
# Cu+ Cu4 S8 N8 O32
# Zr3+ Hf1 Zr1 C1 N1
# Ta3+ Ta6 V2 S12
# La2.33333333+ La12 Si4 I12
# In+ Al4 In4 Br16
# Nb3.33333333+ Nb12 S20
# In2+ In8 Cl16
# Ce2+ Ce24 C16 Br24
# Cu+ K2 Ce1 Cu2 S4
# O- Sr2 H32 O20
# Nb2.5+ K1 Nb6 S8
# O- Ba2 H32 O20
# Ag2+ K2 Ag2 Cl6
# Ce2+ Ce2 Sb1 Te1
# Ti3+ Ti2 C1 N1
# Ta3+ Ta7 S12
# Zr3+ Zr2 C1 N1
# Ta2+ Mg4 Ta8 N12
# Co4+ Li2 Co2 Ni2 O8
# Co4+ Na2 Co6 O12
# Ta3+ Li6 Ta18 N24
# Ag2+ Ag8 S8 O32
# V2+ Ba1 V12 S16
# Tb2+ Tb16 C8 Br12
# Ta3+ Ta6 Cr2 S12
# Cu+ Na12 Cu4 O8
# Ta3+ Ta5 S8
# V4+ V2 P2 Cl18
# Cu3+ Na2 Cu2 O4
# Cu+ Y2 Cu2 Pb2 S6
# V3+ Ba1 V10 S16
# Cu+ Er2 Cu2 Pb2 S6
# Mo3+ Ta4 Mo1 S10
# Cu+ Ho2 Cu2 Pb2 S6
# Cu+ Dy2 Cu2 Pb2 S6
# Bi4+ Co3 Bi6 O18
# Cu+ Tb2 Cu2 Pb2 S6
# Ag3+ Ca2 Ag4 O8
# Cu+ Lu2 Cu2 Pb2 S6
# Cu+ Cu4 Ni2 Sn2 O8
# V3+ V1 N1
# Zr+ Zr4 N2
# La+ La10 Ge6 O2
# W3+ Na2 W12 N2 Cl36
# Zr2.83333333+ Zr12 P2 I28
# Ag3+ Ag6 F18
# Mo2.33333333+ Ba8 Mo24 S36
# Nb3+ Li2 Nb2 Se4
# B3- K2 Zr12 B2 I28
# Cu+ Ta14 Cu3 S24
# In+ In2 Sn2 Cl6
# B- La4 B4 I5
# V2.5+ K1 V6 S8
# Ti3+ Li2 Ti2 Sb2 O1
# Bi5+ Ni4 Bi8 O24
# Cu+ Hf2 Cr2 Cu2 S8
# V4+ K2 V20 S32
# Cu+ Ti3 Mn1 Cu2 S8
# Zr3+ Zr4 I12
# Nb4+ K4 Nb6 Se12
# Zr3+ Zr2 Te2 P1
# Nb4+ Nb6 Ge2 S12
# Mo2+ Ag2 Mo12 Cl26
# Nb4+ Nb6 Ni2 S12
# V2.5+ Na1 V6 S8
# Cu+ Al5 Cu1 S8
# Mo2+ K8 Mo24 Br56
# Ta3+ Ta4 Ag1 S8
# Zr3+ Zr12 Si2 I28
# Cu+ K4 Ti2 Cu4 S8
# Ta3+ Ta6 Co2 S12
# Ni3+ Na4 Ni5 O10
# Ti3+ Ti2 Nb6 Se12
# Ta3.5+ Ta2 In1 S4
# Cu3+ Y1 Cu7 O12
# Zr3+ Zr12 Ge2 I28
# Nb3+ Nb4 Se4 Br4
# Zr2+ Zr5 Te4 P2
# V3+ V2 Br6
# Hf3+ Hf4 C3 N1
# Ag2+ K2 Ag2 Br6
# Ni3+ Zn2 Ni4 O8
# Cu+ Lu4 Cu4 Pb4 Se12
# Ni3.5+ Li8 Ni16 O32
# Zr2+ Zr12 Fe2 I28
# Tb+ Tb4 Ni4 P4
# Cu+ K6 Ta2 Nb2 Cu6 S16
# Yb2+ Yb1 Cu2 S2
# Cu+ Li6 Cu2 S4
# Ti3+ Ti1 Cr2 S4
# Ta3+ Ta3 In2 S6
# Mo2+ La1 Ce1 Mo12 S16
# V4+ V2 S4
# Ta3+ Na4 Ta6 Se12
# V4+ V12 Ga2 Ge1 S24
# Zr2+ Zr12 Co2 I28
# Nb4+ Nb8 V2 Se16
# Zr2.58333333+ K1 Zr12 Te16
# Cu+ Ti2 Cr2 Cu2 S8
# V3.125+ V8 Ga1 Ge1 S16
# V4+ V20 Ga2 Ge3 S40
# Ta3+ Ta6 Cu4 S12
# V3.08333333+ V12 Ga1 Ge2 S24
# Ni3+ Co2 Ni4 O8
# Nb4+ Nb2 Ag1 S4
# Nb4+ Nb4 H3 S8
# Nb4+ Nb1 Se2
# Ni3+ Na5 Ni9 O18
# Zr3+ Zr4 Te6
# Yb2+ Yb12 Gd4 Sb12
# Nb2.5+ K1 Nb6 Se8
# Yb2+ Yb6 Dy2 Sb6
# Mo2+ Li4 Mo6 S8
# Co4+ Co2 Ni2 O6
# W2+ W12 Cl24
# Ta3+ K4 Ta6 Se12
# Cu3+ Zn2 Cu4 O8
# In2+ In1 Cu6 O8
# Ni3+ Na4 Ni8 O16
# Tb2+ Tb4 C2 Br2
# V4+ Li2 V4 N6
# In2+ In32 Br48
# Ti2+ Ti68 Cu4 P48
# W2+ K8 W24 Br56
# Cu+ Mn1 Cu6 O8
# Nb3+ Nb6 Cr2 Se12
# In+ In2 Sn2 Br6
# Cu+ Al2 Cr3 Cu1 S8
# Ag3+ Li2 Ag2 O4
# Ti2+ Ti22 Cu2 P16
# Ta3+ Ta6 V2 Se12
# Ti3+ Ti4 C3 N1
# Zr3+ Zr4 C3 N1
# Nb4+ Nb3 Ag2 Te1 S6
# Bi3- Ce5 Bi1 Sb4
# Zr3+ Zr10 Si6 N2
# Yb2+ Yb6 N4
# Nb4+ Nb3 W1 Se8
# Cu+ Ga2 Cu2 Br8
# Cu3+ Cd2 Cu4 O8
# Bi3- La8 Bi3 Sb3
# Nb4+ Nb8 Ni2 Se16
# V3+ Na3 V5 Se10
# Ti3+ Ti2 Te2 P1
# Nb4+ Nb8 Co2 Se16
# Co4+ Co4 O8
# V4+ Na1 V2 Se4
# Nb4+ Nb8 Fe2 Se16
# Cu+ Gd2 Cu6 S6
# V2+ V1 Cr2 S4
# Ta3+ Ta8 Cr2 Se16
# Cu+ Tb2 Cu6 S6
# Cu+ Dy2 Cu6 S6
# Nb4+ Nb4 Ge1 Se8
# La+ La8 Sn2 Sb4
# Cu+ Ho2 Cu6 S6
# Cu+ Y2 Cu6 S6
# Cu+ Er2 Cu6 S6
# Ta3+ Ta6 Mn1 C3 S6
# Ga2+ Na4 Ga4 Se6
# Mo3+ Mo1 W1 Se4
# Cu+ Al1 Cr4 Cu1 S8
# Ni3+ Ni6 O8
# Mo3+ Mo4 Br12
# Nb3+ Nb4 Se4 I4
# Ag3+ K2 Ag2 O4
# Dy2+ Dy10 Ge4 Sb4
# Ag3+ Na1 Ag1 O2
# Mo3+ Na17 Mo60 S76
# V3+ V5 Se8
# B2- Hf1 Zr1 B4
# Ho2+ Ho10 Ge4 Sb4
# Ti3+ Li1 Ti5 Te10
# Cu+ Ta2 Cr6 Cu4 S16
# Fe4+ Fe2 Cl8
# Nb+ Nb6 N3
# Co+ La3 Pr1 Co8 P8
# Cu+ Cr4 Ga1 Cu1 S8
# Cu+ K2 Zr2 Cu2 Te6
# Mo3+ Ca6 Mo2 N6
# Ni+ Eu1 Ni1 P1
# Ti3+ Ti5 Te8
# Cu+ Cu4 Bi3 Pb1 Se4 O4
# Ti3+ Ti4 Te6
# Bi3- Ca3 Bi1 P1
# Cu+ Cu10 Se2 Cl10 O8
# B- Ca2 Ni2 B2 N2
# Cr2+ Ce6 Cr20 N22
# Nb4+ Nb6 Cu4 Se12
# Mo3+ Li7 Mo12 Se16
# W3+ Sr6 W2 N6
# Co+ Zr18 Co4 P8
# Tb2+ Tb10 Si4 Sb4
# In+ Cr5 In1 S8
# Dy2+ Dy10 Si4 Sb4
# Co+ Ho6 Co18 P12
# Ho2+ Ho10 Si4 Sb4
# Nb4+ Ce6 Nb2 Sb10
# Ni+ Er6 Ni20 P13
# Ni+ Ho6 Ni20 P13
# Ti2+ Ti3 Fe5 P4
# Cu+ Al2 Cu2 Sn2 S8
# La2+ La2 Mn2 N6
# Co1.10526316+ Lu5 Co19 P12
# Yb2+ Sr12 Yb8 Cd10 Sb20
# Co1.10526316+ Er5 Co19 P12
# Ni+ Ce6 Ni20 P13
# Co1.10526316+ Ho5 Co19 P12
# Cu+ Na1 Ti1 Cu3 Se4
# Co1.10526316+ Dy5 Co19 P12
# Nb4+ Ti1 Nb1 B4
# Ni+ Nd2 Ni2 Sb2
# Ni+ Pr2 Ni2 Sb2
# Zr+ Zr5 Co19 P12
# Co1.10526316+ Y5 Co19 P12
# Co+ Tb5 Co19 P12
# Yb2+ Yb2 N4
# B2- Ta1 Ti1 B4
# Ta2+ Ta1 Pb1 Se2
# Yb2+ Yb18 Zn9 Sb18
# Tb2+ Tb4 C2 I2
# Cr2+ Pr6 Cr20 N22
# La2+ La16 P8 C8
# Ni+ Nd6 Ni20 P13
# V4+ Ta1 V1 Cu6 S8
# B2- Hf1 Nb1 B4
# Cu+ Ta1 Nb1 Cu6 S8
# In2.14285714+ K3 In21 S24
# Ta3+ Ta22 Si4 Se16
# Ni4+ Tb2 Ni1 Sb4
# Zr2+ Zr6 Si4
# Ni+ Pr6 Ni20 P13
# Ni+ Yb6 Ni20 P13
# Cu+ Mg1 Cu2 Ge1 S4
# B2- Zr1 Nb1 B4
# W2+ Ca4 W2 N4
# B2- Hf1 Ta1 B4
# Ni4+ Dy2 Ni1 Sb4
# Cu+ Al1 Cr4 Cu1 Se8
# B3- Ta3 Ti1 B4
# B2- Zr1 Ta1 B4
# Ag2+ Cr4 Ag2 S8
# Cu3+ Cu16 O24
# Ni+ Ce1 Ni1 Sb1
# Cu+ Ba4 Cu11 Te8 S2
# V4+ V5 B6
# Ni4+ Ho2 Ni1 Sb4
# V2+ Ta4 V4 P4
# Nb2+ Nb12 H2 S2 I18
# Zr2+ Zr6 Ti4 Si6
# Yb2+ Yb5 Co19 P12
# B3- Ti1 B2 Mo1
# W2+ Ti1 P2 W1
# Cu+ Ta1 Cu3 Se2 S2
# Ce2+ Ce20 Ge4 Sb8
# Ni+ Y12 Ni4 Ge8
# Ni+ Er4 Si4 Ni4
# B3- Ti1 Nb1 B2
# Ti3+ Ti8 Ga2 C6
# Ta4+ Hf1 Ta1 C2
# Cu+ Cr2 Cu2 Sn2 S8
# Cu+ In10 Cu1 Ag1 S16
# Cu+ Nb1 Cu3 Se2 S2
# Cu+ Cr4 Ga1 Cu1 Se8
# Zr3+ Zr20 C18
# Ga2+ Ga12 Te12 Cl4
# Tb2+ Tb8 Hf12 Si16
# Ho2+ Ho4 Si4 Ni4
# Co+ Tb2 Co12 P7
# Ti3+ Ti10 Si6 C2
# Cu+ Ca20 Cu8 N16
# Ni+ Li2 Ca4 Ni2 N4
# Co+ Er2 Fe6 Co6 P7
# V4+ V1 Cu3 Se2 S2
# Ni+ Fe1 Ni35 S32
# Dy2+ Dy12 Ni4 Ge8
# Cu+ Eu4 Zn4 Cu2 P6
# Yb2+ Yb1 Mg2 Sb2
# Dy2+ Dy4 Si4 Ni4
# La+ La30 Ge18 P2
# Cu+ La1 Zn1 Cu1 P2
# Cu+ Ta1 Cu3 Se3 S1
# Co+ La2 Co2 N6
# Ti2+ Ti6 Sn2 C4
# Cu+ Y1 Zn1 Cu1 P2
# Cu+ Al1 Cu1 Sn1 Se4
# Co+ Sm2 Co12 P7
# La+ La20 Mn8 Te7 C12
# Ag2+ Cr4 Cd1 Ag1 Se8
# Tb2+ Tb4 Si4 Ni4
# Cu+ Er1 Zn1 Cu1 P2
# Cu+ Sm1 Zn1 Cu1 P2
# Cu+ In5 Cu1 Se8
# Ni+ Eu4 Ni14 P8
# Co4+ Co4 N16 O48
# Cu1.5+ K1 Cu2 S2
# Co1.5+ Lu6 Co4 Si6
# Cu+ Li2 Ca4 Cu2 N4
# Ce2+ Ce3 Si4 Ni4
# Ti3+ Ta1 Ti1 C2
# Ga2+ Ga12 Te12 Br4
# Cu+ In3 Cu1 Se5
# V3+ V10 Si6 N2
# Zr2+ Zr28 Sb16
# La2.25+ La4 H9
# Ta3+ Er4 Ta1 V7 B24
# Ta4+ Zr1 Ta1 C2
# Cu+ Ce1 Zn1 Cu1 P2
# Bi+ Ce4 Ni4 Bi3 Sb5
# O- Cu2 Ag1 O4
# Zr3+ Zr2 H1 C1
# La2.5+ La4 H10
# Yb2+ Yb2 Ga12 Te20
# Tb2+ Tb1 Nd1 Ni2 Ge4
# O- Cu1 Ag1 O2
# Nb4+ Hf1 Nb1 C2
# B1.33333333- Lu16 V20 B72
# Ti2+ Ti6 V4 Si6
# Ti2+ Ti2 H1 C1
# Nd2+ Nd12 Ni4 Ge8
# Cu+ Ba6 Cu34 S27
# Fe+ Ho2 Fe12 P7
# Co4+ Co2 Ni4 S8
# Cu+ Er4 Cu12 Te12
# Cu+ Ta1 Cu3 Te1 Se2 S1
# In2+ In12 Te12 Br4
# Nd2+ Nd2 Si2 Ni2
# Bi3- K2 Ca2 Bi2
# Nd2.5+ Nd4 H10
# Cu+ In1 Cu1 Ge1 S4
# B3- V9 Cr3 B8
# V3+ V2 I6
# Hf2+ Hf2 H1 C1
# Nd2+ Nd4 Ni4 Ge4
# Co+ Y4 Co4 Si4
# La+ La2 Ga2 Si2
# Ni1.8+ Lu4 Si12 Ni20
# V4+ Ta1 V1 B4
# Sm2+ Sm4 Zn4 Ge4
# Nd2+ Nd4 Zn4 Ge4
# Ni1.8+ Dy4 Si12 Ni20
# Bi3- Tb1 Ni1 Bi1
# Pr2+ Pr2 Si2 Ni2
# Tb2+ Tb4 Zn4 Ge4
# Ga2+ Eu4 Ga8 P8
# Ti2+ Ti10 Si2 Sb4
# B3- Ta1 Be1 B1
# Yb2+ Yb18 Zn8 Bi18
# Ti2+ Ti1 Fe2 Si1
# Ga2+ Pr2 Ga2 Si2
# Nb4+ Nb24 Te96
# Ni+ Nd1 Ni1 Bi1
# Ti2+ Ce2 Ti2 Ge6
# Fe5+ Sm2 Fe2 Si4
# Nb4+ Ti1 Nb1 C2
# Ni4+ Ce1 Cu1 Si2 Ni1
# Co+ Ce1 Co1 Si3
# B3- Ta1 B2 Mo1
# Bi3- La6 Ni6 Bi8
# Ta2+ Ta4 Si4 Ni4
# Cu+ Mn2 Ga4 Cu6 Se12
# Ga2+ Sm2 Ga2 Si2
# Co4+ Co2 Cu2 Ni2 S8
# Tb+ Tb2 Al2 Ge2
# Nb4+ Zr1 Nb1 C2
# Yb2+ Yb1 Mn1 Cu1 P2
# Ho2+ Ho4 Zn4 Ge4
# Ga+ Ba4 Ga2 Ge2 N2
# Cr2+ Cr4 Cu4 P8 S24
# Nd2+ Nd12 Co4 Ge8
# Nb2+ Nb4 Ni4 Te8
# Tb4+ Tb10 Si4 B16
# La+ La2 Al2 Si2
# Fe4+ Ce2 Fe2 Si4
# Cu+ Y1 Cu1 Ge1
# V4+ Pr4 V4 Sb12
# Ce2+ Ce4 Ni6 Ge10
# Ni+ Ti2 Fe1 Ni1 Sb2
# Hf2+ Hf6 Ni6 Sb8
# Cu+ La1 Cu1 Ge1
# B3- Nb10 Si2 B4
# B3- Nb4 B4 Mo2
# Y+ Y2 Sn2 Ge2
# B0.66666667+ Na12 B36 Se34
# Mo2.66666667+ Hf8 Si16 Mo12
# Cu+ Zn1 Cu2 Si1 Se4
# Ni+ Li5 Ni9 P7
# Cu+ Mn1 Ga1 Cu2 Se4
# B- Lu4 Co4 B16
# B3- Ho2 B6 Mo2
# B- Ho4 Fe4 B16
# V4+ Dy4 V4 Sb12
# Co+ Ce12 Co4 Ge8
# Ga+ Ce2 Ga2 Si2
# Cu+ Yb1 Zn1 Cu1 P2
# Sm2+ Sm1 Zn1 Si1
# Ni+ Er12 Ni36 Ge24
# B3- Dy2 B6 Mo2
# Co4+ Er4 Co4 B16
# Tb2+ Tb1 Zn1 Si1
# Cu+ Pr1 Cu1 Ge1
# Ni+ Ni18 S16
# Cu+ Lu1 Cu1 Ge1
# Ni+ Li14 Ni42 P28
# Dy2+ Dy1 Zn1 Si1
# Gd2+ Gd1 Zn1 Si1
# Co4+ Ho4 Co4 B16
# B- Y4 Fe4 B16
# Co+ Lu6 Co30 Si18
# V2.1+ V10 Si6 B1
# Cu+ Cu2 W1 Se4
# La+ La24 In8 Ge8
# V4+ V5 Te8
# Ni+ Pr6 Ni6 Bi8
# Tb4+ Tb4 Fe4 B16
# Co4+ Co8 Cu6 Ni4 Se24
# Ta2+ Ta8 Ni12 Te20
# Co+ Ho6 Co30 Si18
# Ho2+ Ho1 Zn1 Si1
# Cu+ Na1 Mn1 Cu3 Se4
# Co4+ Dy4 Co4 B16
# Co+ Dy6 Co30 Si18
# Co+ Y6 Co30 Si18
# Ni1.22222222+ Mg5 Ni9 P7
# B- Er2 B4 C1
# B2- Ce4 Mn4 B16
# B2- Dy6 B14 Mo2
# B3- Nb1 B2 W1
# B- Y4 Co4 B16
# Nb2+ Nb4 Fe4 Si4
# Co+ Be1 Co2 Si1
# Pr2+ Li4 Pr4 Si6
# Tb4+ Tb4 Co4 B16
# B- Ho2 B4 C1
# Ni3+ Ni6 Se8
# Ta2+ Ta8 Al2 C6
# Co+ Co3 Ni3 P3
# Zr3+ Zr8 Al6 C12
# Ta2+ Ta36 Te18 S6
# B3- Zr3 Co9 B6
# Co+ Tb20 Co4 Bi8
# Ni4+ Fe3 Ni1 P4
# B- Tb6 B14 Mo2
# B1.28571429- Er4 B28 Mo12
# Co4+ Co2 Cu2 S8
# B1.28571429- Dy4 B28 Mo12
# Cu+ Al1 Cu1 P2 Se6
# B1.28571429- Tb4 B28 Mo12
# Cu+ Fe1 Cu6 Ge1 S8
# Yb2+ Yb2 Zn2 Ge2
# B- Tb2 B4 C1
# B3- Gd1 Y1 Co4 B4
# Bi5+ Bi4 I20
# Cu+ Mn1 Cd1 Cu4 Ge2 Se8
# Ni4+ Ni1 Te1 Se1
# B0.5- Ce1 Eu1 B12
# Cu+ In5 Cu1 Te8
# La2+ La6 Cu24 P12
# Ti2+ Ti6 Fe6 Ge6
# Mo3+ Mo30 N32
# Ce2+ La1 Ce1 Mn4 Si4
# Co+ Co7 Ni1 P4
# Nb+ Nb4 Ni10 Te12
# Nb+ Nb10 Ge6 C1
# Ga2+ Eu1 Ga1 Si1
# B- Gd4 Ni2 B20
# B0.5- La1 Ce3 B24
# Fe+ Zr6 Fe16 Si7
# B0.5- La1 Eu1 B12
# Ag2+ Ag1 Sn1 Se2
# Ta+ Ta12 Te2 Se4
# Pr2+ Pr6 Cu24 P12
# Cu+ Sr2 Li7 Cu1 N4
# Pr2+ La1 Pr1 Mn4 Si4
# B- Pr4 Ni2 B20
# B3- Tb1 Er4 Ni10 B10 C5
# Nb+ Nb6 Al2 C4
# Al2+ Al2 Si2 Te6
# Ce2+ Ce6 Cu24 P12
# Ce2+ Ce1 Zn1 Si1
# B- Tb4 Ni2 B20
# O- Ag7 N1 O11
# Cu+ Cd1 Cu2 Se2
# Ni4+ Dy4 Ni2 B20
# Nb+ Nb4 Ge2 C2
# Ni+ Be1 Si1 Ni2
# In2+ In1 Sn1 Te2
# Co4+ Co1 Ni1 Te4
# Ho2+ Ho2 Mn4 Si2 C2
# B- Y4 Ni2 B20
# B- Er4 Al4 B16
# Bi3- Mg6 Bi2 P1 N1
# Cu+ Cr1 Cu1 P2 Se6
# Dy2+ Dy2 Mn4 Si2 C2
# B- Ho4 Al4 B16
# Bi3- Na1 Li2 Bi1
# W2+ W12 I24
# Hf2+ Hf4 Al6 C8
# Tb2+ Tb2 Mn4 Si2 C2
# Cu+ Ta1 Nb1 Cu6 Te8
# B0.5- Nd1 Eu1 B12
# B- Yb4 Mn4 B16
# B0.5- Ce1 Sm1 B12
# Cu+ Eu12 Cu12 Ge12
# Ti2+ Ti1 Fe2 Ge1
# B0.5- Sm1 Eu1 B12
# Cr2+ Cr5 Te8
# Ga2+ Ga4 Si8 Ni24
# Mn+ Nd1 Sm1 Mn4 Ge4
# La2+ La1 Ag2 Ge2
# Fe+ Fe6 Ni2 P4
# B0.5- Pr1 Sm1 B12
# Cu+ Cu12 H24 C12 N24 Cl12
# B0.5- Yb1 Sm1 B12
# B2- Ce1 Co2 B2 C1
# Mn+ Nd1 Mn1 Fe1 Ge2
# Mo2.33333333+ Ni1 Te8 Mo6
# Fe+ Fe12 P6
# B0.5- Sm1 Gd1 B12
# Mn+ Nd2 Mn1 Fe3 Ge4
# Zr3+ Zr4 Al6 C8
# Sm2+ Sm2 Fe4 Si2 C2
# Mo2+ V2 Si6 Mo8
# Cu+ Li8 Cu1 N3
# Cu1.25+ Li5 Cu4 P6
# Ni3+ Ni3 Te4
# Ag2+ Ag2 O2
# Sm2+ Sm2 Mn4 Si2 C2
# B3- Cr2 B4 Mo4
# Ni+ Li2 Ni1 N1
# Ga2+ Sr1 Ga1 Si1
# Sm2+ Sm1 Al2 Ge2
# Yb2+ Yb8 Si4
# Ga2+ Ba1 Ga1 Si1
# B3- Yb3 Ni19 B10
# Cu+ Li7 Cu2 N3
# Fe+ Mn1 V1 Fe4 Si2
# Ni+ La2 Ni18 Ge8
# Ga+ Tb3 Ga1 C1
# B3- Dy6 Co58 Si8 B20
# Mo2.4+ Mn24 Si32 Mo20
# Dy2+ Dy1 Al2 Ge2
# Ni4+ Fe2 Ni2 P12
# B+ Sm20 B20 C20
# Co1.5+ Li1 Co2 Si1
# Ho2+ Ho1 Al2 Ge2
# Cu3+ Yb1 Zn1 Cu1 Si2
# Co4+ Co1 Si4 Ni1
# Nb+ Nb2 Ge2 Sb2
# Bi3- K1 Na2 Bi1
# Bi+ Bi4 Te3
# Bi3- Na3 Bi1
# B3- Fe4 B4
# Fe+ Be1 Fe2 Si1
# Cu+ Cu13 I15
# Ni+ Ni17 Ge4 Se4
# B2- Eu1 Ni2 B2 C1
# Co+ Fe3 Co3 Si2
# Cu+ Cu16 I19
# Ag2.5+ Dy1 Si2 Ag2
# Ni+ Li1 Ni2 Sb1
# Co+ Fe2 Co1 Si1
# Mo3+ Mo2 C1 N1
# Mo3+ Dy2 Mo2 C3
# Bi3- K4 Ag2 Bi2
# Mn+ Ca1 Mn1 Fe1 Ge2
# Ag2+ Ag1 I2
# Mo3+ Tb2 Mo2 C3
# Fe6+ Ca1 Ce1 Fe8 Sb24
# Dy2+ Dy30 C40
# Ni+ Ni10 Ge6
# Co+ Be1 Co2 Ge1
# Bi3- K2 Bi2 Pb2
# Yb2+ Li2 Yb1 Si1
# Fe6+ Fe4 B8
# Cu+ Cu4 Si2 Te6
# Ni+ Ni6 Sb1 Te2
# Mn+ Mn2 V1 Ge1
# Ni4+ Fe2 Ni2 Sb12
# B0.5+ Li2 B24 P2 C2
# Sm2+ Sm12 Mn5 C15
# V3+ Ta1 V1 H4
# Fe+ V1 Fe1 Co1 Ge1
# Bi3- Zr12 Bi4
# Gd2+ Gd2 C1
# Bi3- Na4 Cd4 Bi4
# Co+ V1 Co2 Ge1
# Co+ Mn4 Cr1 Co10 Ge5
# Ni+ Ni10 Sb4
# B0+ Tb2 Si8 B36 C2
# B0.83333333- Dy2 Si9 B36 C1
# B2+ B40 H44 C8
# B0.83333333- Lu2 Si9 B36 C1
# Fe6+ Fe4 Sb12
# B0.23076923+ Li2 B26 C4
# Sm2+ Sm2 C1
# Co+ Cr1 Co2 Ge1
# B3- Li2 Be2 B2
# Mn+ Mn3 Ge1
# B0.83333333- Mg3 Si9 B36 C1
# Fe+ Mn1 Fe2 Ge1
# Bi+ Bi3 Sb1
# Fe+ Fe1 H1
# Co+ Co1 H1

# %%
Element("Fe").common_oxidation_states  # for example, no Fe4+
# Out:
# (2, 3)

# %%
filtered_data_df = []
for d in filtered_data:
    clean_d = {"formula":d["composition"].reduced_formula}
    clean_d["mpid"] = str(d["material_id"])
    clean_d["e_hull"] = d["energy_above_hull"]
    clean_d["e_f"] = round(d["formation_energy_per_atom"],4)
    clean_d["e_d"] = round(d["equilibrium_reaction_energy_per_atom"],4) if d["equilibrium_reaction_energy_per_atom"] else None
    clean_d["avg_oxi"] = d["average_oxidation_states"]
    clean_d["num_elems"] = len(d["composition"].elements)
    filtered_data_df.append(clean_d)
    
df = pandas.DataFrame(filtered_data_df)

# %%
len(filtered_data_df)
# Out:
# 3372

# %%
df.sort_values("e_d").head()  # looking good!
# Out:
#     formula        mpid  e_hull     e_f     e_d                 avg_oxi  \
# 1      DyF3  mp-1212843     0.0 -4.4680 -4.4680  {'Dy': 3.0, 'F': -1.0}
# 2      LuF3  mp-1207204     0.0 -4.4534 -4.4534  {'Lu': 3.0, 'F': -1.0}
# 53     GdF3   mp-972965     0.0 -4.1128 -4.1128  {'Gd': 3.0, 'F': -1.0}
# 231    BeF2   mp-561543     0.0 -3.5527 -3.5527  {'Be': 2.0, 'F': -1.0}
# 412   Ta2O5  mp-1539317     0.0 -3.3365 -3.3365  {'Ta': 5.0, 'O': -2.0}
#
#      num_elems
# 1            2
# 2            2
# 53           2
# 231          2
# 412          2

# %% [markdown]
# #### Removing compounds which have other synthesized polymorphs
#
# Materials Project sometimes gets the incorrect polymorph ordering for several compounds.
#
# For example, MP may indicate that our downloaded entry for LiBr has never been synthesized. While it is true that that particular polymorph may have never been synthesized, there is another one that HAS been synthesized and calculated to be metastable (it could even be just +0.002 eV/atom above the hull and therefore not found in our search).
#
# Therefore we'd like to remove compounds that are associated with *any* previously synthesized crystal structure.

# %%
with MPRester() as mpr:
    previously_synthesized = mpr.summary.search(theoretical=False, 
                                   exclude_elements=exclude_elements, 
                                   all_fields=False,
                                   deprecated=False,
                                   has_props=[emmet.core.summary.HasProps("oxi_states")],
                                  fields=["composition"])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/32545 [00:00<?, ?it/s]

# %%
known_formulas = {d.composition.reduced_formula for d in previously_synthesized}
# Out:
# No electronegativity for He. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
# No electronegativity for Ar. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.
# No electronegativity for Ne. Setting to NaN. This has no physical meaning, and is mainly done to avoid errors caused by the code expecting a float.

# %%
filtered_data_df_2 = [d for d in filtered_data_df if d['formula'] not in known_formulas]

# %%
df = pandas.DataFrame(filtered_data_df_2)

# %%
len(df)
# Out:
# 3045

# %% [markdown]
# #### Removing binary compounds
# Many of these already exist. As we are looking for purely novel compounds, it's best to get rid of these.

# %%
df_2 = df[df["num_elems"]>2]
df_2
# Out:
#          formula        mpid    e_hull     e_f     e_d  \
# 0     BaGdCrFeO6  mp-1518724  0.000000 -5.1543 -2.4397
# 3        BaLu2F8  mp-1214962  0.000000 -4.4284 -0.0539
# 4         BaY2F8   mp-768240  0.000000 -4.3848 -0.0106
# 5      Sr4Lu3F17    mp-35769  0.000000 -4.3724 -0.0294
# 6           LuOF  mp-1210775  0.000000 -4.3444 -0.0331
# ...          ...         ...       ...     ...     ...
# 3035       KCuH3  mp-1147650  0.000000 -0.1126 -0.0015
# 3036       MoWC2  mp-1221393  0.000801 -0.1023     NaN
# 3038      Al3BC3  mp-1228599  0.000000 -0.0922 -0.0058
# 3040   Mg(AlGe)2  mp-1232292  0.000000 -0.0827 -0.0020
# 3041     Zn3SbN3  mp-1271278  0.000000 -0.0506 -0.0000
#
#                                                 avg_oxi  num_elems
# 0     {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5
# 3                     {'Ba': 2.0, 'Lu': 3.0, 'F': -1.0}          3
# 4                      {'Ba': 2.0, 'Y': 3.0, 'F': -1.0}          3
# 5                     {'Sr': 2.0, 'Lu': 3.0, 'F': -1.0}          3
# 6                     {'Lu': 3.0, 'O': -2.0, 'F': -1.0}          3
# ...                                                 ...        ...
# 3035                   {'K': 1.0, 'Cu': 2.0, 'H': -1.0}          3
# 3036                   {'Mo': 4.0, 'W': 4.0, 'C': -4.0}          3
# 3038                   {'Al': 3.0, 'B': 3.0, 'C': -4.0}          3
# 3040                 {'Mg': 2.0, 'Al': 3.0, 'Ge': -4.0}          3
# 3041                  {'Zn': 2.0, 'Sb': 3.0, 'N': -3.0}          3
#
# [2960 rows x 7 columns]

# %% [markdown]
# #### Filter by literature data
# The Materials Project uses a reference to the ICSD database to check if a compound has been synthesized. Because this may be outdated, we now turn to the recent Kononova et al. literature dataset to check for any compounds that have been experimentally synthesized.
#
# Here search the sol-gel and solid-state datasets by formula and filter out any compounds that appear in either.

# %%
f1 = loadfn("solid-state_dataset_20200713.json.xz")
f2 = loadfn("sol-gel_dataset_20200713.json.xz")

# %%
def get_formulas_from_lit(f):
    all_formulas = set()
    for r in f["reactions"]:
        for precursor in r["precursors"]:
            try:
                all_formulas.add(Composition(precursor["material_formula"]).reduced_formula)
            except Exception as e:
                pass
        try:
            all_formulas.add(Composition(r["target"]["material_formula"]).reduced_formula)
        except Exception as e:
            pass
                
    return all_formulas

# %%
all_lit_formulas = get_formulas_from_lit(f1) | get_formulas_from_lit(f2)

# %%
df_3 = df_2[[f not in all_lit_formulas for f in df_2["formula"]]]

# %%
len(df_3)
# Out:
# 2759

# %% [markdown]
# #### Label common composition types
# The goal here is to prioritize synthesizing compounds of desired formula types (and avoiding others).
#
# *We must define these first since they don't seem to be pre-defined in pymatgen...!*

# %%
def get_formula_type_by_anion(formula):
    polyatomics={
        'PO3': 'phosphite',
        'PO4': 'phosphate',
        'HPO4': 'hydrogen phosphate',
        'H2PO4': 'dihydrogen phosphate',
        'BO3': 'orthoborate',
        'BO2': 'metaborate',
        'B2O5': 'diborate',
        'B3O7': 'triborate',
        'B4O7': 'tetraborate',
        'ClO4': 'perchlorate',
        'ClO3': 'chlorate',
        'ClO2': 'chlorite',
        'ClO': 'hypochlorite',
        'OCl': 'oxychloride',
        'BrO4': 'perbromate',
        'BrO3': 'bromate',
        'BrO2': 'bromite',
        'BrO': 'hypobromite',
        'IO4': 'periodate',
        'IO3': 'iodate',
        'IO2': 'iodite',
        'IO': 'hypoiodite',
        'NH4': 'ammonium',
        'NO2': 'nitrite',
        'NO3': 'nitrate',
        'SO3': 'sulfite',
        'SO4': 'sulfate',
        'HSO3': 'bisulfite',
        'HSO4': 'bisulfate',
        'S2O3': 'thiosulfate',
        'HS2O3': 'hydrogen thiosulfate',
        'C2O4': 'oxalate',
        'HC2O4': 'hydrogen oxalate',
        'OH': 'hydroxide',
        'CH3COO': 'acetate',
        'CO3': 'carbonate',
        'HCO3': 'bicarbonate',
        'CrO4': 'chromate',
        'Cr2O7': 'dichromate',
        'MnO4': 'permanganate',
        'CN': 'cyanide',
        'OCN': 'cyanate',
        'SCN': 'thiocyanate',
        'C8H4O4': 'phthalate',
        'C2H3O2': 'acetate',
        'HCO2': 'fomate',
        'SiO4': 'silicate'
    }
    polyatomics = OrderedDict({k: polyatomics[k] for k in sorted(polyatomics, key=len, reverse=True)})
    anions = {"H":'hydride',
            "F":"fluoride",
              "Cl":"chloride",
              "Br":"bromide",
              "I":"iodide",
              "O":"oxide",
              "S":"sulfide",
              "Se":"selenide",
              "Te":"telluride",
              "N":"nitride", 
              "P":"phosphide",
              "As":"arsenide",
              "Sb":"antimonide",
              "Bi":"bismide",
              "C":"carbide",
              "Si":"silicide",
              "Ge":"germanide",
             "Sn":"stannide",
             "Pb":"plumbide",
             "B":"boride",
             "Al":"aluminide",
             "Ga":"gallide",
             "In":"indide",
             "Tl":"thallide",
             "Ni":"nickelide",
             "Mo":"molybdenide"}
    
    for p, name in polyatomics.items():
        if p in formula:
            return name
    
    return anions[re.findall(r"([A-Z][a-z]?)(\d*\)?\d*$)", formula)[0][0]]

# %%
df_3["type"] = [get_formula_type_by_anion(f) for f in df_3["formula"]]
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# Desired composition types:

# %%
desired = ["oxide","sulfite","sulfate","bisulfate","silicate",
           "fluoride","chloride","bromide","orthoborate", "metaborate",
           "hydroxide","carbonate","tetraborate","phosphate","phosphite",
           "chlorate","chlorite","hypochlorite","oxychloride","bicarbonate",
          ]

# %%
df_4 = df_3[[r["type"] in desired for _, r in df_3.iterrows()]]

# %%
df_4.sort_values("e_d").head(10)
# Out:
#          formula        mpid  e_hull     e_f     e_d  \
# 0     BaGdCrFeO6  mp-1518724     0.0 -5.1543 -2.4397
# 1909    Na3ErBr6  mp-1210529     0.0 -2.0638 -0.9318
# 1921    Li3ErBr6  mp-1222492     0.0 -2.0536 -0.9269
# 1166   Tb2(SO4)3  mp-1208801     0.0 -2.6597 -0.3736
# 1212   Sm2(SO4)3  mp-1208980     0.0 -2.6233 -0.3730
# 1156   Dy2(SO4)3  mp-1213482     0.0 -2.6635 -0.3698
# 1144   Ho2(SO4)3   mp-768978     0.0 -2.6695 -0.3688
# 1116   Lu2(SO4)3   mp-768453     0.0 -2.6833 -0.3559
# 527    La5Mn5O16   mp-531717     0.0 -3.1633 -0.3022
# 965        YbCO3   mp-755213     0.0 -2.8150 -0.3007
#
#                                                 avg_oxi  num_elems       type
# 0     {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5      oxide
# 1909                 {'Na': 1.0, 'Er': 3.0, 'Br': -1.0}          3    bromide
# 1921                 {'Li': 1.0, 'Er': 3.0, 'Br': -1.0}          3    bromide
# 1166                   {'Tb': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 1212                   {'Sm': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 1156                   {'Dy': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 1144                   {'Ho': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 1116                   {'Lu': 3.0, 'S': 6.0, 'O': -2.0}          3    sulfate
# 527                   {'La': 3.0, 'Mn': 3.4, 'O': -2.0}          3      oxide
# 965                    {'Yb': 3.0, 'C': 3.0, 'O': -2.0}          3  carbonate

# %%
df_4.value_counts("type")  # most are oxides!
# Out:
# type
# oxide           1241
# fluoride         293
# phosphate        115
# chloride          77
# sulfate           72
# bromide           41
# phosphite         27
# carbonate         23
# orthoborate       21
# hypochlorite      19
# chlorate          10
# silicate           9
# chlorite           8
# metaborate         8
# sulfite            4
# Name: count, dtype: int64

# %%
len(df_4)
# Out:
# 1968

# %% [markdown]
# #### Removing any missed ICSD compounds
# Citrine Informatics has available a list of ICSD formulas found here: https://github.com/CitrineInformatics/learn-citrination/blob/master/citrination_api_examples/tutorial_sequence/example_data/icsd.dat
#
# Even though we previously filtered out compounds that the Materials Project said were in ICSD, this updated list will catch some ones that are more recent / missing from MP.

# %%
citrine = loadfn("icsd_compounds.json.gz")
df_5 = df_4[[f not in citrine for f in df_4["formula"]]]

# %%
len(df_5)
# Out:
# 1448

# %% [markdown]
# #### Removing compounds that appear in De Gruyter's Handbook of Inorganic Substances (2017)
# Handbook of Inorganic Substances (2017): https://www.degruyter.com/document/doi/10.1515/9783110445404/html?lang=en
#
# Using Optical Character Recognition, we scraped the formulas from this handbook. This seems to be a much more encompassing source (often containing compounds that cannot even be identified from Google searches.)

# %%
de_gruyter = loadfn("de_gruyter_formulas.json.gz")
de_gruyter = set(de_gruyter)

# %%
len(de_gruyter)
# Out:
# 99842

# %%
df_6 = df_5[[f not in de_gruyter for f in df_5["formula"]]]

# %%
len(df_6)
# Out:
# 616

# %%
df_6.sort_values(["e_d", "e_hull"]).head(15)
# Out:
#           formula        mpid  e_hull     e_f     e_d  \
# 0      BaGdCrFeO6  mp-1518724     0.0 -5.1543 -2.4397
# 527     La5Mn5O16   mp-531717     0.0 -3.1633 -0.3022
# 381      Eu5P3O13  mp-1212818     0.0 -3.3259 -0.2512
# 2161       Eu2PCl  mp-1225319     0.0 -1.7790 -0.2175
# 47       YbGd3F12  mp-1215594     0.0 -4.1427 -0.2041
# 111    BaCeEuHfO6  mp-1516655     0.0 -3.8470 -0.1453
# 349         CaWF6  mp-1395540     0.0 -3.3691 -0.1426
# 1727   HfZn(SO4)3  mp-2713876     0.0 -2.2481 -0.1379
# 482         MgWF6  mp-1407403     0.0 -3.2070 -0.1286
# 904   Hf2Si(SO6)2  mp-2713341     0.0 -2.8616 -0.1188
# 1449   HfMg(SO4)3  mp-2713884     0.0 -2.4606 -0.1154
# 1916       GaSbO4  mp-1224786     0.0 -2.0554 -0.1113
# 1066        ZnWF6  mp-1400616     0.0 -2.7240 -0.1054
# 796         NaVF6  mp-1120731     0.0 -2.9429 -0.1034
# 460        MgSnF6  mp-1397451     0.0 -3.2305 -0.1010
#
#                                                 avg_oxi  num_elems      type
# 0     {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5     oxide
# 527                   {'La': 3.0, 'Mn': 3.4, 'O': -2.0}          3     oxide
# 381                    {'Eu': 2.2, 'P': 5.0, 'O': -2.0}          3     oxide
# 2161                 {'Eu': 2.0, 'P': -3.0, 'Cl': -1.0}          3  chloride
# 47                    {'Yb': 3.0, 'Gd': 3.0, 'F': -1.0}          3  fluoride
# 111   {'Ba': 2.0, 'Ce': 4.0, 'Eu': 2.0, 'Hf': 4.0, '...          5     oxide
# 349                    {'Ca': 2.0, 'W': 4.0, 'F': -1.0}          3  fluoride
# 1727        {'Hf': 4.0, 'Zn': 2.0, 'S': 6.0, 'O': -2.0}          4   sulfate
# 482                    {'Mg': 2.0, 'W': 4.0, 'F': -1.0}          3  fluoride
# 904         {'Hf': 4.0, 'Si': 4.0, 'S': 6.0, 'O': -2.0}          4     oxide
# 1449        {'Hf': 4.0, 'Mg': 2.0, 'S': 6.0, 'O': -2.0}          4   sulfate
# 1916                  {'Ga': 3.0, 'Sb': 5.0, 'O': -2.0}          3     oxide
# 1066                   {'Zn': 2.0, 'W': 4.0, 'F': -1.0}          3  fluoride
# 796                    {'Na': 1.0, 'V': 5.0, 'F': -1.0}          3  fluoride
# 460                   {'Mg': 2.0, 'Sn': 4.0, 'F': -1.0}          3  fluoride

# %% [markdown]
# #### Saving as Excel file

# %%
df_6.sort_values(["e_d", "e_hull"]).to_excel("screened_targets.xlsx")

# %%
df_6
# Out:
#             formula        mpid    e_hull     e_f     e_d  \
# 0        BaGdCrFeO6  mp-1518724  0.000000 -5.1543 -2.4397
# 47         YbGd3F12  mp-1215594  0.000000 -4.1427 -0.2041
# 70        Dy11Y5O24   mp-766279  0.000417 -3.9979     NaN
# 74           NaLaF4  mp-1220826  0.000000 -3.9914 -0.0171
# 82           NaSmF4  mp-1220915  0.000000 -3.9742 -0.0305
# ...             ...         ...       ...     ...     ...
# 2653        Zn3PBr3  mp-1215629  0.000000 -0.9335 -0.0154
# 2668  Cu2Ag5Se4NO15  mp-1225986  0.000000 -0.9062 -0.0181
# 2826     Zn3P6N12Cl  mp-1215763  0.000000 -0.6356 -0.0394
# 2922       Co(NF3)4  mp-1214815  0.000000 -0.5108 -0.0028
# 2939    Li2H2C6N9Cl  mp-2647033  0.000000 -0.4603 -0.0280
#
#                                                 avg_oxi  num_elems      type
# 0     {'Ba': 2.0, 'Gd': 3.0, 'Cr': 5.0, 'Fe': 2.0, '...          5     oxide
# 47                    {'Yb': 3.0, 'Gd': 3.0, 'F': -1.0}          3  fluoride
# 70                     {'Dy': 3.0, 'Y': 3.0, 'O': -2.0}          3     oxide
# 74                    {'Na': 1.0, 'La': 3.0, 'F': -1.0}          3  fluoride
# 82                    {'Na': 1.0, 'Sm': 3.0, 'F': -1.0}          3  fluoride
# ...                                                 ...        ...       ...
# 2653                 {'Zn': 2.0, 'P': -3.0, 'Br': -1.0}          3   bromide
# 2668  {'Cu': 2.0, 'Ag': 1.0, 'Se': 4.0, 'N': 5.0, 'O...          5     oxide
# 2826  {'Zn': 2.0, 'P': 5.0, 'N': -2.9166666666666665...          4  chloride
# 2922                   {'Co': 2.0, 'N': 2.5, 'F': -1.0}          3  fluoride
# 2939  {'Li': 1.0, 'H': 1.0, 'C': 4.0, 'N': -3.0, 'Cl...          5  chloride
#
# [616 rows x 8 columns]

# %% [markdown]
# #### Final step: manual curation of the final dataset
#
# Google searches of some of these compounds indicate that several have been synthesized very recently and thus would not be captured by any of our resources.
#
# To create the final dataset, one should search the literature for any recent mentions of these compounds.
#
# We performed this manual curation step in Nov 2022; the results are saved as `final_targets_manually_cleaned_11_11_22.xlsx`.
